# %% [markdown]
# # Project 3: Wrangle OpenStreetMap Data

# %% [markdown]
# ### Map Area: Atlanta, GA (https://mapzen.com/data/metro-extracts/metro/atlanta_georgia/)
#
# #### I picked Atlanta becuase it is the city I currently live in.

# %%
# Note: The schema is stored in a .py file in order to take advantage of the
# int() and float() type coercion functions. Otherwise it could easily stored as
# as JSON or another serialized format.

schema = {
    'node': {
        'type': 'dict',
        'schema': {
            'id': {'required': True, 'type': 'integer', 'coerce': int},
            'lat': {'required': True, 'type': 'float', 'coerce': float},
            'lon': {'required': True, 'type': 'float', 'coerce': float},
            'user': {'required': True, 'type': 'string'},
            'uid': {'required': True, 'type': 'integer', 'coerce': int},
            'version': {'required': True, 'type': 'string'},
            'changeset': {'required': True, 'type': 'integer', 'coerce': int},
            'timestamp': {'required': True, 'type': 'string'}
        }
    },
    'node_tags': {
        'type': 'list',
        'schema': {
            'type': 'dict',
            'schema': {
                'id': {'required': True, 'type': 'integer', 'coerce': int},
                'key': {'required': True, 'type': 'string'},
                'value': {'required': True, 'type': 'string'},
                'type': {'required': True, 'type': 'string'}
            }
        }
    },
    'way': {
        'type': 'dict',
        'schema': {
            'id': {'required': True, 'type': 'integer', 'coerce': int},
            'user': {'required': True, 'type': 'string'},
            'uid': {'required': True, 'type': 'integer', 'coerce': int},
            'version': {'required': True, 'type': 'string'},
            'changeset': {'required': True, 'type': 'integer', 'coerce': int},
            'timestamp': {'required': True, 'type': 'string'}
        }
    },
    'way_nodes': {
        'type': 'list',
        'schema': {
            'type': 'dict',
            'schema': {
                'id': {'required': True, 'type': 'integer', 'coerce': int},
                'node_id': {'required': True, 'type': 'integer', 'coerce': int},
                'position': {'required': True, 'type': 'integer', 'coerce': int}
            }
        }
    },
    'way_tags': {
        'type': 'list',
        'schema': {
            'type': 'dict',
            'schema': {
                'id': {'required': True, 'type': 'integer', 'coerce': int},
                'key': {'required': True, 'type': 'string'},
                'value': {'required': True, 'type': 'string'},
                'type': {'required': True, 'type': 'string'}
            }
        }
    }
}

# %%
#!jupyter nbconvert --to script schema.ipynb

# %%
import csv
import codecs
import pprint
import re
import xml.etree.cElementTree as ET
from collections import defaultdict

import cerberus

import schema

OSM_PATH = "sample.osm"

NODES_PATH = "nodes.csv"
NODE_TAGS_PATH = "nodes_tags.csv"
WAYS_PATH = "ways.csv"
WAY_NODES_PATH = "ways_nodes.csv"
WAY_TAGS_PATH = "ways_tags.csv"

LOWER_COLON = re.compile(r'^([a-z]|_)+:([a-z]|_)+')
PROBLEMCHARS = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

SCHEMA = schema.schema

# Make sure the fields order in the csvs matches the column order in the sql table schema
NODE_FIELDS = ['id', 'lat', 'lon', 'user', 'uid', 'version', 'changeset', 'timestamp']
NODE_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_FIELDS = ['id', 'user', 'uid', 'version', 'changeset', 'timestamp']
WAY_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_NODES_FIELDS = ['id', 'node_id', 'position']

# %%
#create a dictionary of the different tags as the key and how many as the value
def count_tags(filename):
    tags = {}
    for ev, elem in ET.iterparse(filename):
        tag = elem.tag
        if tag not in tags.keys():
            tags[tag] = 1
        else:
            tags[tag] = tags[tag]+1
    return tags

# %%
tags = count_tags('sample.osm')
pprint.pprint(tags)
# Out:
# {'member': 3127,
#  'nd': 1327804,
#  'node': 1171609,
#  'osm': 1,
#  'relation': 422,
#  'tag': 623090,
#  'way': 84260}

# %%
#provided regular expressions 
lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

#checking the 'k' value for each tag for potential problem characters
def key_type(element, keys):
    if element.tag == "tag":
        k = element.attrib['k']
        if re.search(lower,k):
            keys["lower"] += 1
        elif re.search(lower_colon,k):
            keys["lower_colon"] += 1
        elif re.search(problemchars,k):
            keys["problemchars"] += 1
            print k
        else:
            keys["other"] += 1
    return keys
    pass

#create a dictionary with 4 tag categories as the key and how many as the value
def process_map_v1(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)

    return keys

# %%
keys = process_map_v1('sample.osm')
pprint.pprint(keys)
# Out:
# towing service
# Payment options
# Abundance LLC Wealth Advisors
# {'lower': 288874, 'lower_colon': 243990, 'other': 90223, 'problemchars': 3}

# %%
#number of users that have edited the map data
def process_map_v2(filename):
    users = set()
    for _, element in ET.iterparse(filename):
        for e in element:
            if 'uid' in e.attrib:
                users.add(e.attrib['uid'])
    return users
users = process_map_v2('sample.osm')
len(users)
# Out:
# 1391

# %%
def get_user(element):
    if "uid" in element.attrib:
        return element.attrib["uid"]


def process_map_v3(filename):
    users = set()
    for _, element in ET.iterparse(filename):
        users.update([get_user(element)])
        users.discard(None) 
    return users

# %%
#number of users that have edited the map data
users = process_map_v3('sample.osm')
len(users)
# Out:
# 1391

# %%
osm_file_open = open("sample.osm","r")
osmfile = "sample.osm"
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)
street_types = defaultdict(set)

# %%
#expected street names for the street type audit
expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Way", "Circle", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons"]

# %%
#provided street type audit code
def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)
            
def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")

def audit_1():
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    pprint.pprint(dict(street_types))
    
def audit_2(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    osm_file.close()
    return street_types

# %%
audit_1()
# Out:
# {'101': set(['State Rte 101']),
#  '138': set(['State Rte 138']),
#  '140': set(['S R 140']),
#  '20': set(['State Rte 20']),
#  '212': set(['State Rte 212']),
#  '41': set(['US 41']),
#  '5': set(['Old Hwy 5']),
#  '78': set(['Highway 78']),
#  'Apartment': set(['Woodland Apartment']),
#  'Approach': set(['Inverness Approach']),
#  'Ave': set(['2nd Ave',
#              'Bridge Mill Ave',
#              'Confederate Ave',
#              'E Foster Ave',
#              'E Ponce de Leon Ave',
#              'Gail Ave',
#              'Highland Ave',
#              'Lexington Ave',
#              'Lyons Ave',
#              'Park Ave',
#              'Rolling Hills Ave',
#              'Seaboard Ave',
#              'Spring Meadows Ave',
#              'The General Ave',
#              'Transit Ave',
#              'W Cooper Ave',
#              'W Foster Ave',
#              'Washington Ave']),
#  'Bend': set(['Glade Bend',
#               'Horsehoe Bend',
#               'Overlook Bend',
#               'Sapphire Bend',
#               'Sweetwater Bend',
#               'Willow Bend']),
#  'Bluff': set(['Aspen Bluff',
#                'Diamond Bluff',
#                'North Bluff',
#                'North Eagles Bluff',
#                'North Falcon Bluff',
#                'Rose Creek Bluff',
#                'South Eagles Bluff',
#                'South Falcon Bluff',
#                'Wheatridge Bluff']),
#  'Blvd': set(['Liberty Blvd',
#               'Riverstone Blvd',
#               'Scott Blvd',
#               'White Columns Blvd']),
#  'Branches': set(['Cross Branches']),
#  'COurt': set(['Benidorm COurt']),
#  'Chapel': set(['Old Chapel']),
#  'Chase': set(['Bluffwind Chase',
#                'Devereux Chase',
#                'Fir Chase',
#                'Foxworth Chase',
#                'Georgetown Chase',
#                'Lazy Laurel Chase',
#                'Longwood Chase',
#                'Morgan Falls Chase',
#                'Park Chase',
#                'Regency Chase',
#                'Shadow Creek Chase',
#                'Taylor Meadow Chase']),
#  'Cir': set(['Ash Cir',
#              'Barros Cir',
#              'Bell Park Cir',
#              'Bone Cir',
#              'Braddock Cir',
#              'Brittania Cir',
#              'Buchanan Cir',
#              'Castlemaine Cir',
#              'Cherokee Village Cir',
#              'Cloud Cir',
#              'Colony Cir',
#              'Compton Cir',
#              'Corley Cir',
#              'Cross Ridge Cir',
#              'Daisy Cir',
#              'Duncan Cir',
#              'Eagle Glen Cir',
#              'Eileen Cir',
#              'Ettas Cir',
#              'Floyd Clark Cir',
#              'Forkwood Cir',
#              'Grandview Cir',
#              'Hank Cir',
#              'Harbor Wood Cir',
#              'Hardy Cir',
#              'Harmon Cir',
#              'Haynes Cir',
#              'Hill Cir',
#              'Hillcrest Cir',
#              'Hilltop Cir',
#              'Hitt Cir',
#              'Hollis Cir',
#              'Jefferson Cir',
#              'Kirkwood Cir',
#              'Lake Cir',
#              'Legacy Park Cir',
#              'Lovejoy Cir',
#              'Macedonia Forest Cir',
#              'Mariner Cir',
#              'Moreland Cir',
#              'Narroway Church Cir',
#              'Northwoods Cir',
#              'Nowlin Cir',
#              'Oak Landing Cir',
#              'Oakcrest Cir',
#              'Old Sixes Cir',
#              'Paris Cir',
#              'Perkins Cir',
#              "Pickett's Cir",
#              'Pine Cir',
#              'Pioneer Cir',
#              'Pope Cir',
#              'Quail Hollow Cir',
#              'Red Fox Cir',
#              'Reed Cir',
#              'Richardson Cir',
#              'Rising Cir',
#              'Roxbury Cir',
#              'Santa Fe Cir',
#              'Shadow Cir',
#              'Shadow Ridge Cir',
#              'Silverthorne Cir',
#              'Sinyard Cir',
#              'Spring Gate Cir',
#              'Summit Cir',
#              'Sweetgum Cir',
#              'Theodore Cox Cir',
#              'Victorian Cir',
#              'Waldan Cir',
#              'Weaver Cir',
#              'Willow Oak Cir',
#              'Winners Cir']),
#  'Clifton': set(['Clifton']),
#  'Close': set(['Blairshire Close',
#                'Branchwind Close',
#                'Cedar Close',
#                'Cliffchase Close',
#                'Cottonwood Close',
#                'Cupit Close',
#                'Dunvegan Close',
#                'Hughes Branch Close',
#                'Marshview Close',
#                'Mistwater Close',
#                'Park Close',
#                'Ridge Point Close',
#                'River Close',
#                'Saint Ignaius Close',
#                'Taylor Knoll Close',
#                'Twinspur Close',
#                'Waverly Hall Close']),
#  'Con': set(['Interstate Highway 575 Byp Con']),
#  'Connector': set(['East-West Connector', 'GA 136 Connector']),
#  'Copse': set(['Cullen Copse']),
#  'Cove': set(['Amethyst Cove',
#               'Broadmeadow Cove',
#               'Cedar Mill Cove',
#               'Cherry Cove',
#               'Claiborne Cove',
#               'Classic Cove',
#               'Cranwood Cove',
#               'Creekside Cove',
#               'Cross Creek Cove',
#               'Deep Creek Cove',
#               'Edgewater Cove',
#               'Elizabeth Cove',
#               'Kensington Cove',
#               'Lochan Cove',
#               'Mill Pointe Cove',
#               'Narda Grace Cove',
#               'Pinehurst Cove',
#               'Tuscan Cove',
#               'Virginia Cove',
#               'Wolfcreek Cove']),
#  'Creek': set(['Cranberry Creek',
#                'Little Creek',
#                "Pickett's Creek",
#                'Toonigh Creek']),
#  'Crossing': set(['Anmore Crossing',
#                   'Hawkins Crossing',
#                   'Inverness Crossing',
#                   'West Hembree Crossing']),
#  'Crst': set(['Woodbrook Crst']),
#  'Ct': set(['Abnaki Ct',
#             'Acorn Ct',
#             'Allatoona Ct',
#             'Amberwood Ct',
#             'Amy Ct',
#             'Andes Ct',
#             'Ansley Ct',
#             'Apple Ct',
#             'Ashey Ct',
#             'Augustus Ct',
#             'Autumn Ct',
#             'Becky Ct',
#             'Bedford Ct',
#             'Beech Ct',
#             'Bell Ct',
#             'Bennett Farms Ct',
#             'Bent Creek Ct',
#             'Bentwater Ct',
#             'Birchwood Ct',
#             'Bitternut Ct',
#             'Bonds Ct',
#             'Bonnabel Ct',
#             'Bradshaw Lake Ct',
#             'Bramble Ct',
#             'Brentwood Ct',
#             'Bridgewater Ct',
#             'Brier Bend Ct',
#             'Broadwater Ct',
#             'Brook Ct',
#             'Byron Ct',
#             'Cabin Creek Ct',
#             'Cade Ct',
#             'Caliber Ct',
#             'Camrose Ct',
#             'Caylee Ct',
#             'Cedar Ct',
#             'Charles Cox Ct',
#             'Chieftan Ct',
#             'Christa Ct',
#             'Clayton Ct',
#             'Clearwater Ct',
#             'Colemans Ct',
#             'Colette Ct',
#             'Colony Springs Ct',
#             'Cool Springs Ct',
#             'Corner Oak Ct',
#             'Covey Ct',
#             'Crabapple Ct',
#             'Crabapple Springs Ct',
#             'Creekridge Ct',
#             'Creekwood Ct',
#             'Cristy Ct',
#             'Darby Ford Ct',
#             'Deer Ct',
#             'Desmond Ct',
#             'Devon Ct',
#             'Discovery Ct',
#             'Dixie Ct',
#             'Dogwood Ct',
#             'Douglas Fir Ct',
#             'Dove Ct',
#             'E Lake Ct',
#             'Echota Ct',
#             'Elizabeth Ct',
#             'Elkay Ct',
#             'Etowah Ct',
#             'Etowah Industrial Ct',
#             'Evans Cook Ct',
#             'Evans Mill Ct',
#             'Executive Ct',
#             'Fairfax Ct',
#             'Fairway Ct',
#             'Fairway Valley Ct',
#             'Faith Ct',
#             'Falls Ct',
#             'Ferret Ct',
#             'Fir Ct',
#             'Forest Ct',
#             'Fort Wayne Ct',
#             'Fox Creek Ct',
#             'Friar Tuck Ct',
#             'Fullerton Ct',
#             'Garnet Ct',
#             'Glenwood Ct',
#             'Gopher Ct',
#             'Hancock Ct',
#             'Hanover Ct',
#             'Harbor Watch Ct',
#             'Hayes Ct',
#             'Hickory Creek Ct',
#             'Hightower Ct',
#             'Holden Ct',
#             'Holland Ct',
#             'Hollow Ct',
#             'Holly Chase Ct',
#             'India Lake Ct',
#             'Indian Lake Ct',
#             'Ivy Green Ct',
#             'Jade Ct',
#             'Jake Ct',
#             'Jasmine Ct',
#             'Jeffrey Ct',
#             'Jennifer Ct',
#             'Kacey Ct',
#             'Kathy Ct',
#             'Knights Ct',
#             'Knotts Ct',
#             'Lakeswan Ct',
#             'Landing Ct',
#             'Laurel Ct',
#             'Lee Ct',
#             'Leopard Ct',
#             'Linkside Ct',
#             'Little Creek Ct',
#             'Live Oak Ct',
#             'Louie Ct',
#             'Maple Ct',
#             'Maya Ct',
#             'Melody Ct',
#             'Middlebrook Ct',
#             'Mill Ct',
#             'Monticello Ct',
#             'Muirfield Ct',
#             'Musket Ct',
#             'Oak Bluff Ct',
#             'Oakside Ct',
#             'Oakwood Ct',
#             'Old Fincher Ct',
#             'Old Tassel Ct',
#             'Overhill Ct',
#             'Palm Ridge Ct',
#             'Papago Ct',
#             'Paxton Ct',
#             'Peardon Ct',
#             'Pheasant Ct',
#             'Pine Bluff Ct',
#             'Pine Ridge Ct',
#             'Pine Valley Ct',
#             'Plantation Ct',
#             'Plum Ct',
#             'Prince Ct',
#             'Queensbury Ct',
#             'Randy Ct',
#             'Red Fern Ct',
#             'Red Maple Ct',
#             'Ridge Ct',
#             'River Rock Ct',
#             'Riverlake Ct',
#             'Robin Nest Ct',
#             'Roscoe Collette Ct',
#             'Rose Ct',
#             'Sabrina Ct',
#             'Sandra Lynn Ct',
#             'Savannah Ct',
#             'Sequoyah Ct',
#             'Sharon Ct',
#             'Sherwood Ct',
#             'Silo View Ct',
#             'Silver Trace Ct',
#             'Spring Creek Ct',
#             'Spring New Ct',
#             'Stanford Falls Ct',
#             'Starboard Ct',
#             'Stockwood Ct',
#             'Stone Ct',
#             'Stratford Ct',
#             'Sturbridge Ct',
#             'Sunhill Ct',
#             'Sunnybrook Ct',
#             'Sussex Ct',
#             'Sweetwater Ct',
#             'Tall Oaks Ct',
#             'Tarragon Ct',
#             'Trevis Ct',
#             'Tucker Mill Ct',
#             'Tugaloo Ct',
#             'Turner Valley Ct',
#             'Unicoi Ct',
#             'Univeter Ct',
#             'Valley Ct',
#             'W Ridge Ct',
#             'W Wind Ct',
#             'Walnut Ct',
#             'Water Wheel Ct',
#             'Waterford Ct',
#             'Wellington Ct',
#             'Wentworth Ct',
#             'Wesley Ct',
#             'Westover Ct',
#             'Westview Ct',
#             'Westwind Ct',
#             'Whisper Wind Ct',
#             'Whispering Ct',
#             'Wild Magnolia Ct',
#             'Wildrose Ct',
#             'Wiley Bridge Ct',
#             'Williams Ct',
#             'Willow Ct',
#             'Windflower Ct',
#             'Windy Hills Ct',
#             'Winston Ct',
#             'Wood Knoll Ct',
#             'Woodberry Ct',
#             'Woodcliffe Ct',
#             'Woodmill Ct',
#             'Woodmont Ct',
#             'Woods Ct',
#             'Wrights Mill Ct']),
#  'Dale': set(['Farm Dale', 'London Dale']),
#  'Downs': set(['Barrow Downs', 'Devereux Downs']),
#  'Dr': set(['A W Roberts Dr',
#             'Abbott Dr',
#             'Acorn Tree Dr',
#             'Airport Dr',
#             'Allatoona Hill Dr',
#             'Allison Dr',
#             'Alma Dr',
#             'Amalfi Dr',
#             'Amanda Dr',
#             'Amber Dr',
#             'Amber Lake Dr',
#             'Ammons Dr',
#             'Ann Dr',
#             'Apache Dr',
#             'Appaloosa Dr',
#             'Apple Valley Dr',
#             'Arborhill Dr',
#             'Arliss Dr',
#             'Arnold Mooney Dr',
#             'Arrow Wood Dr',
#             'Arthur Dr',
#             'Ashlin Dr',
#             'Austin Dr',
#             'Authority Dr',
#             'Baldwin Dr',
#             'Battle Dr',
#             'Beauty Dr',
#             'Beaver Pond Dr',
#             'Beech Knoll Dr',
#             'Bent Creek Dr',
#             'Bentwater Dr',
#             'Berkshire Dr',
#             'Bessie Lusk Dr',
#             'Bethany Farms Dr',
#             'Bethel Dr',
#             'Beverly Dr',
#             'Big Woods Dr',
#             'Bill Bagwell Dr',
#             'Billings Dr',
#             'Birch Bend Dr',
#             'Bishop Dr',
#             'Blackhawk Dr',
#             'Blackwood Dr',
#             'Blake Dr',
#             'Blue Ridge Dr',
#             'Bluff Creek Dr',
#             'Bluff Dr',
#             'Bonnie Dr',
#             'Boone Dr',
#             'Bradshaw Estates Dr',
#             'Bramble Oak Dr',
#             'Braxton Dr',
#             'Briarcliff Dr',
#             'Bridge Station Dr',
#             'Brittany Dr',
#             'Brock Dr',
#             'Brook Forest Dr',
#             'Brook Hollow Dr',
#             'Brookridge Dr',
#             'Brookwood Dr',
#             'Brownlee Dr',
#             'Bunt Hickory Dr',
#             'Byrd Dr',
#             'Campbell Dr',
#             'Campground Dr',
#             'Canvas Back Dr',
#             'Cape Ivy Dr',
#             'Cardinal Dr',
#             'Carl Barrett Dr',
#             'Carmon Dr',
#             'Casablanca Dr',
#             'Castlewood Dr',
#             'Cedar Brook Dr',
#             'Cedar Dr',
#             'Cedar Ridge Dr',
#             'Cedar Valley Dr',
#             'Chastain Dr',
#             'Chattin Dr',
#             'Cherecobb Dr',
#             'Cherokee Dr',
#             'Cherokee Springs Dr',
#             'Cherokee Village Dr',
#             'Chickasaw Dr',
#             'Circle Dr',
#             'Clara Dr',
#             'Cliff Holcomb Dr',
#             'Cochise Dr',
#             'Colemans Bluff Dr',
#             'Colonial Dr',
#             'Colony Center Dr',
#             'Colony Dr',
#             'Colony Springs Dr',
#             'Coltrane Dr',
#             'Country Village Dr',
#             'Covington Dr',
#             'Cowart Dr',
#             'Creek Hollow Dr',
#             'Creekstone Dr',
#             'Crestview Dr',
#             'Crossroads Dr',
#             'Cypress Dr',
#             'Day Dr',
#             'Deanne Dr',
#             'Dearborn Dr',
#             'Deer Hollow Dr',
#             'Deerfield Dr',
#             'Dewberry Creek Dr',
#             'Dials Dr',
#             'Dillon Dr',
#             'Dixie Dr',
#             'Dogwood Dr',
#             'Dogwood Knoll Dr',
#             'Donbie Dr',
#             'Dons Dr',
#             'Dream Catcher Dr',
#             'Dudley Dr',
#             'Dundee Dr',
#             'Dunnwood Dr',
#             'E Cherokee Dr',
#             'E Paulding Dr',
#             'E Shore Dr',
#             'Eagle Dr',
#             'Eagle Glen Dr',
#             'Eagle Watch Dr',
#             'Echo Ridge Dr',
#             'Ellenwood Dr',
#             'Elmtree Dr',
#             'Emerald Pines Dr',
#             'Emmett Dr',
#             'Evans Mill Dr',
#             'Fairway Valley Dr',
#             'Falcon Pointe Dr',
#             'Farmington Dr',
#             'Faye Dr',
#             'Fernbank Dr',
#             'Fielding Grove Dr',
#             'Fields Landing Dr',
#             'Fields McGhee Dr',
#             'Floating Cabin Dr',
#             'Fort Wayne Dr',
#             'Fountain Dr',
#             'Fox Dr',
#             'Fred Bishop Dr',
#             'Garretts Dr',
#             'Gateway Dr',
#             'Gay Thompson Dr',
#             'Ghorley Dr',
#             'Gibbs Dr',
#             'Glendale Forest Dr',
#             'Glenell Dr',
#             'Glenmark Dr',
#             'Gold Nugget Dr',
#             'Golden Hills Dr',
#             'Golf Estates Dr',
#             'Gray Dr',
#             'Green Dr',
#             'Greys Mill Dr',
#             'Hagin Dr',
#             'Harbin Dr',
#             'Harlin Dr',
#             'Harmony Dr',
#             'Harris Dr',
#             'Hartwood Dr',
#             'Haygood Dr',
#             'Hazelwood Dr',
#             'Heard Dr',
#             'Hearthstone Dr',
#             'Heathland Dr',
#             'Hedgewood Dr',
#             'Hembree Hill Dr',
#             'Hester Dr',
#             'Hickory Cv Dr',
#             'Hickory Fairway Dr',
#             'Hickory Hills Dr',
#             'Hickory Knoll Dr',
#             'Highlands Dr',
#             'Hillcrest Dr',
#             'Hillside Dr',
#             'Honeydew Dr',
#             'Hunters Glen Dr',
#             'Imperial Dr',
#             'Indian Oak Dr',
#             'Indian Ridge Dr',
#             'Indian Trail Dr',
#             'Ivy Crest Dr',
#             'Ivy Terrace Dr',
#             'Jack Page Dr',
#             'Jade Dr',
#             'Jamie Dr',
#             'Jefferson Dr',
#             'Jenny Cohran Dr',
#             'Jessica Dr',
#             'John Wesley Dr',
#             'Justin Dr',
#             'Kelly Dr',
#             'Kemp Dr',
#             'Kensley Dr',
#             'King Arnold Dr',
#             'King Arthur Dr',
#             'King William Dr',
#             'Knotts Landing Dr',
#             'Knotts Point Dr',
#             'Kylemoor Dr',
#             'Lake Arrowhead Dr',
#             'Lake Capri Dr',
#             'Lake Circle Dr',
#             'Lake Mist Dr',
#             'Lake Overlook Dr',
#             'Lake Sorrento Dr',
#             'Lakeside Dr',
#             'Lakeview Dr',
#             'Lakewood Dr',
#             'Lambeth Dr',
#             'Laurel Hill Dr',
#             'Lawson Dr',
#             'Lee Dr',
#             'Legend Dr',
#             'Little Brook Dr',
#             'Lone Bear Dr',
#             'Longwood Dr',
#             'Lovingood Dr',
#             'Magnolia Dr',
#             'Malta Dr',
#             'Manassas Dr',
#             'Mauldin Dr',
#             'McBee Dr',
#             'McClure Dr',
#             'Meadows Dr',
#             'Merchants Dr',
#             'Mills Lk Dr',
#             'Mills Ridge Dr',
#             'Milton Dr',
#             'Misty Ridge Dr',
#             'Monterey Dr',
#             'Morningside Dr',
#             'Morningstar Dr',
#             'Morris Hill Dr',
#             'Mount Vernon Dr',
#             'Mountain View Dr',
#             'Musical Dr',
#             'Mustang Dr',
#             'N Etowah Dr',
#             'Nacoochee Dr',
#             'Nations Dr',
#             'Neese Dr',
#             'Norton Dr',
#             'Nottingham Dr',
#             'Oak Grove Dr',
#             'Oak Hills Dr',
#             'Oak Landing Dr',
#             'Oak Meadow Dr',
#             'Old Vandiver Dr',
#             'Overhill Dr',
#             'Palm Lake Dr',
#             'Park Creek Dr',
#             'Patty Dr',
#             'Paulding Meadows Dr',
#             'Pecan Dr',
#             'Picketts Ferry Dr',
#             'Pine Creek Dr',
#             'Pine Crest Dr',
#             'Pine Grove Dr',
#             'Pine Shadows Dr',
#             'Pine Valley Dr',
#             'Pinebrook Dr',
#             'Pineridge Dr',
#             'Pineview Dr',
#             'Pinewood Dr',
#             'Poinsetta Dr',
#             'Poole Dr',
#             'Presidential Dr',
#             'Pritchett Dr',
#             'Providence Dr',
#             'Putnam Ford Dr',
#             'Quarles Dr',
#             'Quarry Dr',
#             'Queensbury Dr',
#             'Rainbow Dr',
#             'Ranch Dr',
#             'Ray Dr',
#             'Revere Dr',
#             'Ridge Pine Dr',
#             'Ritchfield Dr',
#             'River Oaks Dr',
#             'River Plantation Dr',
#             'River Rock Dr',
#             'Riverchase Dr',
#             'Riverclift Dr',
#             'Rivercrest Dr',
#             'Riverlake Dr',
#             'Riverpoint Dr',
#             'Riverside Dr',
#             'Robin Hood Dr',
#             'Rock Creek Dr',
#             'Rocky Creek Farm Dr',
#             'Roland Dr',
#             'Rosedale Dr',
#             'Rosewood Dr',
#             'Rustin Dr',
#             'S Lake Dr',
#             'S McCollum Dr',
#             'Saddlewood Dr',
#             'Sadler Dr',
#             'Sanford Dr',
#             'Senators Ridge Dr',
#             'Sequoyah Dr',
#             'Settindown Dr',
#             'Shadowbrook Dr',
#             'Shane Dr',
#             'Shannon Dr',
#             'Sherwood Dr',
#             'Sims Dr',
#             'Sky Lark Dr',
#             'Smithwyck Dr',
#             'Snookey Dr',
#             'Southland Dr',
#             'Southwind Dr',
#             'Spring Leaf Dr',
#             'Spring Woods Dr',
#             'Springfield Dr',
#             'Springs Dr',
#             'Standridge Dr',
#             'Stella Dr',
#             'Sterling Dr',
#             'Stockwood Dr',
#             'Stone Edge Dr',
#             'Stoneforest Dr',
#             'Stoneybrook Dr',
#             'Stonybrook Dr',
#             'Summer Chase Dr',
#             'Summer Creek Dr',
#             'Summer Point Dr',
#             'Sunlight Dr',
#             'Sunset Dr',
#             'Surrey Dr',
#             'Suzie Creek Dr',
#             'Swan Dr',
#             'Sycamore Dr',
#             'Tall Oaks Dr',
#             'Tanglewood Dr',
#             'Tanner Dr',
#             'The Falls of Cherokee Dr',
#             'Thornwood Dr',
#             'Toms Dr',
#             'Torrington Dr',
#             'Tower Dr',
#             'Town Creek Dr',
#             'Towne Ridge Dr',
#             'Township Dr',
#             'Trade Winds Dr',
#             'Trailwood Dr',
#             'Trickum Valley Dr',
#             'Tulane Dr',
#             'Turnberry Dr',
#             'Valley Dr',
#             'Valleyhill Dr',
#             'Valleyside Dr',
#             'Vally Creek Dr',
#             'Victoria Landing Dr',
#             'Victory Dr',
#             'W Bramble Dr',
#             'W Elmwood Dr',
#             'W Hanger Dr',
#             'W Memorial Dr',
#             'Walnut Creek Dr',
#             'Walnut Dr',
#             'Watkins Glen Dr',
#             'Watson Dr',
#             'Weatherstone Dr',
#             'Wedgewood Dr',
#             'Weeping Willow Dr',
#             'Wellesley Crest Dr',
#             'Wentworth Dr',
#             'Wheeler Martin Dr',
#             'Whispering Pines Dr',
#             'Whispering Woods Dr',
#             'Whistle Stop Dr',
#             'White City Dr',
#             'White Eagle Dr',
#             'White Leaf Dr',
#             'White Pines Dr',
#             'Wiiliam Falls Dr',
#             'Wildwood Dr',
#             'Williams Dr',
#             'Willow Creek Dr',
#             'Willow Dr',
#             'Willow Tree Dr',
#             'Windfield Dr',
#             'Windsor Falls Dr',
#             'Winterville Dr',
#             'Wisteria Dr',
#             'Wolverine Dr',
#             'Wood Ridge Dr',
#             'Wood Valley Dr',
#             'Woodall Dr',
#             'Woodbridge Dr',
#             'Woodcreek Dr',
#             'Woodglen Dr',
#             'Woodvalley Dr',
#             'Woodwind Dr',
#             'Wooten Dr',
#             'Yacht Club Dr',
#             'York Dr']),
#  'E': set(['S Forty Pass E', 'Towne Lake Hill E', 'Village Green Cir E']),
#  'East': set(['Adena Lane East',
#               'Buford Drive North East',
#               'Buford Highway North East',
#               'Creekwood Crossing East',
#               'Cumming Highway North East',
#               'Mansell Court East',
#               'Morrison Moore Parkway East']),
#  'End': set(['Links End']),
#  'Entry': set(['Landing Entry']),
#  'Fairway': set(['Seventeenth Fairway']),
#  'Falls': set(['Watermill Falls']),
#  'Farm': set(['Pearls Farm']),
#  'Forge': set(['Carrington Forge']),
#  'GA)': set(['US 41 (GA)']),
#  'Gate': set(['Gentry Gate']),
#  'Glen': set(['Cheviot Glen',
#               'Iris Glen',
#               'Ivy Glen',
#               'Marne Glen',
#               'Wicksford Glen',
#               'Willshire Glen']),
#  'Glenn': set(['Watson Glenn']),
#  'Grove': set(['Guildhall Grove', 'Olde Roswell Grove']),
#  'Hallow': set(['Harris Hallow']),
#  'Heights': set(['Liberty Heights']),
#  'Highway': set(['Alpharetta Highway',
#                  'Atlanta Highway',
#                  'Braselton Highway',
#                  'Buchanan Highway',
#                  'Cumming Highway',
#                  'Dallas-Acworth Highway',
#                  'Marietta Highway',
#                  'Martha Berry Highway',
#                  'Mount Vernon Highway',
#                  'Old National Highway',
#                  'Roosevelt Highway',
#                  'West Bankhead Highway']),
#  'Hill': set(['Walton Hill', 'Wolfcreek Hill']),
#  'Hills': set(['South Hills']),
#  'Hollow': set(['Hedge Row Hollow',
#                 'Heights Hollow',
#                 'Hembree Hollow',
#                 'Hickory Oak Hollow',
#                 'Mill Creek Hollow',
#                 'Shaker Hollow',
#                 'Wickerberry Hollow']),
#  'Hts': set(['Dogwood Hts']),
#  'Hwy': set(['Atlanta Hwy',
#              'Ball Ground Hwy',
#              'Birmingham Hwy',
#              'Buchanan Hwy',
#              'Canton Hwy',
#              'Cartersville Hwy',
#              'Cumming Hwy',
#              'Dallas Acworth Hwy',
#              'Freehome Hwy',
#              'Hickory Flat Hwy',
#              'Hiram Acworth Hwy',
#              'Knox Bridge Hwy',
#              'Loganville Hwy',
#              'Marietta Hwy',
#              'McDonough Hwy',
#              'Rockmart Hwy',
#              'Scott Hwy',
#              'Stockbridge Hwy',
#              'Villa Rica Hwy']),
#  'Knoll': set(['Camden Knoll',
#                'Capitol Knoll',
#                'Liberty Knoll',
#                'Wickerberry Knoll']),
#  'Lakes': set(['Red Gate Lakes']),
#  'Land': set(['Far Emerald Land']),
#  'Landing': set(['Grogans Landing', 'Old Sandhurst Landing', 'The Landing']),
#  'Lismore': set(['Lismore']),
#  'Ln': set(['Abineton Ln',
#             'Addington Ln',
#             'Aldbury Ln',
#             'Alexandria Ln',
#             'Allison Ln',
#             'Amber Ln',
#             'Apple Orchard Ln',
#             'Arnold Ln',
#             'Arrow Wood Ln',
#             'Atherton Ln',
#             'Avondale Ln',
#             'Barrington Ln',
#             'Bates Ln',
#             'Betty Ln',
#             'Billy Ln',
#             'Blackberry Ln',
#             'Braddock Ln',
#             'Broken Arrow Ln',
#             'Brooks Ln',
#             'Brumby Ln',
#             'Buckeye Ln',
#             'Caboose Ln',
#             'Camden Ln',
#             'Cantrell Ln',
#             'Carpenter Ln',
#             'Cedar Mill Ln',
#             'Chamblee Ln',
#             'Chatsworth Ln',
#             'Chelsea Ln',
#             'Cherrydale Ln',
#             'Chipper Ln',
#             'Cloer Ln',
#             'Cloud Ln',
#             'Cottage Oaks Ln',
#             'Crocker Ln',
#             'Debbie Ln',
#             'Dewberry Ln',
#             'Donna Ln',
#             'Dora Ln',
#             'Doral Ln',
#             'Dorset Ln',
#             'Drake Ln',
#             'Duckett Ln',
#             'E Rope Mill Ln',
#             'Eagle Ridge Ln',
#             'Emerald Cove Ln',
#             'Emerald Pines Ln',
#             'Essen Ln',
#             'Estels Ln',
#             'Etowah Valley Ln',
#             'Faulkner Ln',
#             'Fieldgate Ln',
#             'Fox Ln',
#             'Free Ln',
#             'George Gray Ln',
#             'Gibbs Meyer Ln',
#             'Glory Ln',
#             'Gregory Ln',
#             'Hampton Ln',
#             'Hardman Ln',
#             'Harrison Ln',
#             'Hawkins Farm Ln',
#             'Hembree Hill Ln',
#             'Hendrix Ln',
#             'Hickory Ln',
#             'Hill Ln',
#             'Hobo Ln',
#             'Hollow Springs Ln',
#             'Holly Ln',
#             'Honeysuckle Ln',
#             'Hunters Mill Ln',
#             'Inca Ln',
#             'Jackie Moore Ln',
#             'Johnson Dupree Ln',
#             'Karen Ln',
#             'Kensington Ln',
#             'Kent Ln',
#             'Knollwood Ln',
#             'Linden Ln',
#             'Little Brook Ln',
#             'Live Oak Ln',
#             'London Ln',
#             'Love Ln',
#             'Lovejoy Ln',
#             'Lovelace Ln',
#             'Lynn Ln',
#             'Maplewood Ln',
#             'Marty Ln',
#             'Mary Ln',
#             'McCurry Ln',
#             'Meches Ln',
#             'Medical Ln',
#             'Melanie Ln',
#             'Melrose Ln',
#             'Mill Creek Ln',
#             'Missy Ln',
#             'Molly Ln',
#             'Moores Mill Ln',
#             'Moors Ln',
#             'Mount Carmel Church Ln',
#             'Nutmeg Ln',
#             'Oak Hill Ln',
#             'Oakhurst Ln',
#             'Old Deerfield Ln',
#             'Overlake Ln',
#             'Owens Store Ln',
#             'Paulding Ln',
#             'Pearidge Ln',
#             'Pebble Brook Ln',
#             'Pegasus Farm Ln',
#             'Penny Ln',
#             'Picketts Ridge Ln',
#             'Piedmont Ln',
#             'Pinecone Ln',
#             'Polk Ln',
#             'Ponderosa Ln',
#             'Prince Ln',
#             'Purcell Free Ln',
#             'Recreation Ln',
#             'Remington Ln',
#             'Ridge Tree Ln',
#             'Rockingham Ln',
#             'Rope Mill Ln',
#             'Rose Creek Ln',
#             'Rosewood Ln',
#             'Roy Mason Ln',
#             'Roy Puckett Ln',
#             'Russell King Ln',
#             'Russell Ln',
#             'S Cherokee Ln',
#             'Sam Harris Ln',
#             'Scarlett Ln',
#             'Settlement Ln',
#             'Settlers Ridge Ln',
#             'Shannon Ln',
#             'Sharp Mountain Church Ln',
#             'Shoe Maker Ln',
#             'Sierra Ln',
#             'Skyhawk Ln',
#             'Skyview Ln',
#             'Sleepy Hollow Ln',
#             'Sourwood Ln',
#             'Southshore Ln',
#             'Spice Garden Ln',
#             'Spicers Ln',
#             'Spruce Ln',
#             'Sumner Ln',
#             'Sunny Ln',
#             'Sunnybrook Ln',
#             'Sutallee Ridge Ln',
#             'Swan Ln',
#             'Tara Ln',
#             'Thompson Farm Ln',
#             'Thorntree Ln',
#             'Thornwood Ln',
#             'Tiffany Ln',
#             'Towne Harbor Ln',
#             'Tracey Ln',
#             'Travis Tritt Ln',
#             'Valley Farm Ln',
#             'Valley Vista Ln',
#             'Villa Estates Ln',
#             'Walden Ln',
#             'Warren Ln',
#             'Waters Lake Ln',
#             'Wayside Ln',
#             'White Stag Ln',
#             'Will Dupree Ln',
#             'William E Purcell Ln',
#             'Williambsurg Ln',
#             'Yellow Jacket Ln']),
#  'Loop': set(['Barrington Loop',
#               'Blue Fox Loop',
#               'Cedar Loop',
#               'Landers Loop',
#               'Morse Elm Loop',
#               'Mt Olivet Loop',
#               'Ravenwood Loop',
#               'Redtop Loop',
#               'Silver Fox Loop',
#               'Spoleto Loop',
#               'Thunder Hawk Loop',
#               'Valley Loop',
#               'Village Loop',
#               'Waverly Loop']),
#  'Mall': set(['Cedar Mall']),
#  'Manor': set(['Martin Falls Manor',
#                'Shallowford Park Manor',
#                'Worthington Hills Manor']),
#  'Meadow': set(['Breeze Meadow']),
#  'Ml': set(['Westland Ml']),
#  'Moor': set(['Marquess Moor']),
#  'N': set(['Towne Lake Hill N']),
#  'NE': set(['Bank St NE',
#             'Barn Oak Ct NE',
#             'Bedford Ln NE',
#             'Bethel Rd NE',
#             'Black Rd NE',
#             'Black Shoals Rd NE',
#             'Boar Tusk Rd NE',
#             'Brookview Dr NE',
#             'Carr Rd NE',
#             'Chandler Rd NE',
#             'Chelsea Downs Dr NE',
#             'Chelsea Downs Ln NE',
#             'Columbus St NE',
#             'Costley Mill Rd NE',
#             'Country Lane Dr NE',
#             'Country Lane Way NE',
#             'Cross St NE',
#             'Dennard Rd NE',
#             'Dial Mill Rd NE',
#             'E Park Dr NE',
#             'Eastview Rd NE',
#             'Eastview Way NE',
#             'Fairhaven Cove NE',
#             'Fern Creek Ter NE',
#             'Fern Ridge West Dr NE',
#             'Forest Ln NE',
#             'Gees Mill Business Ct NE',
#             'Gees Mill Business Pkwy NE',
#             'Gees Mill Rd NE',
#             'Glen Rd NE',
#             'Glendale Dr NE',
#             'Granite Dr NE',
#             'Green St NE',
#             'Greenhill Dr NE',
#             'Haynes Creek Dr NE',
#             'Hi Roc Cir NE',
#             'Hill Lake Dr NE',
#             'Inman Village Pkwy NE',
#             'Jackie Ct NE',
#             'Keswick Village Ct NE',
#             'Lake Trl NE',
#             'Lakeshore Dr NE',
#             'Laurel Ln NE',
#             'Leafway Trl NE',
#             'Legion Rd NE',
#             'Lietch Ln NE',
#             'Lizinda Cir NE',
#             'Locust Dr NE',
#             'Main St NE',
#             'McCart Rd NE',
#             'Melody Ridge Ct NE',
#             'Milstead Ave NE',
#             'Milstead Rd NE',
#             'Mountain Dr NE',
#             'N Salem Rd NE',
#             'N Tower Way NE',
#             'Nantucket Cove NE',
#             'New St NE',
#             'Oak St NE',
#             'Old Church Cove NE',
#             'Old Covington Rd NE',
#             'Old Ivy Square NE',
#             'Olde Mill Dr NE',
#             'Park Pl NE',
#             'Parker Dr NE',
#             'Picadilly Ct NE',
#             'Pine Knoll Cir NE',
#             'Pine Knoll Ln NE',
#             'Pine Logging Rd NE',
#             'Pine St NE',
#             'Pinetree Ln NE',
#             'Randolph Ct NE',
#             'Revere Cove NE',
#             'Richard Rd NE',
#             'River Cir NE',
#             'Riverside Ct NE',
#             'Riverside Trl NE',
#             'Robin Rd NE',
#             'Rock View Ln NE',
#             'Rockmill Ln NE',
#             'Roswell Road NE',
#             'S Pine St NE',
#             'Scheaffer Rd NE',
#             'Shore Wood Ct NE',
#             'Sigman Rd NE',
#             'Smith Cir NE',
#             'Spring St NE',
#             'Sutallee Ridge Ct NE',
#             'Sutallee Woods Trl NE',
#             'Tinie Evans Rd NE',
#             'Valley Dr NE',
#             'White Rd NE',
#             'Zingara Rd NE']),
#  'NW': set(['Almand Rd NW',
#             'Armour Dr NW',
#             'Ashley Forest Dr NW',
#             'Barton St NW',
#             'Betty Ct NW',
#             'Bonds Lake Rd NW',
#             'Cooper Cir NW',
#             'Doeskin Dr NW',
#             'Elcar Way NW',
#             'Enchanted Lake Ct NW',
#             'Enchanted Lake Dr NW',
#             'Farmer Rd NW',
#             'Forest Villa Dr NW',
#             'Frontier Dr NW',
#             'Green Valley Dr NW',
#             'Humphries Rd NW',
#             'Industrial Blvd NW',
#             'Institute St NW',
#             'Irwin Bridge Rd NW',
#             'James Ct NW',
#             'Jimi Ln NW',
#             'John Tate Rd NW',
#             'Lake Capri Rd NW',
#             'Lake Rockaway Rd NW',
#             'Lakeview Dr NW',
#             'Landola Dr NW',
#             'Lester Rd NW',
#             'Lindy Ct NW',
#             'Little Fawn Trl NW',
#             'Magnolia Dr NW',
#             'Main St NW',
#             'Marlette Dr NW',
#             'Millcrest Walk NW',
#             'Mink Livey Rd NW',
#             'Mountain View Cir NW',
#             'Mountain View Rd NW',
#             'Nancy Ct NW',
#             'Northside Dr NW',
#             'Oak Ct NW',
#             'Oak Dr NW',
#             'Oak Villas Ct NW',
#             'Old Camp Trl NW',
#             'Paces Landing Dr NW',
#             'Peek St NW',
#             'Pinelake Dr NW',
#             'Pleasant Hill Rd NW',
#             'Plunkett Rd NW',
#             'Presidential Cir NW',
#             'Railroad St NW',
#             'Rambling Rose Ct NW',
#             'Rangewood Dr NW',
#             'Rockaway Industrial Blvd NW',
#             'S Hicks Cir NW',
#             'S Lakeshore Dr NW',
#             'Shephard Ct NW',
#             'Sigman East Dr NW',
#             'Sigman Rd NW',
#             'Skyline Dr NW',
#             'Springwood Dr NW',
#             'Star Dr NW',
#             'Summer Cir NW',
#             'Tillman St NW',
#             'Upland Ridge Dr NW',
#             'Willow Creek Ct NW',
#             'Woodstock Rd NW']),
#  'North': set(['Cobb Parkway North',
#                'Muscadine Court North',
#                'Picardy Circle North']),
#  'Northeast': set(['10th Street Northeast',
#                    '11th Street Northeast',
#                    '12th Street Northeast',
#                    '13th Street Northeast',
#                    '14th Street Northeast',
#                    '15th Street Northeast',
#                    '16th Street Northeast',
#                    '17th Street Northeast',
#                    '3rd Street Northeast',
#                    '4th Street Northeast',
#                    '5th Street Northeast',
#                    '6th Street Northeast',
#                    '7th Street Northeast',
#                    '8th Street Northeast',
#                    '9th Street Northeast',
#                    'Aberdeen Drive Northeast',
#                    'Abington Drive Northeast',
#                    'Acorn Avenue Northeast',
#                    'Adair Avenue Northeast',
#                    'Adina Drive Northeast',
#                    'Alberta Drive Northeast',
#                    'Alco Street Northeast',
#                    'Aldwych Lane Northeast',
#                    'Allen Road Northeast',
#                    'Allgood Road Northeast',
#                    'Allison Drive Northeast',
#                    'Alpine Road Northeast',
#                    'Alta Avenue Northeast',
#                    'Amherst Court Northeast',
#                    'Amsterdam Avenue Northeast',
#                    'Angelo Court Northeast',
#                    'Angelo Drive Northeast',
#                    'Angier Avenue Northeast',
#                    'Angier Place Northeast',
#                    'Angus Trail Northeast',
#                    'Ansley Drive Northeast',
#                    'Arden Way Northeast',
#                    'Argonne Avenue Northeast',
#                    'Arlene Way Northeast',
#                    'Arlington Avenue Northeast',
#                    'Arlington Place Northeast',
#                    'Armand Court Northeast',
#                    'Armand Road Northeast',
#                    'Armour Drive Northeast',
#                    'Arnold Street Northeast',
#                    'Ashebrooke Drive Northeast',
#                    'Ashford Dunwoody Road Northeast',
#                    'Ashland Avenue Northeast',
#                    'Ashley Avenue Northeast',
#                    'Atwood Road Northeast',
#                    'Auburn Avenue Northeast',
#                    'Austin Avenue Northeast',
#                    'Avalon Place Northeast',
#                    'Avery Drive Northeast',
#                    'Baker Street Northeast',
#                    'Balmoral Road Northeast',
#                    'Barclay Place Northeast',
#                    'Barfield Road Northeast',
#                    'Barksdale Drive Northeast',
#                    'Barnett Street Northeast',
#                    'Baroque Circle Northeast',
#                    'Battery Place Northeast',
#                    'Beachland Drive Northeast',
#                    'Beech Valley Road Northeast',
#                    'Belgrade Avenue Northeast',
#                    'Bellaire Drive Northeast',
#                    'Bellevue Drive Northeast',
#                    'Benning Place Northeast',
#                    'Benton Woods Drive Northeast',
#                    'Berkshire Road Northeast',
#                    'Berwick Avenue Northeast',
#                    'Berwick Drive Northeast',
#                    'Beverly Road Northeast',
#                    'Birchwood Drive Northeast',
#                    'Blue Ridge Avenue Northeast',
#                    'Bolling Road Northeast',
#                    'Bonaventure Avenue Northeast',
#                    'Bonnie Lane Northeast',
#                    'Bonview Lane Northeast',
#                    'Boulevard Place Northeast',
#                    'Boylston Drive Northeast',
#                    'Brackenwood Circle Northeast',
#                    'Bradley Street Northeast',
#                    'Brandon Place Northeast',
#                    'Brandon Ridge Drive Northeast',
#                    'Bransford Road Northeast',
#                    'Brentwood Drive Northeast',
#                    'Brentwood Terrace Northeast',
#                    'Brewer Way Northeast',
#                    'Briarcliff Court Northeast',
#                    'Briarcliff Place Northeast',
#                    'Bridges Creek Trail Northeast',
#                    'Brighton Road Northeast',
#                    'Brinkley Lane Northeast',
#                    'Brixham Court Northeast',
#                    'Brook Drive Northeast',
#                    'Brookfield Drive Northeast',
#                    'Brookgreen Road Northeast',
#                    'Brookhaven Springs Court Northeast',
#                    'Brookridge Drive Northeast',
#                    'Brookwood Drive Northeast',
#                    'Bruton Way Northeast',
#                    'Buckhead Avenue Northeast',
#                    'Buckhead Trace Northeast',
#                    'Buford Highway Northeast',
#                    'Burke Road Northeast',
#                    'Calhoun Road Northeast',
#                    'Calvert Lane Northeast',
#                    'Cambridge Way Northeast',
#                    'Camden Park Court Northeast',
#                    'Camden Road Northeast',
#                    'Candler Park Drive Northeast',
#                    'Candler Street Northeast',
#                    'Canter Road Northeast',
#                    'Cantrell Road Northeast',
#                    'Cardova Drive Northeast',
#                    'Carlisle Court Northeast',
#                    'Carlton Drive Northeast',
#                    'Carlton Ridge Northeast',
#                    'Carmain Drive Northeast',
#                    'Carmel Avenue Northeast',
#                    'Caroline Street Northeast',
#                    'Carolwood Lane Northeast',
#                    'Carpenter Drive Northeast',
#                    'Carriage Drive Northeast',
#                    'Carter Drive Northeast',
#                    'Castleridge Drive Northeast',
#                    'Catina Court Northeast',
#                    'Chadds Lake Drive Northeast',
#                    'Charles Allen Drive Northeast',
#                    'Charline Avenue Northeast',
#                    'Chaseland Road Northeast',
#                    'Chastain Park Court Northeast',
#                    'Chateaugay Lane Northeast',
#                    'Chelsea Park Drive Northeast',
#                    'Chemin de Vie Northeast',
#                    'Cherry Tree Lane Northeast',
#                    'Cherrywood Lane Northeast',
#                    'Childers Pond Overlook Northeast',
#                    'Chipley Street Northeast',
#                    'Churchill Downs Road Northeast',
#                    'Cleburne Avenue Northeast',
#                    'Clementstone Drive Northeast',
#                    'Clemont Drive Northeast',
#                    'Cliftwood Drive Northeast',
#                    'Club Circle Northeast',
#                    'Club Drive Northeast',
#                    'Clubland Drive Northeast',
#                    'Cole Street Northeast',
#                    'Colquitt Avenue Northeast',
#                    'Colton Drive Northeast',
#                    'Conifer Circle Northeast',
#                    'Cooledge Avenue Northeast',
#                    'Corley Street Northeast',
#                    'Courtenay Court Northeast',
#                    'Courtenay Drive Northeast',
#                    'Courtland Street Northeast',
#                    'Craighead Drive Northeast',
#                    'Crane Road Northeast',
#                    'Crescent Avenue Northeast',
#                    'Cresthill Avenue Northeast',
#                    'Crestridge Drive Northeast',
#                    'Crestwicke Pointe Northeast',
#                    'Cromwell Road Northeast',
#                    'Cumberland Circle Northeast',
#                    'Cumberland Road Northeast',
#                    'Dale Drive Northeast',
#                    'Dalmer Road Northeast',
#                    'Dalrymple Road Northeast',
#                    'Darlington Circle Northeast',
#                    'Darlington Road Northeast',
#                    'Dekalb Avenue Northeast',
#                    'Delmont Drive Northeast',
#                    'Delta Place Northeast',
#                    'Devonwood Drive Northeast',
#                    'Dickson Place Northeast',
#                    'Dixie Avenue Northeast',
#                    'Dogwood Valley Drive Northeast',
#                    'Doncaster Drive Northeast',
#                    'Drewry Street Northeast',
#                    'Druid Circle Northeast',
#                    'Druid Valley Drive Northeast',
#                    'Drummen Court Northeast',
#                    'Duncourtney Drive Northeast',
#                    'Dunhill Court Northeast',
#                    'Dunhill Terrace Northeast',
#                    'Dunwoody Springs Drive Northeast',
#                    'Durant Place Northeast',
#                    'Earlston Drive Northeast',
#                    'East Avenue Northeast',
#                    'East Belle Isle Road Northeast',
#                    'East Club Lane Northeast',
#                    'East Drive Northeast',
#                    'East Morningside Drive Northeast',
#                    'East Northway Lane Northeast',
#                    'East Paces Ferry Road Northeast',
#                    'East Pelham Road Northeast',
#                    'East Powderhorn Road Northeast',
#                    'East Rock Springs Road Northeast',
#                    'East Shadowlawn Avenue Northeast',
#                    'Edgewood Avenue Northeast',
#                    'Edison Avenue Northeast',
#                    'Elden Drive Northeast',
#                    'Elizabeth Ann Lane Northeast',
#                    'Elizabeth Street Northeast',
#                    'Elkmont Drive Northeast',
#                    'Elliott Circle Northeast',
#                    'Ellis Street Northeast',
#                    'Ellwood Drive Northeast',
#                    'Elmira Place Northeast',
#                    'Elmwood Drive Northeast',
#                    'Emma Lane Northeast',
#                    'Euclid Avenue Northeast',
#                    'Euclid Terrace Northeast',
#                    'Eulalia Road Northeast',
#                    'Eureka Drive Northeast',
#                    'Fairhaven Circle Northeast',
#                    'Fairview Road Northeast',
#                    'Fairville Court Northeast',
#                    'Falcon Chase Lane Northeast',
#                    'Faulkner Road Northeast',
#                    'Felton Drive Northeast',
#                    'Fenwick Place Northeast',
#                    'Ferguson Street Northeast',
#                    'Ferncliff Place Northeast',
#                    'Ferncliff Road Northeast',
#                    'Ferry Drive Northeast',
#                    'Flagler Avenue Northeast',
#                    'Flora Avenue Northeast',
#                    'Floyd Street Northeast',
#                    'Fordham Court Northeast',
#                    'Forest Hills Drive Northeast',
#                    'Forest Valley Road Northeast',
#                    'Forestdale Drive Northeast',
#                    'Forrest Way Northeast',
#                    'Fortune Street Northeast',
#                    'Fowler Circle Northeast',
#                    'Franklin Road Northeast',
#                    'Frederica Street Northeast',
#                    'Friar Tuck Road Northeast',
#                    'Garber Drive Northeast',
#                    'Glen Arden Way Northeast',
#                    'Glen Iris Drive Northeast',
#                    'Glenairy Drive Northeast',
#                    'Glencourtney Drive Northeast',
#                    'Glendale Terrace Northeast',
#                    'Glenforest Road Northeast',
#                    'Glengary Court Northeast',
#                    'Glengary Drive Northeast',
#                    'Glenivy Northeast',
#                    'Glenlake Parkway Northeast',
#                    'Glenridge Close Drive Northeast',
#                    'Glenridge Drive Northeast',
#                    'Glenwood Drive Northeast',
#                    'Golf Circle Northeast',
#                    'Goodwin Road Northeast',
#                    'Gotham Way Northeast',
# ...
#                    'Skyview Drive Southwest',
#                    'Smith Street Southwest',
#                    'Somerset Trail Southwest',
#                    'Sorrento Circle Southwest',
#                    'South Alvarado Terrace Southwest',
#                    'South Gordon Street Southwest',
#                    'South Marietta Parkway Southwest',
#                    'South Olympian Way Southwest',
#                    'Sparks Street Southwest',
#                    'Spreading Oak Drive Southwest',
#                    'Spring Garden Drive Southwest',
#                    'Spring Street Southwest',
#                    'Springdale Circle Southwest',
#                    'Springdale Place Southwest',
#                    'Springdale Road Southwest',
#                    'Stafford Street Southwest',
#                    'Stamford Road Southwest',
#                    'Star Mist Drive Southwest',
#                    'Stephanie Drive Southwest',
#                    'Stephens Street Southwest',
#                    'Steve Drive Southwest',
#                    'Stokes Avenue Southwest',
#                    'Stone Road Southwest',
#                    'Stonecastle Pass Southwest',
#                    'Stoneleigh Drive Southwest',
#                    'Stonemeade Court Southwest',
#                    'Summit Parkway Southwest',
#                    'Susan Lane Southwest',
#                    'Suttles Drive Southwest',
#                    'Sylvan Circle Southwest',
#                    'Sylvan Place Southwest',
#                    'Sylvan Ridge Drive Southwest',
#                    'Taft Street Southwest',
#                    'Tallon Lane Southwest',
#                    'Tarragon Way Southwest',
#                    'Tartan Lane Southwest',
#                    'Tee Road Southwest',
#                    'Tejas Trail Southwest',
#                    'Telfair Lane Southwest',
#                    'Telhurst Street Southwest',
#                    'Tell Road Southwest',
#                    'Tennessee Avenue Southwest',
#                    'Thackeray Place Southwest',
#                    'Thaxton Road Southwest',
#                    'Thornton Place Southwest',
#                    'Thurgood Street Southwest',
#                    'Tift Avenue Southwest',
#                    'Timbergrove Drive Southwest',
#                    'Timothy Drive Southwest',
#                    'Toll House Lane Southwest',
#                    'Topaz Lane Southwest',
#                    'Treadwell Circle Southwest',
#                    'Trellis Oaks Court Southwest',
#                    'Trellis Oaks Drive Southwest',
#                    'Trenholm Street Southwest',
#                    'Trinity Avenue Southwest',
#                    'Trusco Way Southwest',
#                    'Tuckawanna Drive Southwest',
#                    'Tucker Place Southwest',
#                    'Tucson Trail Southwest',
#                    'Tulane Drive Southwest',
#                    'Twin Tendrils Southwest',
#                    'Union Road Southwest',
#                    'Upshaw Street Southwest',
#                    'Utoy Circle Southwest',
#                    'Utoy Court Southwest',
#                    'Valley Ridge Drive Southwest',
#                    'Valley Ridge Terrace Southwest',
#                    'Valleydale Drive Southwest',
#                    'Veltre Circle Southwest',
#                    'Veltre Place Southwest',
#                    'Venetian Drive Southwest',
#                    'Victoria Place Southwest',
#                    'Victory Drive Southwest',
#                    'Village Drive Southwest',
#                    'Vine Street Southwest',
#                    'Vinson Place Southwest',
#                    'Waits Avenue Southwest',
#                    'Waits Drive Southwest',
#                    'Walker Street Southwest',
#                    'Wallace Avenue Southwest',
#                    'Wallace Road Southwest',
#                    'Walnut Street Southwest',
#                    'Wanda Circle Southwest',
#                    'Ward Drive Southwest',
#                    'Washington Place Southwest',
#                    'Washington Street Southwest',
#                    'Waterfront Drive Southwest',
#                    'Welch Street Southwest',
#                    'Wellington Street Southwest',
#                    'Wells Drive Southwest',
#                    'Wells Street Southwest',
#                    'Wendell Drive Southwest',
#                    'West Avenue Southwest',
#                    'West End Avenue Southwest',
#                    'West End Place Southwest',
#                    'West Fair Street Southwest',
#                    'West Kimberly Road Southwest',
#                    'West Manor Circle Southwest',
#                    'West Manor Lane Southwest',
#                    'West Ontario Avenue Southwest',
#                    'Westboro Drive Southwest',
#                    'Westgate Parkway Southwest',
#                    'Westhaven Drive Southwest',
#                    'Westmeath Drive Southwest',
#                    'Westmont Road Southwest',
#                    'Westridge Road Southwest',
#                    'Westview Drive Southwest',
#                    'Westview Place Southwest',
#                    'Westwood Avenue Southwest',
#                    'Weyman Avenue Southwest',
#                    'Wharton Circle Southwest',
#                    'Wharton Drive Southwest',
#                    'Wheaton Drive Southwest',
#                    'White Street Southwest',
#                    'Whitehall Street Southwest',
#                    'Whitehall Terrace Southwest',
#                    'Whitworth Drive Southwest',
#                    'Wichita Drive Southwest',
#                    'Wildwood Lake Drive Southwest',
#                    'Willard Avenue Southwest',
#                    'Willis Mill Road Southwest',
#                    'Willow Cove Way Southwest',
#                    'Willow Trail Southwest',
#                    'Willowbrook Drive Southwest',
#                    'Willowood Lane Southwest',
#                    'Wilmington Avenue Southwest',
#                    'Wilson Drive Southwest',
#                    'Wilson James Road Southwest',
#                    'Wilson Mill Road Southwest',
#                    'Windhaven Trail Southwest',
#                    'Windsor Drive Southwest',
#                    'Windsor Street Southwest',
#                    'Wingate Street Southwest',
#                    'Wisteria Lane Southwest',
#                    'Wolf Creek Circle Southwest',
#                    'Woodbourne Drive Southwest',
#                    'Woodland Terrace Southwest',
#                    'Woodrow Street Southwest',
#                    'Woodside Drive Southwest',
#                    'Woodstock Drive Southwest',
#                    'Wyland Drive Southwest',
#                    'Wynns Way Southwest',
#                    'Wynnwood Drive Southwest',
#                    'Yale Place Southwest',
#                    'Zane Drive Southwest']),
#  'Sq': set(['Park Sq', 'Scully Sq']),
#  'St': set(['Alex St',
#             'Archer St',
#             'Baldwin St',
#             'Barry St',
#             'Birch St',
#             'Blackwell St',
#             'Braswell St',
#             'Brooks St',
#             'Brown St',
#             'Byers St',
#             'Canton St',
#             'Cartersville St',
#             'Center St',
#             'Chestnut St',
#             'Church St',
#             'Coker St',
#             'Creekmore St',
#             'Crisler St',
#             'Dupree St',
#             'Durham St',
#             'E Broad St',
#             'E Main St',
#             'E Spring St',
#             'Elizabeth St',
#             'Elm St',
#             'Field St',
#             'Fitzgerald St',
#             'Fowler St',
#             'Fulton St',
#             'Hamilton St',
#             'Hickory St',
#             'Holly St',
#             'Hughes St',
#             'Ivy St',
#             'Jarvis St',
#             'Jeannette St',
#             'Joseph St',
#             'Juniper St',
#             'Lee St',
#             'Linton St',
#             'Lowry St',
#             'Lucky St',
#             'Luke St',
#             'Main St',
#             'McClure St',
#             'McLain St',
#             'Michael St',
#             'Mill St',
#             'Muriel St',
#             'N Johnston St',
#             'North St',
#             'Palm St',
#             'Park St',
#             'Pawnee St',
#             'Pine St',
#             'Ragsdale St',
#             'Rusk St',
#             'S Johnston St',
#             'Shipp St',
#             'Short St',
#             'Short Tanyard St',
#             'Shotwell St',
#             'South St',
#             'St Ann St',
#             'Terrell St',
#             'Timberland St',
#             'Toulouse St',
#             'Valley St',
#             'W Main St',
#             'W Marietta St',
#             'Waleska St',
#             'Westview St',
#             'White Antelope St',
#             'Woodland St']),
#  'Station': set(['Old Sandhurst Station', 'Victoria Station']),
#  'Steeplechase': set(['Steeplechase']),
#  'Strip': set(['Sunset Strip']),
#  'Tarn': set(['Misty Lake Tarn', 'Willow Tarn']),
#  'Ter': set(['Bridgewater Ter',
#              'Honeysuckle Ter',
#              'Lakeview Ter',
#              'Park Ter',
#              'River Run Ter',
#              'Spring Ridge Ter',
#              'Summer Ter',
#              'Villa Ridge Ter',
#              'Woodglen Ter']),
#  'Terrace': set(['Avalon Terrace',
#                  'Carlton Pointe Terrace',
#                  'Carobet Terrace',
#                  'Clear Creek Terrace',
#                  'Clubside Terrace',
#                  'Dabney Terrace',
#                  'Delmont Terrace',
#                  'Fallview Terrace',
#                  'Fripp Terrace',
#                  'Headland Terrace',
#                  'Huntcliff Terrace',
#                  'Jefferson Terrace',
#                  'Knoll Terrace',
#                  'Knoll Woods Terrace',
#                  'McAlpin Terrace',
#                  'Oak Park Terrace',
#                  'Orly Terrace',
#                  'Park Terrace',
#                  'Parkside Terrace',
#                  'Raymond Terrace',
#                  'Rugby Terrace',
#                  'Scenic Terrace',
#                  'Spring Hill Terrace',
#                  'Springlake Terrace',
#                  'Stoneview Terrace',
#                  'Sylvan Terrace',
#                  'Valante Terrace',
#                  'Vesta Terrace',
#                  'Walnut Terrace',
#                  'Waterbrook Terrace',
#                  'Weldstone Terrace',
#                  'Wentworth Terrace',
#                  'Winburn Terrace']),
#  'Tier': set(['Maplewood Tier']),
#  'Trace': set(['Aubusson Trace',
#                'Boulder Trace',
#                'Bridle Ridge Trace',
#                'Camber Trace',
#                'Cedar Trace',
#                'Club Walk Trace',
#                'Derby Ridge Trace',
#                'Fall Creek Trace',
#                'Farm Grove Trace',
#                'Grassy Trace',
#                'Greenvine Trace',
#                'Greenwood Trace',
#                'Huntcliff Trace',
#                'Lakes Trace',
#                'Liberty Trace',
#                'Marshwood Trace',
#                'Meadow Trace',
#                'Meadowsweet Trace',
#                'Mica Trace',
#                'Mistwater Trace',
#                'Mountain Trace',
#                'Newgold Trace',
#                'North Hickory Trace',
#                'Northcliff Trace',
#                'Northgate Trace',
#                'Northpointe Trace',
#                'Old Oak Trace',
#                'Old Tree Trace',
#                'Parkmont Trace',
#                'Pine Glade Trace',
#                'Rebecca Lake Trace',
#                'Rippling Brook Trace',
#                'River Trace',
#                'Saddle Ridge Trace',
#                'Shady River Trace',
#                'Slane Trace',
#                'Spender Trace',
#                'Spring Ridge Trace',
#                'Stonemist Trace',
#                'Swan Trace',
#                'Sweetwater Trace',
#                'Truehedge Trace',
#                'Village Trace',
#                'Waverly Trace',
#                'Welford Trace',
#                'Windflower Trace',
#                'Wood Valley Trace',
#                'Wynland Trace']),
#  'Track': set(['Farm Track', 'Junction Track']),
#  'Trce': set(['Bethany Trce',
#               'Blue Ridge Trce',
#               'Enfield Trce',
#               'Hunters Trce',
#               'Jonathan Trce',
#               'Lakeshire Trce',
#               'Magnolia Springs Trce',
#               'Magnolia Trce',
#               'Mill Trce',
#               'Mountain Trce',
#               'Olde Mill Trce',
#               'Paces Lakes Trce',
#               "Pickett's Trce",
#               'Plantation Trce',
#               'Springwater Trce',
#               'Starlyn Trce',
#               'Timber Trce',
#               'Victoria Trce',
#               'Wind Song Trce']),
#  'Trl': set(['Allatoona Trl',
#              'Apache Trl',
#              'Bennett Farms Trl',
#              'Bentwood Trl',
#              'Bethesda Trl',
#              'Bishop Trl',
#              'Bobwhite Trl',
#              'Broomall Trl',
#              'Chase Trl',
#              'Cherokee Gold Trl',
#              'Cherokee Trl',
#              'Clearview Trl',
#              'Clearwater Trl',
#              'Cool Springs Trl',
#              'Crabapple Trl',
#              'Cross Trl',
#              'Dunhill Trl',
#              'E Hightower Trl',
#              'Fawn Trl',
#              'Flatbottom Trl',
#              'Garrison Trl',
#              'Glenn Wilkie Trl',
#              'Godfrey Trl',
#              'Hasty Trl',
#              'Hickory Trl',
#              'Hidden Branches Trl',
#              'Hightower Trl',
#              'Indian Trl',
#              'Jade Trl',
#              'Knox Campground Trl',
#              'Kraft Trl',
#              'Lakeview Trl',
#              'Lakewood Trl',
#              'Lula Payne Trl',
#              'Misty Ridge Trl',
#              'Murphy Trl',
#              'New Mill Trl',
#              'Old Blackberry Trl',
#              'Old Fincher Trl',
#              'Old Magnolia Trl',
#              'Old Pioneer Trl',
#              'Old Shoal Creek Trl',
#              'Old Virginia Trl',
#              'Overlook Trl',
#              'Pine Trl',
#              'Pioneer Trl',
#              'Ponderosa Trl',
#              'Rampley Trl',
#              'Saddle Creek Trl',
#              'Shady Trl',
#              'Shagbark Trl',
#              'Streamview Trl',
#              'Tippens Trl',
#              'Upper Sweetwater Trl',
#              'Vicksburg Trl',
#              'Vintage Trl',
#              'W Hightower Trl',
#              'W Point Trl',
#              'Wabash Trl',
#              'Wild Azalea Trl',
#              'Wilkie Trl',
#              'Wilzman Trl',
#              'Winding Woods Trl',
#              'Windstone Trl']),
#  'Troon': set(['Royal Troon']),
#  'Turn': set(['Cedar Turn', 'Gable Gate Turn', 'Revere Turn']),
#  'Valley': set(['Ridge Valley', 'Wildwood Valley']),
#  'View': set(['Babbling View',
#               'Bluegrass View',
#               'Highland Lake View',
#               'Olmadison View',
#               'Wolfcreek View']),
#  'Vine': set(['Hope Vine']),
#  'Vw': set(['Chadds Vw', 'Peaceful Vw']),
#  'W': set(['Park Ave W']),
#  'Walk': set(['Colemans Walk',
#               'Cool Springs Walk',
#               'Crescent Walk',
#               'Cresthaven Walk',
#               'Crosswinds Walk',
#               'Greenmont Walk',
#               'Kenley Walk',
#               'Magnolia Walk',
#               'Providence Walk',
#               'River Walk',
#               'Shoreline Walk',
#               'Sparrow Walk',
#               'Vestry Walk',
#               'Waverly Walk']),
#  'West': set(['Adena Lane West', 'Creekwood Crossing West']),
#  'Wood': set(['Stradford Wood']),
#  'Woods': set(['Merriweather Woods']),
#  'Xing': set(['Cedar Mill Xing',
#               'Foxfire Xing',
#               'Highpoint Xing',
#               'Hunters Xing',
#               'Settlers Xing',
#               'Springdale Xing',
#               'Vinson Mountain Xing',
#               'Woodruff Xing']),
#  'circle': set(['Wrotham circle']),
#  'lane': set(['Lava lane'])}

# %%
st_types = audit_2(osmfile)
pprint.pprint(dict(st_types))
# Out:
# {'101': set(['State Rte 101']),
#  '138': set(['State Rte 138']),
#  '140': set(['S R 140']),
#  '20': set(['State Rte 20']),
#  '212': set(['State Rte 212']),
#  '30360': set(['The Nalley Way, Atlanta, GA 30360']),
#  '330': set(['Highway 330']),
#  '41': set(['US 41']),
#  '5': set(['Old Hwy 5']),
#  '526': set(['526']),
#  '53': set(['GA 53']),
#  '575': set(['Parkway 575']),
#  '710': set(['Dallas Hwy. SW #710']),
#  '78': set(['Highway 78']),
#  '995': set(['Peachtree Street Northwest #995']),
#  'Alley': set(['Hidden Alley']),
#  'Apartment': set(['Woodland Apartment']),
#  'Approach': set(['Inverness Approach']),
#  'Ave': set(['2nd Ave',
#              'Bridge Mill Ave',
#              'Capital Ave',
#              'Confederate Ave',
#              'E Foster Ave',
#              'E Ponce de Leon Ave',
#              'Gail Ave',
#              'Georgia Ave',
#              'Highland Ave',
#              'Lexington Ave',
#              'Lyons Ave',
#              'North Ave',
#              'Park Ave',
#              'Polk Ave',
#              'Rolling Hills Ave',
#              'Seaboard Ave',
#              'Spring Meadows Ave',
#              'St Charles Ave',
#              'States Ave',
#              'Stations Ave',
#              'The General Ave',
#              'Transit Ave',
#              'W Cooper Ave',
#              'W Foster Ave',
#              'Wabash Ave',
#              'Waconda Ave',
#              'Washington Ave',
#              'West Ave',
#              'Womack Ave']),
#  'BLF': set(['Royal BLF']),
#  'Bend': set(['Glade Bend',
#               'Horsehoe Bend',
#               'Marsh Rabbit Bend',
#               'Overlook Bend',
#               'Parkland Bend',
#               'Pool Bend',
#               'Sapphire Bend',
#               'Sweetwater Bend',
#               'Willow Bend']),
#  'Bluff': set(['Aspen Bluff',
#                'Council Bluff',
#                'Diamond Bluff',
#                'North Bluff',
#                'North Eagles Bluff',
#                'North Falcon Bluff',
#                'Rose Creek Bluff',
#                'South Eagles Bluff',
#                'South Falcon Bluff',
#                'Wheatridge Bluff']),
#  'Blvd': set(['Liberty Blvd',
#               'Millard Farmer Industrial Blvd',
#               'N Industrial Blvd',
#               'Paulding Blvd',
#               'Riverstone Blvd',
#               'Satellite Blvd',
#               'Scott Blvd',
#               'White Columns Blvd',
#               'Woodpark Blvd']),
#  'Branches': set(['Cross Branches']),
#  'Byway': set(['The Byway']),
#  'COurt': set(['Benidorm COurt']),
#  'Canoe': set(['Dragging Canoe']),
#  'Causeway': set(['Riverside Causeway']),
#  'Chapel': set(['Old Chapel']),
#  'Chase': set(['Bluffwind Chase',
#                'Carver Falls Chase',
#                'Chelsea Chase',
#                'Corley Chase',
#                'Country Chase',
#                'Devereux Chase',
#                'Fir Chase',
#                'Foxworth Chase',
#                'Georgetown Chase',
#                'Ivygreen Chase',
#                'Lazy Laurel Chase',
#                'Longwood Chase',
#                'Morgan Falls Chase',
#                'Park Chase',
#                'Regency Chase',
#                'Shadow Creek Chase',
#                'Taylor Meadow Chase',
#                'Woodridge Chase']),
#  'Cir': set(['Adam Cir',
#              'Addington Cir',
#              'Ash Cir',
#              'Baggett Cir',
#              'Bainbridge Cir',
#              'Barros Cir',
#              'Bell Park Cir',
#              'Betts Cir',
#              'Bone Cir',
#              'Braddock Cir',
#              'Brenda Cir',
#              'Brittania Cir',
#              'Browning Cir',
#              'Buchanan Cir',
#              'Cagle Cir',
#              'Canterbury Ridge Cir',
#              'Castlemaine Cir',
#              'Cherokee Village Cir',
#              'Cheswick Cir',
#              'Cloud Cir',
#              'Colony Cir',
#              'Compton Cir',
#              'Corley Cir',
#              'Cross Ridge Cir',
#              'Crow Cir',
#              'Daisy Cir',
#              'Debord Cir',
#              'Duncan Cir',
#              'E Lake Cir',
#              'Eagle Glen Cir',
#              'Eileen Cir',
#              'Erie Cir',
#              'Ettas Cir',
#              'Floyd Clark Cir',
#              'Forkwood Cir',
#              'Grandview Cir',
#              'Green Cir',
#              'Hank Cir',
#              'Harbor Wood Cir',
#              'Hardy Cir',
#              'Harmon Cir',
#              'Hart Cir',
#              'Hawkins Farm Cir',
#              'Haynes Cir',
#              'Henry Bryan Cir',
#              'Hickory Cir',
#              'Hill Cir',
#              'Hill Street Cir',
#              'Hillcrest Cir',
#              'Hilltop Cir',
#              'Hitt Cir',
#              'Hog Farm Cir',
#              'Holiday Cir',
#              'Hollis Cir',
#              'Hudson Cir',
#              'Hunters Cir',
#              'Jaycee Cir',
#              'Jefferson Cir',
#              'Kirkwood Cir',
#              'Knotts Cir',
#              'Lake Cir',
#              'Lakeview Cir',
#              'Legacy Park Cir',
#              'Lovejoy Cir',
#              'Macedonia Forest Cir',
#              'Mariner Cir',
#              'Masters Cir',
#              'Milner Cir',
#              'Moreland Cir',
#              'Narroway Church Cir',
#              'Northwoods Cir',
#              'Nowlin Cir',
#              'Oak Cir',
#              'Oak Landing Cir',
#              'Oakcrest Cir',
#              'Oakhill Cir',
#              'Old Sixes Cir',
#              'Oxford Cir',
#              'Paris Cir',
#              'Perkins Cir',
#              "Pickett's Cir",
#              'Pine Cir',
#              'Pine Crest Cir',
#              'Pine Ridge Cir',
#              'Pinecrest Cir',
#              'Pioneer Cir',
#              'Pointe Cir',
#              'Polk Cir',
#              'Pope Cir',
#              'Quail Hollow Cir',
#              'Radford Cir',
#              'Red Fox Cir',
#              'Red Oak Cir',
#              'Reed Cir',
#              'Richardson Cir',
#              'Ridge Cir',
#              'Rising Cir',
#              'Riverdale Cir',
#              'Roxbury Cir',
#              'Santa Fe Cir',
#              'Sardis Cir',
#              'Sequoyah Cir',
#              'Shadow Cir',
#              'Shadow Ridge Cir',
#              'Silverthorne Cir',
#              'Sinyard Cir',
#              'Spring Gate Cir',
#              'Sterling Falls Cir',
#              'Summit Cir',
#              'Sweetgum Cir',
#              'Sweetwater Cir',
#              'Theodore Cox Cir',
#              'Valerie Cir',
#              'Valley Cir',
#              'Valley Falls Cir',
#              'Victorian Cir',
#              'Waldan Cir',
#              'Walden Chase Cir',
#              'Weaver Cir',
#              'Westside Cir',
#              'Willow Oak Cir',
#              'Winners Cir',
#              'Winterbury Ridge Cir']),
#  'Clifton': set(['Clifton']),
#  'Close': set(['Blairshire Close',
#                'Branchwind Close',
#                'Cedar Close',
#                'Cliffchase Close',
#                'Cottonwood Close',
#                'Crabtree Close',
#                'Cupit Close',
#                'Dunvegan Close',
#                'Glenbrooke Close',
#                'Hughes Branch Close',
#                'Landgraf Close',
#                'Marshview Close',
#                'Mistwater Close',
#                'Park Close',
#                'Red Oak Close',
#                'Ridge Point Close',
#                'River Close',
#                'Saint Ignaius Close',
#                'Taylor Knoll Close',
#                'Twinspur Close',
#                'Waverly Hall Close']),
#  'Cmns': set(['Hillcrest Cmns']),
#  'Con': set(['Interstate Highway 575 Byp Con', 'State Rte 120 Con']),
#  'Connector': set(['East-West Connector', 'GA 136 Connector']),
#  'Copse': set(['Cullen Copse']),
#  'Cove': set(['Al Cove',
#               'Amethyst Cove',
#               'Appaloosa Cove',
#               'Bailey Cove',
#               'Blake Cove',
#               'Broadmeadow Cove',
#               'Buccaneers Cove',
#               'Caseys Cove',
#               'Cedar Mill Cove',
#               'Cherry Cove',
#               'Claiborne Cove',
#               'Classic Cove',
#               'Cranwood Cove',
#               'Creekside Cove',
#               'Cross Creek Cove',
#               'Cypress Cove',
#               'Deep Creek Cove',
#               'Dockside Cove',
#               'Dogwood Cove',
#               'Edgewater Cove',
#               'Elizabeth Cove',
#               'Forest Downs Cove',
#               'Harbor Cove',
#               "Hunter's Cove",
#               'Hunters Cove',
#               'Kensington Cove',
#               'Ketch Cove',
#               'Landgraf Cove',
#               'Laurel Cove',
#               'Lochan Cove',
#               'Magnolia Springs Cove',
#               'Maplewood Cove',
#               'Marsh Rabbit Cove',
#               'Mill Pointe Cove',
#               'Mountain Oak Cove',
#               'Narda Grace Cove',
#               'Nature Cove',
#               'Old Mill Cove',
#               'Paris Cove',
#               'Pine Cove',
#               'Pinehurst Cove',
#               'River Mist Cove',
#               'Rose Creek Cove',
#               'Shelter Cove',
#               'Shipjack Cove',
#               'Summer Creek Cove',
#               'Summer Lake Cove',
#               'Summer-Chase Cove',
#               'Torree Cove',
#               'Towne Harbor Cove',
#               'Tuscan Cove',
#               'Virginia Cove',
#               'Wenlock Edge Cove',
#               'Wilkins Cove',
#               'Wolfcreek Cove',
#               'Yasmine Cove']),
#  'Creek': set(['Cranberry Creek',
#                'Hearthstone Creek',
#                'Little Creek',
#                "Pickett's Creek",
#                'Toonigh Creek']),
#  'Creekwood': set(['Creekwood']),
#  'Crossing': set(['Anmore Crossing',
#                   'Cambridge Crossing',
#                   'Galleon Crossing',
#                   'Hawkins Crossing',
#                   'Idlewood Parc Crossing',
#                   'Inverness Crossing',
#                   'Orso Crossing',
#                   'West Hembree Crossing',
#                   'Wynhurst Crossing']),
#  'Crst': set(['Allatoona Crst', 'Woodbrook Crst']),
#  'Ct': set(['Abnaki Ct',
#             'Acacia Ct',
#             'Acorn Ct',
#             'Allatoona Ct',
#             'Amanda Ct',
#             'Amber Ct',
#             'Amberwood Ct',
#             'Amy Ct',
#             'Anderson Ct',
#             'Andes Ct',
#             'Ann Ct',
#             'Ansley Ct',
#             'Apple Ct',
#             'Apple Valley Ct',
#             'Applewood Ct',
#             'Ashbury Ct',
#             'Ashey Ct',
#             'Atlantis Ct',
#             'Augustus Ct',
#             'Autumn Ct',
#             'Azalea Springs Ct',
#             'Bald Cypress Ct',
#             'Barbara Ct',
#             'Bascomb Springs Ct',
#             'Becky Ct',
#             'Bedford Ct',
#             'Beech Ct',
#             'Bell Ct',
#             'Bennett Farms Ct',
#             'Bent Creek Ct',
#             'Bentwater Ct',
#             'Birchwood Ct',
#             'Bishop Pine Ct',
#             'Bitternut Ct',
#             'Black Fox Ct',
#             'Blackberry Ct',
#             'Bluff Ct',
#             'Blyth Ct',
#             'Bonds Ct',
#             'Bonnabel Ct',
#             'Bowline Ct',
#             'Braddock Ct',
#             'Bradshaw Lake Ct',
#             'Braelin Ct',
#             'Bramble Ct',
#             'Brandie Ct',
#             'Breckenridge Ct',
#             'Brentwood Ct',
#             'Briarcliff Ct',
#             'Briardale Ct',
#             'Bridgewater Ct',
#             'Brier Bend Ct',
#             'Broadwater Ct',
#             'Brook Ct',
#             'Brook Ridge Ct',
#             'Brooks Ct',
#             'Brookside Ct',
#             'Browns Ct',
#             'Bruce Ct',
#             'Butler Ct',
#             'Byron Ct',
#             'Cabin Creek Ct',
#             'Cade Ct',
#             'Caliber Ct',
#             'Callaway Ct',
#             'Camden Ct',
#             'Cameron Ct',
#             'Camrose Ct',
#             'Candle Tree Ct',
#             'Cannon Ct',
#             'Canterbury Ct',
#             'Canterbury Falls Ct',
#             'Carly Ct',
#             'Caylee Ct',
#             'Cedar Ct',
#             'Cedar Valley Ct',
#             'Charles Cox Ct',
#             'Cherokee Ct',
#             'Cherokee Overlook Ct',
#             'Cherokee Village Ct',
#             'Cherry Ct',
#             'Chestnut Ct',
#             'Chieftan Ct',
#             'Christa Ct',
#             'Christie Ct',
#             'Cindy Ct',
#             'Clayton Ct',
#             'Clearwater Ct',
#             'Cloister Ct',
#             'Cobblestone Ct',
#             'Colby Ct',
#             'Colemans Ct',
#             'Colette Ct',
#             'Colony Springs Ct',
#             'Combine Ct',
#             'Commons Ct',
#             'Cool Springs Ct',
#             'Corner Oak Ct',
#             'Cougar Ct',
#             'Coventry Ct',
#             'Covey Ct',
#             'Crabapple Ct',
#             'Crabapple Springs Ct',
#             'Cranfill Ct',
#             'Creek Bank Ct',
#             'Creekridge Ct',
#             'Creekview Ct',
#             'Creekwood Ct',
#             'Cristy Ct',
#             'Cross Tie Ct',
#             'Daniel Ct',
#             'Darby Ford Ct',
#             'David Ct',
#             'Deer Ct',
#             'Denae Ct',
#             'Dennis Ct',
#             'Desmond Ct',
#             'Devon Ct',
#             'Devonshire Ct',
#             'Diane Ct',
#             'Discovery Ct',
#             'Dixie Ct',
#             'Dogwood Ct',
#             'Douglas Fir Ct',
#             'Dove Ct',
#             'Dover Ct',
#             'E Cherokee Ct',
#             'E Lake Ct',
#             'E Terrace Ct',
#             'Eagle Point Ct',
#             'Echota Ct',
#             'Elder Ct',
#             'Elenas Ct',
#             'Elizabeth Ct',
#             'Elkay Ct',
#             'Enterprise Ct',
#             'Eric Ct',
#             'Estate Ct',
#             'Etowah Ct',
#             'Etowah Industrial Ct',
#             'Evans Cook Ct',
#             'Evans Mill Ct',
#             'Executive Ct',
#             'Fairfax Ct',
#             'Fairway Ct',
#             'Fairway Valley Ct',
#             'Faith Ct',
#             'Falcon Pointe Ct',
#             'Falls Ct',
#             'Fernwick Ct',
#             'Ferret Ct',
#             'Ferry Crossing Creek Ct',
#             'Fielding Ct',
#             'Finch Ct',
#             'Fir Ct',
#             'Flanders Ct',
#             'Flint Ct',
#             'Forest Ct',
#             'Fort Wayne Ct',
#             'Fox Chase Ct',
#             'Fox Creek Ct',
#             'Franklin Ct',
#             'Franklin Hills Ct',
#             'Friar Tuck Ct',
#             'Fullerton Ct',
#             'Gail Ct',
#             'Garnet Ct',
#             'Glen Ct',
#             'Glenwood Ct',
#             'Gopher Ct',
#             'Gray Fox Ct',
#             'Hancock Ct',
#             'Hanover Ct',
#             'Harbor Ct',
#             'Harbor Watch Ct',
#             'Hayes Ct',
#             'Hearthwood Ct',
#             'Heather Ct',
#             'Hemlock Ct',
#             'Herrod Ct',
#             'Hickory Creek Ct',
#             'Hickory Ct',
#             'Hickory Grove Ct',
#             'Hickory Mountain Ct',
#             'Hightower Ct',
#             'Highview Ct',
#             'Hill Ct',
#             'Hillshire Ct',
#             'Holden Ct',
#             'Holland Ct',
#             'Hollow Ct',
#             'Holly Chase Ct',
#             'Holly Ct',
#             'Hunters Ct',
#             'Huron Ct',
#             'India Lake Ct',
#             'Indian Lake Ct',
#             'Indian Ridge Ct',
#             'Ivory Ct',
#             'Ivy Green Ct',
#             'Jack Pine Ct',
#             'Jade Ct',
#             'Jake Ct',
#             'Jasmine Ct',
#             'Jeffrey Ct',
#             'Jennifer Ct',
#             'Jody Lynn Ct',
#             'John Ct',
#             'John Ross Ct',
#             'Johnny Ct',
#             'Jones Mill Ct',
#             'Jonquil Ct',
#             'Julie Ct',
#             'Kacey Ct',
#             'Kathy Ct',
#             'Keenan Ct',
#             'Kimball Ct',
#             'Kincade Ct',
#             'King George Ct',
#             'Klamath Ct',
#             'Knights Ct',
#             'Knotts Ct',
#             'Lake Ridge Ct',
#             'Lakeswan Ct',
#             'Landing Ct',
#             'Large Ct',
#             'Laurel Ct',
#             'Lee Ct',
#             'Legacy Ct',
#             'Leopard Ct',
#             'Leslie Ct',
#             'Lima Ct',
#             'Linkside Ct',
#             'Little Creek Ct',
#             'Live Oak Ct',
#             'Londonderry Ct',
#             'Long Shadow Ct',
#             'Longbow Ct',
#             'Louie Ct',
#             'Lovingood Ct',
#             'Loxley Ct',
#             'Lusk Ct',
#             'Magnolia Ct',
#             'Mallory Ct',
#             'Maple Creek Ct',
#             'Maple Ct',
#             'Marian Grove Ct',
#             'Mark Ct',
#             'Marten Ct',
#             'Maya Ct',
#             'Mayfair Ct',
#             'McCollum Ct',
#             'McEvers Branch Ct',
#             'Melody Ct',
#             'Middlebrook Ct',
#             'Mildred Ct',
#             'Mill Crossing Ct',
#             'Mill Ct',
#             'Mill Spring Ct',
#             'Misty Ct',
#             'Monticello Ct',
#             'Morgan Springs Ct',
#             'Mosswood Ct',
#             'Mount Glen Ct',
#             'Mount Tabor Ct',
#             'Mountain Ridge Ct',
#             'Mountain View Ct',
#             'Muirfield Ct',
#             'Musket Ct',
#             'N Springs Ct',
#             'Narrows Ct',
#             'Navaho Ct',
#             'Neil Ct',
#             'New Tracy Ct',
#             'Oak Bluff Ct',
#             'Oak Hill Ct',
#             'Oak Landing Ct',
#             'Oakdale Ct',
#             'Oakside Ct',
#             'Oakview Ct',
#             'Oakwood Ct',
#             'Ocelot Ct',
#             'Old Bascomb Ct',
#             'Old Canton Ct',
#             'Old Chestnut Ct',
#             'Old Course Ct',
#             'Old Fincher Ct',
#             'Old Mill Ct',
#             'Old Settlers Ct',
#             'Old Tassel Ct',
#             'Opal Ct',
#             'Overhill Ct',
#             'Palm Ridge Ct',
#             'Palmer Ct',
#             'Papago Ct',
#             'Paris Ct',
#             'Paxton Ct',
#             'Peardon Ct',
#             'Pebble Creek Ct',
#             'Pheasant Ct',
#             'Phoenix Ct',
#             'Picketts Ridge Ct',
#             'Pimas Ct',
#             'Pine Bluff Ct',
#             'Pine Branches Ct',
#             'Pine Ct',
#             'Pine Ridge Ct',
#             'Pine Valley Ct',
#             'Plantation Ct',
#             'Plum Ct',
#             'Ponca Ct',
#             'Pondview Ct',
#             'Poole Bridge Ct',
#             'Poplar Spring Ct',
#             'Prince Ct',
#             'Puma Ct',
#             'Quail Ct',
#             'Queensbury Ct',
#             'Radford Ct',
#             'Randy Ct',
#             'Red Cedar Ct',
#             'Red Fern Ct',
#             'Red Maple Ct',
#             'Remington Ct',
#             'Reno Ct',
#             'Revere Ct',
#             'Ridge Ct',
#             'Ridgepoint Ct',
#             'River Marsh Ct',
#             'River Rock Ct',
#             'Riverbirch Trace Ct',
#             'Riverlake Ct',
#             'Robin Ct',
#             'Robin Nest Ct',
#             'Rockhouse Ct',
#             'Rocky Ridge Ct',
#             'Roscoe Collette Ct',
#             'Rose Ct',
#             'Rough Creek Ct',
#             'S Oak Landing Ct',
#             'Sabrina Ct',
#             'Sackman Falls Ct',
#             'Saddlehorn Ct',
#             'Sagewood Ct',
#             'Sandra Lynn Ct',
#             'Santee Ct',
#             'Savannah Ct',
#             'Sequoyah Ct',
#             'Shady Oak Ct',
#             'Shagbark Ct',
#             'Sharon Ct',
#             'Shea Ct',
#             'Sherwood Ct',
#             'Shotwell Ct',
#             'Siddiqui Ct',
#             'Silo View Ct',
#             'Silver Thorne Ct',
#             'Silver Trace Ct',
#             'Spring Creek Ct',
#             'Spring Mill Ct',
#             'Spring New Ct',
#             'Springshade Ct',
#             'Springwood Ct',
#             'Spruce Ct',
#             'Standing Turkey Ct',
#             'Stanford Falls Ct',
#             'Starboard Ct',
#             'Starlifter Ct',
#             'Stockwood Ct',
#             'Stone Ct',
#             'Stone Edge Ct',
#             'Stratford Ct',
#             'Sturbridge Ct',
#             'Sunhill Ct',
#             'Sunnybrook Ct',
#             'Sussex Ct',
#             'Sutallee Ridge Ct',
#             'Sweetwater Creek Ct',
#             'Sweetwater Ct',
#             'Sycamore Ct',
#             'Tall Oaks Ct',
#             'Talula Ct',
#             'Tara Ct',
#             'Tarragon Ct',
#             'Taylors Farm Ct',
#             'Teal Ct',
#             'Thornbush Ct',
#             'Toochalar Ct',
#             'Toonigh Ct',
#             'Tower Ct',
#             'Towne Ct',
#             'Township Ct',
#             'Trace Train Ct',
#             'Tranquility Ct',
#             'Trevis Ct',
#             'Tucker Mill Ct',
#             'Tugaloo Ct',
#             'Turner Valley Ct',
#             'Turnrow Ct',
#             'Unicoi Ct',
#             'Univeter Ct',
#             'Valley Ct',
#             'Valley Green Ct',
#             'Valley Mill Ct',
#             'Valley View Ct',
#             'Valleywood Ct',
#             'Victoria Ct',
#             'Victorian Ct',
#             'Village Ct',
#             'W Ridge Ct',
#             'W Wind Ct',
#             'Walnut Ct',
#             'Water Front Ct',
#             'Water Wheel Ct',
#             'Waterford Ct',
#             'Weatherstone Ct',
#             'Wedgewood Ct',
#             'Wellington Ct',
#             'Wentworth Ct',
#             'Wesley Ct',
#             'Westland Ct',
#             'Westover Ct',
#             'Westridge Ct',
#             'Westview Ct',
#             'Westwind Ct',
#             'Westwood Ct',
#             'Whisper Wind Ct',
#             'Whispering Ct',
#             'Whistlewood Ct',
#             'Whiteleaf Ct',
#             'Whitney Ct',
#             'Wild Magnolia Ct',
#             'Wildrose Ct',
#             'Wiley Bridge Ct',
#             'Wilkie Ct',
#             'Williams Ct',
#             'Willow Branch Ct',
#             'Willow Ct',
#             'Windcliff Ct',
#             'Windflower Ct',
#             'Windy Hills Ct',
#             'Winston Ct',
#             'Winter Park Ct',
#             'Wisteria Ct',
#             'Wood Crest Ct',
#             'Wood Knoll Ct',
#             'Woodall Ct',
#             'Woodberry Ct',
#             'Woodcliffe Ct',
#             'Woodmill Ct',
#             'Woodmont Ct',
#             'Woodruff Ct',
#             'Woods Ct',
#             'Woodside Ct',
#             'Wrights Mill Ct']),
#  'D': set(['Highway 54 W #D']),
#  'Dale': set(['Farm Dale', 'London Dale']),
#  'Downs': set(['Barrow Downs', 'Devereux Downs']),
#  'Dr': set(['A W Roberts Dr',
#             'Abbott Dr',
#             'Able Dr',
#             'Acorn Tree Dr',
#             'Airport Dr',
#             'Airport Industrial Dr',
#             'Airstrip Dr',
#             'Allatoona Dr',
#             'Allatoona Highland Dr',
#             'Allatoona Hill Dr',
#             'Allatoona Shores Dr',
#             'Allison Dr',
#             'Alma Dr',
#             'Amalfi Dr',
#             'Amanda Dr',
#             'Amber Dr',
#             'Amber Lake Dr',
#             'Amberwood Dr',
#             'Ammons Dr',
#             'Ann Dr',
#             'Annandale Dr',
#             'Apache Dr',
#             'Appaloosa Dr',
#             'Apple Jack Dr',
#             'Apple Valley Dr',
#             'Arborhill Dr',
#             'Arch Dr',
#             'Arliss Dr',
#             'Arnold Mooney Dr',
#             'Arrow Wood Dr',
#             'Arrowhead Dr',
#             'Arthur Dr',
#             'Ashlin Dr',
#             'Ashwood Dr',
#             'Austin Dr',
#             'Authority Dr',
#             'Autumn Dr',
#             'Avery Creek Dr',
#             'Avery Estates Dr',
#             'Azalea Dr',
#             'Bainbridge Dr',
#             'Baldwin Dr',
#             'Ballentine Dr',
#             'Barton Town Dr',
#             'Bascomb Dr',
#             'Bascomb Park Dr',
#             'Bates Dr',
#             'Battle Dr',
#             'Bear Dr',
#             'Beauty Dr',
#             'Beaver Pond Dr',
#             'Beech Knoll Dr',
#             'Beechwood Dr',
#             'Bell Park Dr',
#             'Benjamin Dr',
#             'Bennett Farms Dr',
#             'Bent Creek Dr',
#             'Bentwater Dr',
#             'Berkeley Dr',
#             'Berkshire Dr',
#             'Bessie Lusk Dr',
#             'Bethany Farms Dr',
#             'Bethel Dr',
#             'Beverly Dr',
#             'Big K Dr',
#             'Big Oak Dr',
#             'Big Woods Dr',
#             'Bill Bagwell Dr',
#             'Billings Dr',
#             'Birch Bend Dr',
#             'Birchwood Dr',
#             'Bishop Dr',
#             'Blackberry Dr',
#             'Blackhawk Dr',
#             'Blackwood Dr',
#             'Blake Dr',
#             'Blankenship Dr',
#             'Blossomwood Dr',
#             'Blue Bird Dr',
#             'Blue Heron Dr',
#             'Blue Pond Dr',
#             'Blue Ridge Dr',
#             'Blueridge Dr',
#             'Bluff Creek Dr',
#             'Bluff Dr',
#             'Bonnie Dr',
#             'Boone Dr',
#             'Bradshaw Estates Dr',
#             'Braly Dr',
#             'Bramble Oak Dr',
#             'Brandi Dr',
#             'Brandywine Dr',
#             'Braxton Dr',
#             'Breckenridge Dr',
#             'Brent Dr',
#             'Briarcliff Dr',
#             'Bridge Station Dr',
#             'Bridgewood Dr',
#             'Brittany Dr',
#             'Brock Dr',
#             'Broken Arrow Dr',
#             'Brolley Woods Dr',
#             'Brompton Dr',
#             'Brook Forest Dr',
#             'Brook Hollow Dr',
#             'Brook Rapids Dr',
#             'Brookridge Dr',
#             'Brooks Dr',
#             'Brookside Dr',
#             'Brookview Dr',
#             'Brookwood Dr',
#             'Brownlee Dr',
#             'Buford Dr',
#             'Bunt Hickory Dr',
#             'Butler Industrial Dr',
#             'Byrd Dr',
#             'Cain Dr',
#             'Campbell Dr',
#             'Campground Dr',
#             'Canvas Back Dr',
#             'Cape Ivy Dr',
#             'Caracas Dr',
#             'Cardinal Dr',
#             'Carl Barrett Dr',
#             'Carmon Dr',
#             'Carvau Dr',
#             'Casablanca Dr',
#             'Cascade Dr',
#             'Castlewood Dr',
#             'Cathie Dr',
#             'Cedar Brook Dr',
#             'Cedar Creek Dr',
#             'Cedar Dr',
#             'Cedar Mill Dr',
#             'Cedar Ridge Dr',
#             'Cedar Valley Dr',
#             'Charles Cox Dr',
#             'Chastain Dr',
#             'Chattin Dr',
#             'Chattooga Dr',
#             'Cherecobb Dr',
#             'Cherokee Dr',
#             'Cherokee Mills Dr',
#             'Cherokee Overlook Dr',
#             'Cherokee Springs Dr',
#             'Cherokee Village Dr',
#             'Chickasaw Dr',
#             'Chief Vann Dr',
#             'Christy Dr',
#             'Circle Dr',
#             'Civic Dr',
#             'Clara Dr',
#             'Clarkview Dr',
#             'Claude Pettit Dr',
#             'Clearview Dr',
#             'Cliff Holcomb Dr',
#             'Clubview Dr',
#             'Cochise Dr',
#             'Coker Dr',
#             'Colemans Bluff Dr',
#             'Colonial Dr',
#             'Colony Center Dr',
#             'Colony Dr',
#             'Colony Springs Dr',
#             'Coltrane Dr',
#             'Commerce Dr',
#             'Commonwealth Dr',
#             'Cooper Dr',
#             'Copper Creek Dr',
#             'Copper Ridge Dr',
#             'Cotton Mill Dr',
#             'Cottonwood Dr',
#             'Country Village Dr',
#             'Cove Dr',
#             'Covered Wagon Dr',
#             'Covington Dr',
#             'Cowart Dr',
#             'Crabapple Springs Dr',
#             'Creek Bank Dr',
#             'Creek Hollow Dr',
#             'Creekbend Dr',
#             'Creekstone Dr',
#             'Creekview Dr',
#             'Crestview Dr',
#             'Crestwood Dr',
#             'Crossbrook Dr',
#             'Crossroads Dr',
#             'Crystal Springs Dr',
#             'Cypress Dr',
#             'Darla Dr',
#             'Davis Mill Dr',
#             'Day Dr',
#             'Deanne Dr',
#             'Dearborn Dr',
#             'Debord Dr',
#             'Deer Hollow Dr',
#             'Deerchase Dr',
#             'Deerfield Dr',
#             'Dene Dr',
#             'Dewberry Creek Dr',
#             'Dials Dr',
#             'Diana Dr',
#             'Dillon Dr',
#             'Dixie Dr',
#             'Dockside Downs Dr',
#             'Dogwood Dr',
#             'Dogwood Knoll Dr',
#             'Donbie Dr',
#             'Dons Dr',
#             'Doris Dr',
#             'Dream Catcher Dr',
#             'Driftwood Dr',
#             'Dudley Dr',
#             'Due West Dr',
#             'Dundee Dr',
#             'Dunnwood Dr',
#             'E Cherokee Dr',
#             'E Forest Dr',
#             'E Memorial Dr',
#             'E Paulding Dr',
#             'E Shore Dr',
#             'Eagle Dr',
#             'Eagle Glen Dr',
#             'Eagle Pointe Dr',
#             'Eagle Watch Dr',
#             'Echo Ridge Dr',
#             'Ellenwood Dr',
#             'Elmtree Dr',
#             'Emerald Pines Dr',
#             'Emmett Dr',
#             'Etowah Valley Dr',
#             'Evans Mill Dr',
#             'Evergreen Dr',
#             'Fairhaven Dr',
#             'Fairway Dr',
#             'Fairway Valley Dr',
#             'Falcon Pointe Dr',
#             'Farmington Dr',
#             'Fawn Dr',
#             'Faye Dr',
#             'Fernbank Dr',
#             'Ficklen Dr',
#             'Fielding Grove Dr',
#             'Fields Landing Dr',
#             'Fields McGhee Dr',
#             'Fieldstone Dr',
#             'Fitchburg Dr',
#             'Floating Cabin Dr',
#             'Foothill Dr',
#             'Forest Dr',
#             'Fort Wayne Dr',
#             'Fountain Dr',
#             'Fowler Dr',
#             'Fox Creek Dr',
#             'Fox Dr',
#             'Fox Glen Dr',
#             'Foxboro Dr',
#             'Fred Bishop Dr',
#             'Furchas Dr',
#             'Garner Farm Dr',
#             'Garretts Dr',
#             'Garrison Dr',
#             'Gateway Dr',
#             'Gay Thompson Dr',
#             'Ghorley Dr',
#             'Gibbs Dr',
#             'Gibson Dr',
#             'Glen Oaks Dr',
#             'Glendale Forest Dr',
#             'Glenell Dr',
#             'Glenmark Dr',
#             'Gold Nugget Dr',
#             'Golden Hills Dr',
#             'Goldfield Dr',
#             'Golf Estates Dr',
#             'Gray Dr',
#             'Green Dr',
#             'Grey Eagle Dr',
#             'Greys Mill Dr',
#             'Gwenelyn Dr',
#             'Hagin Dr',
#             'Haithcock Dr',
#             'Hampton Dr',
#             'Harbin Dr',
#             'Harlin Dr',
#             'Harmony Dr',
#             'Harris Dr',
#             'Hartwood Dr',
#             'Haygood Dr',
#             'Hazelwood Dr',
#             'Heard Dr',
#             'Hearthstone Dr',
#             'Heath Dr',
#             'Heathland Dr',
#             'Hedgewood Dr',
#             'Helms Dr',
#             'Hembree Hill Dr',
#             'Henderson Farm Dr',
#             'Hester Dr',
#             'Hickery Point Dr',
#             'Hickory Cv Dr',
#             'Hickory Dr',
#             'Hickory Fairway Dr',
#             'Hickory Hills Dr',
#             'Hickory Knoll Dr',
#             'Hickory Nut Dr',
#             'Hicks Dr',
#             'Hidden Valley Dr',
#             'Highland Dr',
#             'Highlands Dr',
#             'Hill Creek Dr',
#             'Hillcrest Dr',
#             'Hillmont Dr',
#             'Hillside Dr',
#             'Hiram Dr',
#             'Holly Dr',
#             'Honey Springs Dr',
#             'Honeydew Dr',
#             'Honeysuckle Dr',
#             'Hope Dr',
#             'Hopewell Chase Dr',
#             'Horizon Dr',
#             'Hummingbird Dr',
#             'Hunters Glen Dr',
#             'Imperial Dr',
#             'Indian Creek Dr',
#             'Indian Oak Dr',
#             'Indian Ridge Dr',
#             'Indian Trace Dr',
#             'Indian Trail Dr',
#             'Indian Valley Dr',
#             'Ivey Dr',
#             'Ivy Brook Dr',
#             'Ivy Crest Dr',
#             'Ivy Terrace Dr',
#             'Jack Page Dr',
#             'Jade Dr',
#             'Jamie Dr',
#             'Jaywood Dr',
#             'Jefferson Dr',
#             'Jenny Cohran Dr',
#             'Jesse McCollum Dr',
#             'Jessica Dr',
#             'John Wesley Dr',
#             'Johnson Dr',
#             'Junaluska Dr',
#             'Justin Dr',
#             'Keith Dr',
#             'Kellogg Dr',
#             'Kelly Dr',
#             'Kemp Dr',
#             'Kensley Dr',
#             'Key Dr',
#             'King Arnold Dr',
#             'King Arthur Dr',
#             'King William Dr',
#             'Knotts Landing Dr',
#             'Knotts Point Dr',
#             'Kylemoor Dr',
#             'Ladora Dr',
#             'Lady Savannah Dr',
#             'Laguna Springs Dr',
#             'Lake Arrowhead Dr',
#             'Lake Capri Dr',
#             'Lake Circle Dr',
#             'Lake Forest Dr',
#             'Lake Mist Dr',
#             'Lake Overlook Dr',
#             'Lake Pointe Dr',
#             'Lake Sorrento Dr',
#             'Lake Tanisha Dr',
#             'Lakeside Dr',
#             'Lakeview Dr',
#             'Lakewood Dr',
#             'Lambeth Dr',
#             'Lancaster Dr',
#             'Landsdowne Dr',
#             'Larkwood Dr',
#             'Laurel Hill Dr',
#             'Laurel Lake Dr',
#             'Lawson Dr',
#             'Lee Dr',
#             'Legacy Park Dr',
#             'Legend Dr',
#             'Lester Dr',
#             'Little Brook Dr',
#             'Little River Dr',
#             'Lockhighland Dr',
#             'Londonderry Dr',
#             'Lone Bear Dr',
#             'Long Dr',
#             'Longview Dr',
#             'Longwood Dr',
#             'Lovingood Dr',
#             'Lovingood Landing Dr',
#             'Lynnwood Dr',
#             'Magnolia Dr',
#             'Magnolia Springs Dr',
#             'Malta Dr',
#             'Manassas Dr',
#             'Mark Twain Dr',
#             'Marsha Dr',
#             'Mason Dr',
#             'Matthew Dr',
#             'Mauldin Dr',
#             'Mc Cready Dr',
#             'McBee Dr',
#             'McClure Dr',
#             'Meadows Dr',
#             'Memorial Dr',
#             'Mercer Dr',
#             'Merchants Dr',
#             'Messer Reece Dr',
#             'Middlebrook Dr',
#             'Mill Dr',
#             'Mill Gate Dr',
#             'Mills Lk Dr',
#             'Mills Ridge Dr',
#             'Milton Dr',
#             'Misty Ridge Dr',
#             'Misty Valley Dr',
#             'Mohawk Dr',
#             'Mondi Dr',
#             'Monterey Dr',
#             'Morningside Dr',
#             'Morningstar Dr',
#             'Morris Hill Dr',
#             'Mount Vernon Dr',
#             'Mountain View Dr',
#             'Musical Dr',
#             'Mustang Dr',
#             'N Etowah Dr',
#             'N Oakwood Dr',
#             'N River Dr',
#             'N Spring Dr',
#             'Nacoochee Dr',
#             'Nalley Dr',
#             'Narrows Dr',
#             'Nations Dr',
#             'Neese Dr',
#             'New Georgia Dr',
#             'Northcreek Dr',
#             'Northcroft Dr',
#             'Northtowne Dr',
#             'Northwoods Dr',
#             'Norton Dr',
#             'Nottingham Dr',
#             "O'Farrell Dr",
#             'Oak Forest Dr',
#             'Oak Grove Dr',
#             'Oak Hills Dr',
#             'Oak Landing Dr',
#             'Oak Meadow Dr',
#             'Oak Ridge Dr',
#             'Oakmont Dr',
#             'Observatory Dr',
#             'Old Course Dr',
#             'Old Cumming Dr',
#             'Old Vandiver Dr',
#             'Orange Shoals Dr',
#             'Orchard Dr',
#             'Overhill Dr',
#             'Pace Dr',
#             'Paces Lakes Dr',
#             'Paces Meadows Dr',
#             'Palm Lake Dr',
#             'Park Creek Dr',
#             'Parkside Dr',
#             'Pat Dr',
#             'Patsy Dr',
#             'Patty Dr',
#             'Paul King Dr',
#             'Paulding Meadows Dr',
#             'Payne Dr',
#             'Peachtree Dr',
#             'Pecan Dr',
#             "Pickett's Creek Dr",
#             'Picketts Ferry Dr',
#             'Pine Creek Dr',
#             'Pine Crest Dr',
#             'Pine Forrest Dr',
#             'Pine Grove Dr',
#             'Pine Shadows Dr',
#             'Pine Valley Dr',
#             'Pinebrook Dr',
#             'Pineridge Dr',
#             'Pineview Dr',
#             'Pinewood Dr',
#             'Poinsetta Dr',
#             'Ponderosa Dr',
#             'Poole Bridge Dr',
#             'Poole Dr',
#             'Popcorn Dr',
#             'Pope Dr',
#             'Presidential Dr',
#             'Princeton Dr',
#             'Pritchett Dr',
#             'Providence Dr',
#             'Pruitt Dr',
#             'Purcell Free Dr',
#             'Putnam Dr',
#             'Putnam Ford Dr',
#             'Quail Hollow Dr',
#             'Quarles Dr',
#             'Quarry Dr',
#             'Queensbury Dr',
#             'Rainbow Dr',
#             'Ranch Dr',
#             'Randall Creek Dr',
#             'Ravenwood Dr',
#             'Ray Dr',
#             'Red Gate Lakes Dr',
#             'Redfield Dr',
#             'Redwood Dr',
#             'Regency Dr',
#             'Revere Dr',
#             'Richmond Dr',
#             'Ridge Crossing Dr',
#             'Ridge Dr',
#             'Ridge Pine Dr',
#             'Ridgewood Dr',
#             'Ritchfield Dr',
#             'River Creek Dr',
#             'River Oaks Dr',
#             'River Plantation Dr',
#             'River Rock Dr',
#             'River Station Dr',
#             'Riverchase Dr',
#             'Riverclift Dr',
#             'Rivercrest Dr',
#             'Riverlake Dr',
#             'Riverpoint Dr',
#             'Riverside Dr',
#             'Robin Hood Dr',
#             'Robinhood Dr',
#             'Rock Creek Dr',
#             'Rocky Creek Dr',
#             'Rocky Creek Farm Dr',
#             'Roland Dr',
#             'Rolling Green Dr',
#             'Romain Dr',
#             'Rose Ridge Dr',
#             'Rosedale Dr',
#             'Rosewood Dr',
#             'Roy Haynes Dr',
#             'Rustin Dr',
#             'S Etowah Dr',
#             'S Lake Dr',
#             'S McCollum Dr',
#             'Saddlewood Dr',
#             'Sadler Dr',
#             'Sandpiper Dr',
#             'Sanford Dr',
#             'Savannah Dr',
#             'Seminole Dr',
#             'Senators Ridge Dr',
#             'Sequoyah Dr',
#             'Seth Ridge Dr',
#             'Settindown Dr',
#             'Sexton Dr',
#             'Shadow Wood Dr',
#             'Shadowbrook Dr',
#             'Shady Brook Dr',
#             'Shane Dr',
#             'Shannon Dr',
#             'Sherwood Dr',
#             'Sherwood Forest Dr',
#             'Short Dr',
#             'Silver Thorne Dr',
#             'Sims Dr',
#             'Sky Lark Dr',
#             'Skyline Dr',
#             'Skyridge Dr',
#             'Smith Dr',
#             'Smithwyck Dr',
#             'Snookey Dr',
#             'Southern Trace Dr',
#             'Southfork Dr',
#             'Southland Dr',
#             'Southwind Dr',
#             'Spring Dr',
#             'Spring Lake Dr',
#             'Spring Leaf Dr',
#             'Spring Woods Dr',
#             'Springfield Dr',
#             'Springharbor Dr',
#             'Springs Dr',
#             'Stacey Dr',
#             'Standridge Dr',
#             'Stations Dr',
#             'Stella Dr',
#             'Sterling Dr',
#             'Stewart Dr',
#             'Stockwood Dr',
#             'Stone Edge Dr',
#             'Stoneforest Dr',
#             'Stoneybrook Dr',
#             'Stonybrook Dr',
#             'Stowers Dr',
#             'Strickland Dr',
#             'Summer Chase Dr',
#             'Summer Creek Dr',
#             'Summer Lake Dr',
#             'Summer Point Dr',
#             'Sundown Dr',
#             'Sunlight Dr',
#             'Sunset Dr',
#             'Surrey Dr',
#             'Suzie Creek Dr',
#             'Swan Dr',
#             'Sweetgum Dr',
#             'Sweetwater Creek Dr',
#             'Sweetwater Dr',
#             'Sycamore Dr',
#             'Talcmine Dr',
#             'Tall Oaks Dr',
#             'Tanglewood Dr',
#             'Tanner Dr',
#             'Taylor Creek Dr',
#             'Taylors Farm Dr',
#             'Teague Dr',
#             'The Falls of Cherokee Dr',
#             'Thorn Thicket Dr',
#             'Thornbrook Dr',
#             'Thornwood Dr',
#             'Thunder Ridge Dr',
#             'Timberchase Dr',
#             'Timberland Dr',
#             'Tom Hulsey Dr',
#             'Toms Dr',
#             'Torrington Dr',
#             'Tower Dr',
#             'Town Creek Dr',
#             'Towne Lake Hills South Dr',
#             'Towne Ridge Dr',
#             'Township Dr',
#             'Trade Winds Dr',
#             'Trailwood Dr',
#             'Trenton Dr',
#             'Trickum Dr',
#             'Trickum Valley Dr',
#             'Tulane Dr',
#             'Turnberry Dr',
#             'Twin Pines Dr',
#             'Tynsdale Dr',
#             'Tyson Dr',
#             'Upland Estates Dr',
#             'Valley Brook Dr',
#             'Valley Dr',
#             'Valleyhill Dr',
#             'Valleyridge Dr',
#             'Valleyside Dr',
#             'Vally Creek Dr',
#             'Vaughn Dr',
#             'Vickie Dr',
#             'Victoria Landing Dr',
#             'Victory Dr',
#             'Viola Dr',
#             'W Alabama Dr',
#             'W Bramble Dr',
#             'W Elmwood Dr',
#             'W Hanger Dr',
#             'W Memorial Dr',
#             'W Pine Ridge Dr',
#             'Walnut Creek Dr',
#             'Walnut Dr',
#             'Warehouse Dr',
#             'Warrenton Dr',
#             'Waterford Falls Dr',
#             'Watkins Glen Dr',
#             'Watson Dr',
#             'Weatherstone Dr',
#             'Wedgewood Dr',
#             'Weeping Willow Dr',
#             'Wellesley Crest Dr',
#             'Wentworth Dr',
#             'Wesleyan Dr',
#             'Westchester Club Dr',
#             'Westover Dr',
#             'Westwind Dr',
#             'Wheeler Martin Dr',
#             'Whispering Pines Dr',
#             'Whispering Woods Dr',
#             'Whistle Stop Dr',
#             'Whitby Dr',
#             'White City Dr',
#             'White Eagle Dr',
#             'White Leaf Dr',
#             'White Oak Dr',
#             'White Path Dr',
#             'White Pines Dr',
#             'Whitfield Dr',
#             'Wiiliam Falls Dr',
#             'Wilbanks Dr',
#             'Wildwood Dr',
#             'Willhaven Dr',
#             'William Bobo Dr',
#             'Williams Dr',
#             'Willis Dr',
#             'Willow Bend Dr',
#             'Willow Creek Dr',
#             'Willow Dr',
#             'Willow Oak Dr',
#             'Willow Tree Dr',
#             'Windfield Dr',
#             'Windmill Dr',
#             'Windridge Dr',
#             'Windsor Dr',
#             'Windsor Falls Dr',
#             'Winnview Dr',
#             'Winooki Dr',
#             'Winterville Dr',
#             'Wisteria Dr',
#             'Wolverine Dr',
#             'Wood Chase Dr',
#             'Wood Ridge Dr',
#             'Wood Valley Dr',
#             'Woodall Dr',
#             'Woodbridge Dr',
#             'Woodcreek Dr',
#             'Woodglen Dr',
#             'Woodland Brook Dr',
#             'Woodland Dr',
#             'Woodside Park Dr',
#             'Woodvalley Dr',
#             'Woodwind Dr',
#             'Wooten Dr',
#             'Yacht Club Dr',
#             'York Dr',
#             'Yorkshire Dr',
#             'Zion Hill Dr']),
#  'E': set(['3rd Ave E',
#            '5th Ave E',
#            'Picketts Forge Dr E',
#            'S Forty Pass E',
#            'Towne Lake Hill E',
#            'Village Green Cir E']),
#  'East': set(['Adena Lane East',
#               'Buford Drive North East',
#               'Buford Highway North East',
#               'Creekwood Crossing East',
#               'Cumming Highway North East',
#               'Mansell Court East',
#               'Morrison Moore Parkway East',
#               'Nelson Brogdon Boulevard North East']),
#  'End': set(['Links End']),
#  'Entry': set(['Landing Entry']),
#  'Estate': set(['Manor Estate']),
#  'Fairway': set(['Seventeenth Fairway', 'The Fairway', 'The Fifth Fairway']),
#  'Falls': set(['Watermill Falls']),
#  'Farm': set(['Clarity Farm', 'Pearls Farm']),
#  'Forge': set(['Carrington Forge']),
#  'GA)': set(['US 41 (GA)']),
#  'GLN': set(['Lakeway GLN']),
#  'GRV': set(['Orchard GRV']),
#  'Gate': set(['Gentry Gate']),
#  'Glen': set(['Cheviot Glen',
#               'Heather Glen',
#               'Iris Glen',
#               'Ivy Glen',
#               'Kingswood Glen',
#               'Marne Glen',
#               'Shady Glen',
#               'Wicksford Glen',
#               'Willshire Glen']),
#  'Glenn': set(['Watson Glenn']),
#  'Grove': set(['Guildhall Grove', 'Olde Roswell Grove', 'Poplar Grove']),
#  'Hallow': set(['Harris Hallow']),
#  'Heights': set(['Liberty Heights']),
#  'Highway': set(['Alpharetta Highway',
#                  'Atlanta Highway',
#                  'Bankhead Highway',
#                  'Braselton Highway',
#                  'Buchanan Highway',
#                  'Cumming Highway',
#                  'Dallas Highway',
#                  'Dallas-Acworth Highway',
#                  'Dawsonville Highway',
#                  'Marietta Highway',
#                  'Martha Berry Highway',
#                  'Mount Vernon Highway',
#                  'Old National Highway',
#                  'Roosevelt Highway',
#                  'West Bankhead Highway']),
#  'Hill': set(['Cherokee Hill',
#               'Mystic Ridge Hill',
#               'Walton Hill',
#               'Wolfcreek Hill']),
#  'Hills': set(['South Hills']),
#  'Hollow': set(['Chadds Hollow',
#                 'Hedge Row Hollow',
#                 'Heights Hollow',
#                 'Hembree Hollow',
#                 'Hickory Oak Hollow',
#                 'Mill Creek Hollow',
#                 'Shaker Hollow',
#                 'Wickerberry Hollow']),
#  'Hts': set(['Cherokee Hts', 'Dogwood Hts']),
#  'Hwy': set(['Atlanta Hwy',
#              'Ball Ground Hwy',
#              'Birmingham Hwy',
#              'Buchanan Hwy',
#              'Canton Hwy',
#              'Cartersville Hwy',
#              'Covington Hwy',
#              'Cumming Hwy',
#              'Dallas Acworth Hwy',
#              'Freehome Hwy',
#              'Hickory Flat Hwy',
#              'Hiram Acworth Hwy',
#              'Hiram Douglasville Hwy',
#              'Knox Bridge Hwy',
#              'Loganville Hwy',
#              'Marietta Hwy',
#              'McDonough Hwy',
#              'Old Ball Ground Hwy',
#              'Rockmart Hwy',
#              'Scott Hwy',
#              'Stockbridge Hwy',
#              'Villa Rica Hwy']),
#  'Knoll': set(['Camden Knoll',
#                'Capitol Knoll',
#                'Liberty Knoll',
#                'Wickerberry Knoll',
#                'Young Knoll']),
#  'Lakes': set(['Red Gate Lakes']),
#  'Land': set(['Far Emerald Land']),
#  'Landing': set(['Grimes Bridge Landing',
#                  'Grogans Landing',
#                  'McGhee Landing',
#                  'Old Sandhurst Landing',
#                  'Ozmer Landing',
#                  'The Landing']),
#  'Lismore': set(['Lismore']),
#  'Ln': set(['Abineton Ln',
#             'Abney Ln',
#             'Addington Ln',
#             'Aiken Ln',
#             'Aldbury Ln',
#             'Alexandria Ln',
#             'Allatoona Ln',
#             'Allen Ln',
#             'Allison Ln',
#             'Amanda Ln',
#             'Amber Ln',
#             'Angela Ln',
#             'Apple Orchard Ln',
#             'Arnold Ln',
#             'Arnold Mooney Ln',
#             'Arrow Wood Ln',
#             'Ashley Ln',
#             'Atherton Ln',
#             'Avondale Ln',
#             'Bannister Ln',
#             'Barrington Ln',
#             'Bates Ln',
#             'Bay Leaf Ln',
#             'Beau Ln',
#             'Bent Willow Ln',
#             'Betty Ln',
#             'Bexley Ln',
#             'Biddy Ln',
#             'Bill Jordan Ln',
#             'Billy Ln',
#             'Blackberry Ln',
#             'Bobo Ln',
#             'Bomar Ln',
#             'Braddock Ln',
#             'Bradshaw Ln',
#             'Brandywine Ln',
#             'Breckenridge Ln',
#             'Breeze Hill Ln',
#             'Briar Patch Ln',
#             'Britley Park Ln',
#             'Broken Arrow Ln',
#             'Brook Ln',
#             'Brooks Ln',
#             'Brooks Mill Ln',
# ...
#                    'Zone Avenue Southwest']),
#  'Spring': set(['Riverwood Spring']),
#  'Sq': set(['Park Sq', 'Scully Sq', 'Sycamore Sq']),
#  'St': set(['1st St',
#             'Academy St',
#             'Adel St',
#             'Alex St',
#             'Alpha St',
#             'Alpine St',
#             'Archer St',
#             'Ash St',
#             'Baldwin St',
#             'Barry St',
#             'Bartow St',
#             'Beatrice St',
#             'Birch St',
#             'Blackwell St',
#             'Boyd St',
#             'Braswell St',
#             'Brooks St',
#             'Brown St',
#             'Byers St',
#             'Canton St',
#             'Cartersville St',
#             'Center St',
#             'Cherokee St',
#             'Chestnut St',
#             'Church St',
#             'Coker St',
#             'Creekmore St',
#             'Crisler St',
#             'Dallas St',
#             'Dean St',
#             'Delay St',
#             'Depot St',
#             'Doefield St',
#             'Dupree St',
#             'Durham St',
#             'E Broad St',
#             'E Main St',
#             'E Marietta St',
#             'E Spring St',
#             'East St',
#             'Elizabeth St',
#             'Elm St',
#             'Evans St',
#             'Field St',
#             'Fitzgerald St',
#             'Fowler St',
#             'Fulton St',
#             'Gail St',
#             'Glenn St',
#             'Goodwin St',
#             'Goss St',
#             'Grady St',
#             'Groover St',
#             'Hamilton St',
#             'Hemlock St',
#             'Henry Clay St',
#             'Hickory St',
#             'Highland St',
#             'Holly St',
#             'Hood St',
#             'Hughes St',
#             'Ingram St',
#             'Ivy St',
#             'Jarvis St',
#             'Jeannette St',
#             'Joseph St',
#             'Juniper St',
#             'Kyle St',
#             'Lee St',
#             'Lemon St',
#             'Lerol St',
#             'Linton St',
#             'Lowry St',
#             'Lucky St',
#             'Luke St',
#             'Main St',
#             'Mary St',
#             'McClure St',
#             'McLain St',
#             'Meadow St',
#             'Michael St',
#             'Mill St',
#             'Mound St',
#             'Muriel St',
#             'N Crisler St',
#             'N Johnston St',
#             'Nix St',
#             'North St',
#             'Oak St',
#             'Orange St',
#             'Palm St',
#             'Park St',
#             'Pate St',
#             'Pawnee St',
#             'Picabo St',
#             'Pickens St',
#             'Pine St',
#             'Poplar St',
#             'Powder Mill St',
#             'Powder Springs St',
#             'Ragsdale St',
#             'Railroad St',
#             'Rusk St',
#             'S Church St',
#             'S Johnston St',
#             'Shipp St',
#             'Short St',
#             'Short Tanyard St',
#             'Shotwell St',
#             'South St',
#             'Spring St',
#             'St Ann St',
#             'Strippling St',
#             'Teasley St',
#             'Terrell St',
#             'Timberland St',
#             'Toulouse St',
#             'Valley St',
#             'W Griffin St',
#             'W Main St',
#             'W Marietta St',
#             'W South St',
#             'Waleska St',
#             'Westview St',
#             'White Antelope St',
#             'Wood Branch St',
#             'Woodland St']),
#  'Station': set(['Old Sandhurst Station',
#                  'Ridge Brook Station',
#                  'Victoria Station',
#                  'Wood Wind Station']),
#  'Steeplechase': set(['Steeplechase']),
#  'Strip': set(['Sunset Strip']),
#  'Tarn': set(['Ferry Crossing Tarn',
#               'Legendary Tarn',
#               'Misty Lake Tarn',
#               'Ridge Tarn',
#               'Willow Tarn']),
#  'Tears': set(['Trl of Tears']),
#  'Ter': set(['Barnesdale Ter',
#              'Bridgewater Ter',
#              'Crestview Ter',
#              'Etowah Ter',
#              'Gladstone Ter',
#              'Hickory Bend Ter',
#              'Highland Ter',
#              'Honeysuckle Ter',
#              'Lakeview Ter',
#              'Park Ter',
#              'Pine Ter',
#              'Ragsdale Ter',
#              'Red Gate Ter',
#              'River Run Ter',
#              'River Station Ter',
#              'Salem Ter',
#              'Shotwell Ter',
#              'Spring Ridge Ter',
#              'Summer Ter',
#              'Villa Ridge Ter',
#              'Woodglen Ter']),
#  'Terrace': set(['Amhurst Terrace',
#                  'Avalon Terrace',
#                  'Barcelona Terrace',
#                  'Carlton Pointe Terrace',
#                  'Carobet Terrace',
#                  'Charleston Terrace',
#                  'Clear Creek Terrace',
#                  'Clubside Terrace',
#                  'Courtyard Terrace',
#                  'Dabney Terrace',
#                  'Delmont Terrace',
#                  'Fallview Terrace',
#                  'Fripp Terrace',
#                  'Headland Terrace',
#                  'Huntcliff Terrace',
#                  'Jefferson Terrace',
#                  'Knoll Terrace',
#                  'Knoll Woods Terrace',
#                  'McAlpin Terrace',
#                  'Oak Park Terrace',
#                  'Orchard Hill Terrace',
#                  'Orly Terrace',
#                  'Park Terrace',
#                  'Parkside Terrace',
#                  'Princeton Terrace',
#                  'Raymond Terrace',
#                  'Rugby Terrace',
#                  'Scenic Terrace',
#                  'Spring Hill Terrace',
#                  'Springlake Terrace',
#                  'Stoneview Terrace',
#                  'Sylvan Terrace',
#                  'Valante Terrace',
#                  'Vesta Terrace',
#                  'Villas Terrace',
#                  'Walnut Terrace',
#                  'Waterbrook Terrace',
#                  'Weldstone Terrace',
#                  'Wellington Terrace',
#                  'Wentworth Terrace',
#                  'Winburn Terrace']),
#  'Tier': set(['Maplewood Tier']),
#  'Trace': set(['Aubusson Trace',
#                'Baltusrol Trace',
#                'Boulder Trace',
#                'Bridle Ridge Trace',
#                'Camber Trace',
#                'Cedar Trace',
#                'Charleston Trace',
#                'Clearlake Trace',
#                'Club Walk Trace',
#                'Dendy Trace',
#                'Derby Ridge Trace',
#                'Fall Creek Trace',
#                'Farm Grove Trace',
#                'Grassy Trace',
#                'Greenvine Trace',
#                'Greenwood Trace',
#                'Gunlock Trace',
#                'Hammock Trace',
#                'Hearthstone Trace',
#                'High Creek Trace',
#                'Hughes Trace',
#                'Huntcliff Trace',
#                'Lakes Trace',
#                'Langston Trace',
#                'Liberty Trace',
#                'Marie Trace',
#                'Marshwood Trace',
#                'Meadow Trace',
#                'Meadowsweet Trace',
#                'Mica Trace',
#                'Mistwater Trace',
#                'Mountain Trace',
#                'Newgold Trace',
#                'North Hickory Trace',
#                'Northcliff Trace',
#                'Northgate Trace',
#                'Northpointe Trace',
#                'Old Oak Trace',
#                'Old Tree Trace',
#                'Orchard Trace',
#                'Parkmont Trace',
#                'Pine Glade Trace',
#                'Plymouth Trace',
#                'Rebecca Lake Trace',
#                'Rippling Brook Trace',
#                'River Trace',
#                'Saddle Ridge Trace',
#                'Shady River Trace',
#                'Slane Trace',
#                'Spender Trace',
#                'Spring Ridge Trace',
#                'Stonemist Trace',
#                'Summit Trace',
#                'Swan Trace',
#                'Sweetwater Trace',
#                'Thistle Oak Trace',
#                'Truehedge Trace',
#                'Village Trace',
#                'Waverly Trace',
#                'Welford Trace',
#                'Willow Tree Trace',
#                'Windflower Trace',
#                'Wood Valley Trace',
#                'Wynland Trace']),
#  'Track': set(['Farm Track', 'Junction Track']),
#  'Trce': set(['Amber Trce',
#               'Bethany Trce',
#               'Blue Ridge Trce',
#               'Brookstone Trce',
#               'Cambridge Trce',
#               'Cherecobb Trce',
#               'Cross Creek Trce',
#               'Eagle Glen Trce',
#               'Eagle View Trce',
#               'Enfield Trce',
#               'Fox Hound Trce',
#               'Gantt Trce',
#               'Goldpoint Trce',
#               'Hayes Trce',
#               'Holly Oak Trce',
#               'Hunters Trce',
#               'Jonathan Trce',
#               'Kremer Falls Trce',
#               'Lakeshire Trce',
#               'Magnolia Springs Trce',
#               'Magnolia Trce',
#               'Middlebrooke Trce',
#               'Mill Trce',
#               'Misty Trce',
#               'Mountain Trce',
#               'Oak Trce',
#               'Old Oak Trce',
#               'Olde Mill Trce',
#               'Paces Lakes Trce',
#               "Pickett's Trce",
#               'Plantation Trce',
#               'Rising Trce',
#               'River Rock Trce',
#               'Springwater Trce',
#               'Starlyn Trce',
#               'Tara Falls Trce',
#               'Timber Trce',
#               'Victoria Trce',
#               'Wildwind Trce',
#               'Wind Song Trce']),
#  'Trl': set(['Allatoona Trl',
#              'Apache Trl',
#              'Arrow Trl',
#              'Ashley Trl',
#              'Bagwell Trl',
#              'Bennett Farms Trl',
#              'Bentwood Trl',
#              'Bethesda Trl',
#              'Bishop Trl',
#              'Black Oak Trl',
#              'Black Trl',
#              'Blue Ridge Trl',
#              'Bobwhite Trl',
#              'Bridge Trl',
#              'Bridgewater Trl',
#              'Brook Hollow Lake Trl',
#              'Broomall Trl',
#              'Carney Trl',
#              'Chase Trl',
#              'Cherokee Forest Trl',
#              'Cherokee Gold Trl',
#              'Cherokee Trl',
#              'Clearview Trl',
#              'Clearwater Trl',
#              'Cool Springs Trl',
#              'Copper Trl',
#              'Country Square Trl',
#              'Country Trl',
#              'Crabapple Trl',
#              'Crooked Branch Trl',
#              'Cross Trl',
#              'Dock Lathem Trl',
#              'Dogwood Lake Trl',
#              'Dogwood Trl',
#              'Don John Trl',
#              'Due West Trl',
#              'Dunedin Trl',
#              'Dunhill Trl',
#              'E Hightower Trl',
#              'Eagle Ridge Trl',
#              'Eastside Trl',
#              'Fawn Trl',
#              'Flatbottom Trl',
#              'Forkwood Trl',
#              'Garrison Trl',
#              'Glenn Wilkie Trl',
#              'Godfrey Trl',
#              'Gramling Trl',
#              'Hampton Trl',
#              'Hasty Trl',
#              'Hearthstone Trl',
#              'Hickory Gap Trl',
#              'Hickory Trl',
#              'Hidden Branches Trl',
#              'Hightower Trl',
#              'Hulsey Trl',
#              'Hunters Trl',
#              'Indian Trl',
#              'Jade Trl',
#              'Jesse Martin Trl',
#              'Knox Campground Trl',
#              'Kraft Trl',
#              'Lakeview Trl',
#              'Lakewood Trl',
#              'Landing Trl',
#              'Laurel Trl',
#              'Lemon Trl',
#              'Lula Payne Trl',
#              'Mark Trl',
#              'Mill Pointe Trl',
#              'Misty Ridge Trl',
#              'Moccasin Trl',
#              'Mountain Breeze Trl',
#              'Murphy Trl',
#              'Narroway Trl',
#              'New Mill Trl',
#              'Old Blackberry Trl',
#              'Old Fincher Trl',
#              'Old Hightower Trl',
#              'Old Magnolia Trl',
#              'Old Mill Trl',
#              'Old Mystic Trl',
#              'Old Pioneer Trl',
#              'Old Shoal Creek Trl',
#              'Old Virginia Trl',
#              'Overlook Trl',
#              'Pine Trl',
#              'Pioneer Trl',
#              'Ponderosa Trl',
#              'Puckett Trl',
#              'Rampley Trl',
#              'Ranchwood Trl',
#              'River Rock Trl',
#              'Ross Williams Trl',
#              'Saddle Creek Trl',
#              'Sante Fe Trl',
#              'Seldom Seen Trl',
#              'Setser Trl',
#              'Shady Trl',
#              'Shagbark Trl',
#              'Spriggs Trl',
#              'Springwater Trl',
#              'Steeple Chase Trl',
#              'Sterling Trl',
#              'Stevensons Trl',
#              'Streamview Trl',
#              'Summer Glen Trl',
#              'Summerchase Trl',
#              'Sutallee Ridge Trl',
#              'Tamarack Trl',
#              'Terrace Trl',
#              'Thunderwood Trl',
#              'Tippens Trl',
#              'Tomahawk Trl',
#              'Tomlin Trl',
#              'Tower Trl',
#              'Towne Harbor Trl',
#              'Tribal Trl',
#              'Upper Bethany Trl',
#              'Upper Sweetwater Trl',
#              'Vicksburg Trl',
#              'Vintage Trl',
#              'W Hightower Trl',
#              'W Point Trl',
#              'Wabash Trl',
#              'Wagon Trl',
#              'White Path Trl',
#              'Wild Azalea Trl',
#              'Wilkie Trl',
#              'Wilzman Trl',
#              'Winding Woods Trl',
#              'Windstone Trl',
#              'Woodbrook Trl']),
#  'Troon': set(['Royal Troon']),
#  'Turn': set(['Cedar Turn', 'Gable Gate Turn', 'Revere Turn']),
#  'Valley': set(['Ridge Valley', 'Wildwood Valley']),
#  'View': set(['Babbling View',
#               'Bluegrass View',
#               'Colonial View',
#               'Creekside View',
#               'Highland Lake View',
#               'Olmadison View',
#               'Parkland View',
#               'Stream View',
#               'Wolfcreek View']),
#  'Vine': set(['Hope Vine']),
#  'Vw': set(['Chadds Vw',
#             'Cinema Vw',
#             'Hunters Vw',
#             'Peaceful Vw',
#             "Pickett's Vw"]),
#  'W': set(['Hwy. 124 W', 'Lake Rd W', 'Park Ave W', 'Towne Lake Hill W']),
#  'Walk': set(['Ashfern Walk',
#               'Bridge Walk',
#               'Camden Walk',
#               'Chelsea Walk',
#               'Colemans Walk',
#               'Cool Springs Walk',
#               'Crescent Walk',
#               'Cresthaven Walk',
#               'Crosswinds Walk',
#               'Greenmont Walk',
#               'Heritage Walk',
#               'Hickory Walk',
#               'High Vista Walk',
#               'Kenley Walk',
#               'Legacy Walk',
#               'Magnolia Walk',
#               'Meadows Walk',
#               'Misty Walk',
#               'Morgan Walk',
#               'Providence Walk',
#               'River Walk',
#               'Rose Creek Walk',
#               'Shoreline Walk',
#               'Silver Walk',
#               'Sonja Walk',
#               'Southland Walk',
#               'Sparrow Walk',
#               'Surveyor Walk',
#               'Vestry Walk',
#               'Waverly Walk',
#               'Wilshire Walk']),
#  'West': set(['Adena Lane West',
#               'Creekwood Crossing West',
#               'Pebble Rock  West',
#               'Perimeter Center West']),
#  'Willow': set(['Weeping Willow']),
#  'Wood': set(['Stradford Wood']),
#  'Woods': set(['Merriweather Woods', 'Wisteria Woods']),
#  'Xing': set(['Buckhead Xing',
#               'Cedar Mill Xing',
#               'Daventry Xing',
#               'Eagle Glen Xing',
#               'Foxfire Xing',
#               'Hearthstone Xing',
#               'Highpoint Xing',
#               'Hunters Xing',
#               'Settlers Xing',
#               'Southern Trace Xing',
#               'Springdale Xing',
#               'Vinson Mountain Xing',
#               'Woodruff Xing']),
#  'blvd': set(['Keeneland blvd']),
#  'circle': set(['Wrotham circle']),
#  'dr': set(['1807 preston lake dr']),
#  'drive': set(['Sanford drive']),
#  'lane': set(['Creel lane', 'Lava lane']),
#  'place': set(['Harris Commons place'])}

# %% [markdown]
# ## Problems Encountered

# %% [markdown]
# #### Street abbreviations:
#
# When looking through the output of audit_1 and audit_2 functions I saw that several street names are abbreviated. For example: Ave, Blvd, Cir, Ct and Dr to name some. There is also some incorrect case abbreviations / spellings, for example: COurt, blvd, circle, dr, drive, lane and place.
#
# These can be updated with a mapping dictionary and using the update_name and test functions.
#
#
#
#
# #### Invalid zip codes:
#
# When looking through the zip code data I noticed 2 records that had invalid zip codes. All zip codes in the Atlanta area start with '30' so it was easy to identify with the below query.
#
# `SELECT id, value
# FROM nodes_tags
# WHERE key like '%postcode%' AND value not LIKE '30%';`
#
# `2352501668 | 80083
# 3121340792 | Georgia`
#
# id '2352501668' is 4997 Saxony Court, Stone Mountain, GA 80083. The correct zip code is 30083 for this address. This can be updated in the database by an UPDATE statement.
#
# `UPDATE nodes_tags
# SET VALUE = '30083'
# WHERE id = '2352501668' AND key LIKE '%postcode%';`
#
# id '3121340792' is 1420 Cresthaven Lane NW, Lawrenceville, Georgia with the zip code being 'Georgia'. The correct zip code is 30043 for this address. This can also be updated in the database by an UPDATE statement.
#
# `UPDATE nodes_tags
# SET VALUE = '30043'
# WHERE id = '3121340792' AND key LIKE '%postcode%';`

# %%
#mapping dictionary for update_name
mapping = { "St": "Street",
            "St.": "Street",
            "street": "Street",
            "Rd": "Road",
            "Rd.": "Road",
            "road": "Road",
            "Ave": "Avenue",
            "Ave.": "Avenue",
            "avenue": "Avenue",
            "Dr": "Drive",
            "Dr.": "Drive",
            "drive": "Drive",
            "dr": "Drive",
            "Hwy": "Highway",
            "highway": "Highway",
            "Ct": "Court",
            "Ct.": "Court",
            "court": "Court",
            "COurt": "Court",
            "Cir": "Circle",
            "Cir.": "Circle",
            "circle": "Circle",
            "Hts": "Heights",
            "Ln": "Lane",
            "lane": "Lane",
            "Ter": "Terrace",
            "Trce": "Trace",
            "Trl": "Trail",
            "Vw": "View",
            "Xing": "Crossing",
            "blvd": "Blvd",
            "place": "Place"            
            }

# %%
#updating street names per the mapping dictionary
def update_name(name, mapping):

    m = street_type_re.search(name)
    if m:
        street_type = m.group()
        if street_type in mapping.keys():
            #print 'Before: ' , name
            name = re.sub(m.group(), mapping[m.group()], name)
            #print 'After: ', name
    return name   


def test():
    st_types = audit_2(osmfile)
   
    for st_type, ways in st_types.iteritems():
        for name in ways:
            better_name = update_name(name, mapping)
            print name, "=>", better_name

# %%
test()
# Out:
# Waverly Way Northeast => Waverly Way Northeast
# Ashland Avenue Northeast => Ashland Avenue Northeast
# Mathieson Drive Northeast => Mathieson Drive Northeast
# Windemere Drive Northeast => Windemere Drive Northeast
# West Ashland Avenue Northeast => West Ashland Avenue Northeast
# Parkerton Lane Northeast => Parkerton Lane Northeast
# North Fulton Drive Northeast => North Fulton Drive Northeast
# Belgrade Avenue Northeast => Belgrade Avenue Northeast
# Ivy Gates Northeast => Ivy Gates Northeast
# Lindbergh Drive Northeast => Lindbergh Drive Northeast
# Old Creek Road Northeast => Old Creek Road Northeast
# Bradley Street Northeast => Bradley Street Northeast
# Shenandoah Avenue Northeast => Shenandoah Avenue Northeast
# Miller Avenue Northeast => Miller Avenue Northeast
# Piedmont Road Northeast => Piedmont Road Northeast
# Acorn Avenue Northeast => Acorn Avenue Northeast
# Baroque Circle Northeast => Baroque Circle Northeast
# Parkside Drive Northeast => Parkside Drive Northeast
# Rickenbacker Drive Northeast => Rickenbacker Drive Northeast
# Johnson Ferry Road Northeast => Johnson Ferry Road Northeast
# Earlston Drive Northeast => Earlston Drive Northeast
# Kings Road Northeast => Kings Road Northeast
# Valley Green Drive Northeast => Valley Green Drive Northeast
# Liddell Drive Northeast => Liddell Drive Northeast
# Huntington Road Northeast => Huntington Road Northeast
# Wieuca Overlook Northeast => Wieuca Overlook Northeast
# Squire Place Northeast => Squire Place Northeast
# Meadowdale Avenue Northeast => Meadowdale Avenue Northeast
# Glendale Terrace Northeast => Glendale Terrace Northeast
# Potomac Avenue Northeast => Potomac Avenue Northeast
# Glengary Drive Northeast => Glengary Drive Northeast
# Wallace Road Northeast => Wallace Road Northeast
# Prince Terrace Northeast => Prince Terrace Northeast
# Lakeside Drive Northeast => Lakeside Drive Northeast
# Mountain Drive Northeast => Mountain Drive Northeast
# Kay Lane Northeast => Kay Lane Northeast
# Spruce Street Northeast => Spruce Street Northeast
# Elizabeth Street Northeast => Elizabeth Street Northeast
# Haverhill Drive Northeast => Haverhill Drive Northeast
# Churchill Downs Road Northeast => Churchill Downs Road Northeast
# Catina Court Northeast => Catina Court Northeast
# Linwood Avenue Northeast => Linwood Avenue Northeast
# La France Street Northeast => La France Street Northeast
# Forest Hills Drive Northeast => Forest Hills Drive Northeast
# Cherrywood Lane Northeast => Cherrywood Lane Northeast
# Northwood Avenue Northeast => Northwood Avenue Northeast
# North Hills Drive Northeast => North Hills Drive Northeast
# Moores Club Place Northeast => Moores Club Place Northeast
# Clementstone Drive Northeast => Clementstone Drive Northeast
# Halah Circle Northeast => Halah Circle Northeast
# Cromwell Road Northeast => Cromwell Road Northeast
# Los Angeles Avenue Northeast => Los Angeles Avenue Northeast
# Glenridge Drive Northeast => Glenridge Drive Northeast
# Starlight Circle Northeast => Starlight Circle Northeast
# Spruell Springs Road Northeast => Spruell Springs Road Northeast
# Robin Hood Road Northeast => Robin Hood Road Northeast
# Allgood Road Northeast => Allgood Road Northeast
# Dekalb Avenue Northeast => Dekalb Avenue Northeast
# Willow Creek Drive Northeast => Willow Creek Drive Northeast
# Camden Park Court Northeast => Camden Park Court Northeast
# High Point Place Northeast => High Point Place Northeast
# Ponce de Leon Terrace Northeast => Ponce de Leon Terrace Northeast
# McClatchey Circle Northeast => McClatchey Circle Northeast
# West Sussex Road Northeast => West Sussex Road Northeast
# Rosedale Drive Northeast => Rosedale Drive Northeast
# Lee Circle Northeast => Lee Circle Northeast
# Oakdale Road Northeast => Oakdale Road Northeast
# Lakemoore Drive Northeast => Lakemoore Drive Northeast
# McGruder Street Northeast => McGruder Street Northeast
# Wildwood Road Northeast => Wildwood Road Northeast
# Candler Street Northeast => Candler Street Northeast
# Morosgo Way Northeast => Morosgo Way Northeast
# Sunny Brook Lane Northeast => Sunny Brook Lane Northeast
# Carolwood Lane Northeast => Carolwood Lane Northeast
# Old Ivy Road Northeast => Old Ivy Road Northeast
# Falcon Chase Lane Northeast => Falcon Chase Lane Northeast
# Carmain Drive Northeast => Carmain Drive Northeast
# Royervista Drive Northeast => Royervista Drive Northeast
# Saratoga Place Northeast => Saratoga Place Northeast
# Windsor Parkway Northeast => Windsor Parkway Northeast
# Baker Street Northeast => Baker Street Northeast
# Hillswick Court Northeast => Hillswick Court Northeast
# Brook Drive Northeast => Brook Drive Northeast
# Garber Drive Northeast => Garber Drive Northeast
# Pine Street Northeast => Pine Street Northeast
# Lake Forrest Lane Northeast => Lake Forrest Lane Northeast
# West Kingston Court Northeast => West Kingston Court Northeast
# Bridges Creek Trail Northeast => Bridges Creek Trail Northeast
# Lindridge Way Northeast => Lindridge Way Northeast
# Park Place Northeast => Park Place Northeast
# Walthall Street Northeast => Walthall Street Northeast
# Ponce de Leon Place Northeast => Ponce de Leon Place Northeast
# Laurel Drive Northeast => Laurel Drive Northeast
# Calhoun Road Northeast => Calhoun Road Northeast
# Virginia Place Northeast => Virginia Place Northeast
# East Northway Lane Northeast => East Northway Lane Northeast
# Cumberland Circle Northeast => Cumberland Circle Northeast
# Mobile Avenue Northeast => Mobile Avenue Northeast
# Prince Avenue Northeast => Prince Avenue Northeast
# Caroline Street Northeast => Caroline Street Northeast
# Merry Lane Northeast => Merry Lane Northeast
# Virginia Circle Northeast => Virginia Circle Northeast
# Heritage Way Northeast => Heritage Way Northeast
# Forest Valley Road Northeast => Forest Valley Road Northeast
# Chaseland Road Northeast => Chaseland Road Northeast
# Pasadena Avenue Northeast => Pasadena Avenue Northeast
# Hunters Trace Circle Northeast => Hunters Trace Circle Northeast
# Miami Circle Northeast => Miami Circle Northeast
# Tree Haven Drive Northeast => Tree Haven Drive Northeast
# Mabry Road Northeast => Mabry Road Northeast
# Winslow Drive Northeast => Winslow Drive Northeast
# Taft Avenue Northeast => Taft Avenue Northeast
# Brighton Road Northeast => Brighton Road Northeast
# Lampkin Street Northeast => Lampkin Street Northeast
# South Prado Northeast => South Prado Northeast
# Craighead Drive Northeast => Craighead Drive Northeast
# Ivy Ridge Northeast => Ivy Ridge Northeast
# Ellwood Drive Northeast => Ellwood Drive Northeast
# Chadds Lake Drive Northeast => Chadds Lake Drive Northeast
# Willow Avenue Northeast => Willow Avenue Northeast
# 14th Street Northeast => 14th Street Northeast
# Seal Place Northeast => Seal Place Northeast
# Angelo Court Northeast => Angelo Court Northeast
# Juniper Street Northeast => Juniper Street Northeast
# Myrtle Street Northeast => Myrtle Street Northeast
# Boulevard Place Northeast => Boulevard Place Northeast
# Old Maine Trail Northeast => Old Maine Trail Northeast
# West Belle Isle Road Northeast => West Belle Isle Road Northeast
# Roxboro Drive Northeast => Roxboro Drive Northeast
# San Antonio Drive Northeast => San Antonio Drive Northeast
# Inverness Avenue Northeast => Inverness Avenue Northeast
# Dale Drive Northeast => Dale Drive Northeast
# West Northway Lane Northeast => West Northway Lane Northeast
# Kilburn Drive Northeast => Kilburn Drive Northeast
# Harleston Road Northeast => Harleston Road Northeast
# Homestead Avenue Northeast => Homestead Avenue Northeast
# Robinson Road Northeast => Robinson Road Northeast
# 11th Street Northeast => 11th Street Northeast
# West Roxboro Road Northeast => West Roxboro Road Northeast
# Hilderbrand Drive Northeast => Hilderbrand Drive Northeast
# Peachtree Way Northeast => Peachtree Way Northeast
# Hudson Drive Northeast => Hudson Drive Northeast
# Berwick Avenue Northeast => Berwick Avenue Northeast
# Lanier Place Northeast => Lanier Place Northeast
# East Paces Ferry Road Northeast => East Paces Ferry Road Northeast
# Virginia Avenue Northeast => Virginia Avenue Northeast
# Courtland Street Northeast => Courtland Street Northeast
# Jamerson Road Northeast => Jamerson Road Northeast
# Emma Lane Northeast => Emma Lane Northeast
# Kayron Drive Northeast => Kayron Drive Northeast
# Glenairy Drive Northeast => Glenairy Drive Northeast
# Highland Terrace Northeast => Highland Terrace Northeast
# Vedado Way Northeast => Vedado Way Northeast
# Longleaf Drive Northeast => Longleaf Drive Northeast
# Stonington Drive Northeast => Stonington Drive Northeast
# North Highland Avenue Northeast => North Highland Avenue Northeast
# Silverwood Road Northeast => Silverwood Road Northeast
# Westerhall Court Northeast => Westerhall Court Northeast
# Courtenay Drive Northeast => Courtenay Drive Northeast
# Montclair Drive Northeast => Montclair Drive Northeast
# Cliftwood Drive Northeast => Cliftwood Drive Northeast
# Dickson Place Northeast => Dickson Place Northeast
# Adina Drive Northeast => Adina Drive Northeast
# Barksdale Drive Northeast => Barksdale Drive Northeast
# Rumson Road Northeast => Rumson Road Northeast
# Ellis Street Northeast => Ellis Street Northeast
# Club Circle Northeast => Club Circle Northeast
# Barfield Road Northeast => Barfield Road Northeast
# Dogwood Valley Drive Northeast => Dogwood Valley Drive Northeast
# Highbury Lane Northeast => Highbury Lane Northeast
# Robin Lane Northeast => Robin Lane Northeast
# Highland Park Lane Northeast => Highland Park Lane Northeast
# Hunt Street Northeast => Hunt Street Northeast
# Rockledge Road Northeast => Rockledge Road Northeast
# Buford Highway Northeast => Buford Highway Northeast
# Dutch Valley Place Northeast => Dutch Valley Place Northeast
# Aldwych Lane Northeast => Aldwych Lane Northeast
# Austin Avenue Northeast => Austin Avenue Northeast
# Hunters Knoll Northeast => Hunters Knoll Northeast
# Brandon Place Northeast => Brandon Place Northeast
# Wabash Avenue Northeast => Wabash Avenue Northeast
# Landmark Drive Northeast => Landmark Drive Northeast
# High Point Road Northeast => High Point Road Northeast
# Northview Avenue Northeast => Northview Avenue Northeast
# Pine Ridge Road Northeast => Pine Ridge Road Northeast
# Greenlaurel Drive Northeast => Greenlaurel Drive Northeast
# Midtown Place Northeast => Midtown Place Northeast
# Zimmer Drive Northeast => Zimmer Drive Northeast
# Atwood Road Northeast => Atwood Road Northeast
# Cardova Drive Northeast => Cardova Drive Northeast
# Cherry Tree Lane Northeast => Cherry Tree Lane Northeast
# Hardeman Road Northeast => Hardeman Road Northeast
# Scufflegrit Road Northeast => Scufflegrit Road Northeast
# Glencourtney Drive Northeast => Glencourtney Drive Northeast
# Lavista Road Northeast => Lavista Road Northeast
# Windsor Gate Court Northeast => Windsor Gate Court Northeast
# Cambridge Way Northeast => Cambridge Way Northeast
# Kentucky Avenue Northeast => Kentucky Avenue Northeast
# Glengary Court Northeast => Glengary Court Northeast
# Mansfield Avenue Northeast => Mansfield Avenue Northeast
# Fowler Circle Northeast => Fowler Circle Northeast
# Angelo Drive Northeast => Angelo Drive Northeast
# North Stratford Road Northeast => North Stratford Road Northeast
# Holly Springs Road Northeast => Holly Springs Road Northeast
# Wright Road Northeast => Wright Road Northeast
# Floyd Street Northeast => Floyd Street Northeast
# Summer Terrace Lane Northeast => Summer Terrace Lane Northeast
# Allen Road Northeast => Allen Road Northeast
# Palisades Road Northeast => Palisades Road Northeast
# Darlington Road Northeast => Darlington Road Northeast
# Putnam Circle Northeast => Putnam Circle Northeast
# Piedmont Circle Northeast => Piedmont Circle Northeast
# Birchwood Drive Northeast => Birchwood Drive Northeast
# Flagler Avenue Northeast => Flagler Avenue Northeast
# Loridans Drive Northeast => Loridans Drive Northeast
# Oxford Road Northeast => Oxford Road Northeast
# Peachtree Street Northeast => Peachtree Street Northeast
# Dalmer Road Northeast => Dalmer Road Northeast
# Greenbrier Road Northeast => Greenbrier Road Northeast
# Timberlane Terrace Northeast => Timberlane Terrace Northeast
# High Point Lane Northeast => High Point Lane Northeast
# Carlton Drive Northeast => Carlton Drive Northeast
# Starlight Drive Northeast => Starlight Drive Northeast
# Pinecrest Road Northeast => Pinecrest Road Northeast
# Druid Valley Drive Northeast => Druid Valley Drive Northeast
# Washita Avenue Northeast => Washita Avenue Northeast
# Howell Street Northeast => Howell Street Northeast
# Ivy Park Lane Northeast => Ivy Park Lane Northeast
# Longchamps Drive Northeast => Longchamps Drive Northeast
# Spalding Trail Northeast => Spalding Trail Northeast
# Elliott Circle Northeast => Elliott Circle Northeast
# Osner Drive Northeast => Osner Drive Northeast
# 15th Street Northeast => 15th Street Northeast
# Hitchcock Mill Run Northeast => Hitchcock Mill Run Northeast
# Ansley Drive Northeast => Ansley Drive Northeast
# Courtenay Court Northeast => Courtenay Court Northeast
# Helen Drive Northeast => Helen Drive Northeast
# 8th Street Northeast => 8th Street Northeast
# Kingsboro Road Northeast => Kingsboro Road Northeast
# Park Drive Northeast => Park Drive Northeast
# Rockridge Place Northeast => Rockridge Place Northeast
# Maddox Drive Northeast => Maddox Drive Northeast
# West Wieuca Road Northeast => West Wieuca Road Northeast
# Stovall Terrace Northeast => Stovall Terrace Northeast
# Carmel Avenue Northeast => Carmel Avenue Northeast
# High Point Walk Northeast => High Point Walk Northeast
# Highland Drive Northeast => Highland Drive Northeast
# Iverson Street Northeast => Iverson Street Northeast
# Winfield Glen Court Northeast => Winfield Glen Court Northeast
# Eulalia Road Northeast => Eulalia Road Northeast
# Huntley Drive Northeast => Huntley Drive Northeast
# Clubland Drive Northeast => Clubland Drive Northeast
# West Brookhaven Drive Northeast => West Brookhaven Drive Northeast
# Timm Valley Road Northeast => Timm Valley Road Northeast
# Boylston Drive Northeast => Boylston Drive Northeast
# Arlington Place Northeast => Arlington Place Northeast
# East Drive Northeast => East Drive Northeast
# Sandy Springs Circle Northeast => Sandy Springs Circle Northeast
# Stratford Road Northeast => Stratford Road Northeast
# Beverly Road Northeast => Beverly Road Northeast
# Rosedale Road Northeast => Rosedale Road Northeast
# Hayes Industrial Drive Northeast => Hayes Industrial Drive Northeast
# Plasamour Drive Northeast => Plasamour Drive Northeast
# Wynhill Drive Northeast => Wynhill Drive Northeast
# North Buckhead Drive Northeast => North Buckhead Drive Northeast
# Duncourtney Drive Northeast => Duncourtney Drive Northeast
# Hillpine Drive Northeast => Hillpine Drive Northeast
# Timber Trail Northeast => Timber Trail Northeast
# Euclid Terrace Northeast => Euclid Terrace Northeast
# Haralson Avenue Northeast => Haralson Avenue Northeast
# Bonnie Lane Northeast => Bonnie Lane Northeast
# Childers Pond Overlook Northeast => Childers Pond Overlook Northeast
# Mystic Drive Northeast => Mystic Drive Northeast
# Hardman Court Northeast => Hardman Court Northeast
# Skyland Drive Northeast => Skyland Drive Northeast
# Brookfield Drive Northeast => Brookfield Drive Northeast
# Manchester Street Northeast => Manchester Street Northeast
# Barnes Mill Road Northeast => Barnes Mill Road Northeast
# Weeping Oak Trace Northeast => Weeping Oak Trace Northeast
# Brentwood Drive Northeast => Brentwood Drive Northeast
# Rivoli Circle Northeast => Rivoli Circle Northeast
# Hogue Street Northeast => Hogue Street Northeast
# Benton Woods Drive Northeast => Benton Woods Drive Northeast
# Ivy Road Northeast => Ivy Road Northeast
# Trophy Drive Northeast => Trophy Drive Northeast
# Briarcliff Court Northeast => Briarcliff Court Northeast
# Amherst Court Northeast => Amherst Court Northeast
# The Prado Northeast => The Prado Northeast
# Elkmont Drive Northeast => Elkmont Drive Northeast
# Bonaventure Avenue Northeast => Bonaventure Avenue Northeast
# Lookout Place Northeast => Lookout Place Northeast
# Statewood Road Northeast => Statewood Road Northeast
# Johnson Road Northeast => Johnson Road Northeast
# Drummen Court Northeast => Drummen Court Northeast
# Stone Mill Trail Northeast => Stone Mill Trail Northeast
# Vernon Woods Drive Northeast => Vernon Woods Drive Northeast
# Whispering Way Northeast => Whispering Way Northeast
# Ridgeland Way Northeast => Ridgeland Way Northeast
# Sherrell Drive Northeast => Sherrell Drive Northeast
# Wimbledon Road Northeast => Wimbledon Road Northeast
# Dalrymple Road Northeast => Dalrymple Road Northeast
# Vallo Vista Court Northeast => Vallo Vista Court Northeast
# Alberta Drive Northeast => Alberta Drive Northeast
# Elden Drive Northeast => Elden Drive Northeast
# Twin Branch Lane Northeast => Twin Branch Lane Northeast
# Old Wheat Street Northeast => Old Wheat Street Northeast
# Kennesaw Avenue Northeast => Kennesaw Avenue Northeast
# Armand Road Northeast => Armand Road Northeast
# Kingston Drive Northeast => Kingston Drive Northeast
# Drewry Street Northeast => Drewry Street Northeast
# Prospect Place Northeast => Prospect Place Northeast
# Ferry Drive Northeast => Ferry Drive Northeast
# Basswood Circle Northeast => Basswood Circle Northeast
# Wayne Avenue Northeast => Wayne Avenue Northeast
# Cooledge Avenue Northeast => Cooledge Avenue Northeast
# Reeder Circle Northeast => Reeder Circle Northeast
# Marietta Industrial Drive Northeast => Marietta Industrial Drive Northeast
# Ashebrooke Drive Northeast => Ashebrooke Drive Northeast
# Greenview Avenue Northeast => Greenview Avenue Northeast
# North Avenue Northeast => North Avenue Northeast
# Industrial Park Drive Northeast => Industrial Park Drive Northeast
# Golf Circle Northeast => Golf Circle Northeast
# Ivy Lane Northeast => Ivy Lane Northeast
# Glenlake Parkway Northeast => Glenlake Parkway Northeast
# The Croft Northeast => The Croft Northeast
# Adair Avenue Northeast => Adair Avenue Northeast
# Woodcrest Avenue Northeast => Woodcrest Avenue Northeast
# Berkshire Road Northeast => Berkshire Road Northeast
# Darlington Circle Northeast => Darlington Circle Northeast
# 17th Street Northeast => 17th Street Northeast
# Chipley Street Northeast => Chipley Street Northeast
# Dunhill Terrace Northeast => Dunhill Terrace Northeast
# Greenland Road Northeast => Greenland Road Northeast
# Angier Avenue Northeast => Angier Avenue Northeast
# Sampson Street Northeast => Sampson Street Northeast
# Whispering Trail Northeast => Whispering Trail Northeast
# Hurst Drive Northeast => Hurst Drive Northeast
# Rock Springs Road Northeast => Rock Springs Road Northeast
# Elizabeth Ann Lane Northeast => Elizabeth Ann Lane Northeast
# The Chace Northeast => The Chace Northeast
# Bellaire Drive Northeast => Bellaire Drive Northeast
# Crane Road Northeast => Crane Road Northeast
# Fordham Court Northeast => Fordham Court Northeast
# Wakefield Drive Northeast => Wakefield Drive Northeast
# Battery Place Northeast => Battery Place Northeast
# Pine Tree Drive Northeast => Pine Tree Drive Northeast
# Rose Gate Drive Northeast => Rose Gate Drive Northeast
# Parkgate Drive Northeast => Parkgate Drive Northeast
# Moreland Avenue Northeast => Moreland Avenue Northeast
# Chelsea Park Drive Northeast => Chelsea Park Drive Northeast
# Valley Lane Northeast => Valley Lane Northeast
# Noble Drive Northeast => Noble Drive Northeast
# Rosewood Drive Northeast => Rosewood Drive Northeast
# Timberland Drive Northeast => Timberland Drive Northeast
# Brookgreen Road Northeast => Brookgreen Road Northeast
# Mountain Way Northeast => Mountain Way Northeast
# Druid Circle Northeast => Druid Circle Northeast
# Morosgo Drive Northeast => Morosgo Drive Northeast
# Wieuca Trace Northeast => Wieuca Trace Northeast
# Vance Avenue Northeast => Vance Avenue Northeast
# 7th Street Northeast => 7th Street Northeast
# Melante Drive Northeast => Melante Drive Northeast
# Bonview Lane Northeast => Bonview Lane Northeast
# 13th Street Northeast => 13th Street Northeast
# West Shadowlawn Avenue Northeast => West Shadowlawn Avenue Northeast
# Sharondale Drive Northeast => Sharondale Drive Northeast
# Jackson Street Northeast => Jackson Street Northeast
# Rupley Drive Northeast => Rupley Drive Northeast
# Springdale Drive Northeast => Springdale Drive Northeast
# Forrest Way Northeast => Forrest Way Northeast
# Piedmont Way Northeast => Piedmont Way Northeast
# Lenox Hill Court Northeast => Lenox Hill Court Northeast
# Princeton Way Northeast => Princeton Way Northeast
# Pintail Point Northeast => Pintail Point Northeast
# South Trimble Road Northeast => South Trimble Road Northeast
# Peachtree Circle Northeast => Peachtree Circle Northeast
# Carpenter Drive Northeast => Carpenter Drive Northeast
# Kings Circle Northeast => Kings Circle Northeast
# Wieuca Road Northeast => Wieuca Road Northeast
# Twin Branch Road Northeast => Twin Branch Road Northeast
# Roanoke Avenue Northeast => Roanoke Avenue Northeast
# Lakeview Avenue Northeast => Lakeview Avenue Northeast
# Hutchinson Street Northeast => Hutchinson Street Northeast
# Sinclair Avenue Northeast => Sinclair Avenue Northeast
# Williams Mill Road Northeast => Williams Mill Road Northeast
# Merrick Drive Northeast => Merrick Drive Northeast
# Interlaken Drive Northeast => Interlaken Drive Northeast
# Franklin Road Northeast => Franklin Road Northeast
# Hedden Street Northeast => Hedden Street Northeast
# Alpine Road Northeast => Alpine Road Northeast
# Crestwicke Pointe Northeast => Crestwicke Pointe Northeast
# McLynn Avenue Northeast => McLynn Avenue Northeast
# Greystone Park Northeast => Greystone Park Northeast
# Dunhill Court Northeast => Dunhill Court Northeast
# Marion Avenue Northeast => Marion Avenue Northeast
# Buckhead Trace Northeast => Buckhead Trace Northeast
# Pharr Road Northeast => Pharr Road Northeast
# Barclay Place Northeast => Barclay Place Northeast
# Charline Avenue Northeast => Charline Avenue Northeast
# Greenland Drive Northeast => Greenland Drive Northeast
# Waterford Court Northeast => Waterford Court Northeast
# Maryland Avenue Northeast => Maryland Avenue Northeast
# Plymouth Road Northeast => Plymouth Road Northeast
# Goodwin Road Northeast => Goodwin Road Northeast
# Peachtree Drive Northeast => Peachtree Drive Northeast
# Peachtree Place Northeast => Peachtree Place Northeast
# Arden Way Northeast => Arden Way Northeast
# Blue Ridge Avenue Northeast => Blue Ridge Avenue Northeast
# Lorell Terrace Northeast => Lorell Terrace Northeast
# Hunters Branch Drive Northeast => Hunters Branch Drive Northeast
# Brandon Ridge Drive Northeast => Brandon Ridge Drive Northeast
# Berwick Drive Northeast => Berwick Drive Northeast
# Wellons Street Northeast => Wellons Street Northeast
# Lanier Boulevard Northeast => Lanier Boulevard Northeast
# Vivian Lane Northeast => Vivian Lane Northeast
# Fairville Court Northeast => Fairville Court Northeast
# Starlight Lane Northeast => Starlight Lane Northeast
# Sandy Plains Road Northeast => Sandy Plains Road Northeast
# Shallowford Road Northeast => Shallowford Road Northeast
# Fairview Road Northeast => Fairview Road Northeast
# Hampton Way Northeast => Hampton Way Northeast
# Cumberland Road Northeast => Cumberland Road Northeast
# Springside Court Northeast => Springside Court Northeast
# Macklone Street Northeast => Macklone Street Northeast
# East Piedmont Road Northeast => East Piedmont Road Northeast
# Woodmoore Court Northeast => Woodmoore Court Northeast
# Peachtree Dunwoody Road Northeast => Peachtree Dunwoody Road Northeast
# Aberdeen Drive Northeast => Aberdeen Drive Northeast
# John Wesley Dobbs Avenue Northeast => John Wesley Dobbs Avenue Northeast
# Elmira Place Northeast => Elmira Place Northeast
# Bransford Road Northeast => Bransford Road Northeast
# North Morningside Drive Northeast => North Morningside Drive Northeast
# Fortune Street Northeast => Fortune Street Northeast
# Inwood Circle Northeast => Inwood Circle Northeast
# Dixie Avenue Northeast => Dixie Avenue Northeast
# Hollyfax Circle Northeast => Hollyfax Circle Northeast
# Francyne Court Northeast => Francyne Court Northeast
# Bolling Road Northeast => Bolling Road Northeast
# Shady Valley Drive Northeast => Shady Valley Drive Northeast
# Wessex Court Northeast => Wessex Court Northeast
# Marion Place Northeast => Marion Place Northeast
# Inman Circle Northeast => Inman Circle Northeast
# Armour Drive Northeast => Armour Drive Northeast
# North Hampton Drive Northeast => North Hampton Drive Northeast
# Crestridge Drive Northeast => Crestridge Drive Northeast
# Read Lane Northeast => Read Lane Northeast
# Ashley Avenue Northeast => Ashley Avenue Northeast
# Nassau Way Northeast => Nassau Way Northeast
# Fenwick Place Northeast => Fenwick Place Northeast
# Wendover Drive Northeast => Wendover Drive Northeast
# Thornhill Lane Northeast => Thornhill Lane Northeast
# Northglenn Court Northeast => Northglenn Court Northeast
# Piedmont Avenue Northeast => Piedmont Avenue Northeast
# Steinhauer Road Northeast => Steinhauer Road Northeast
# Ponce de Leon Avenue Northeast => Ponce de Leon Avenue Northeast
# Stewart Drive Northeast => Stewart Drive Northeast
# Northrope Drive Northeast => Northrope Drive Northeast
# Gotham Way Northeast => Gotham Way Northeast
# Greystone Court Northeast => Greystone Court Northeast
# Lower Roswell Road Northeast => Lower Roswell Road Northeast
# Glenridge Close Drive Northeast => Glenridge Close Drive Northeast
# Wright Circle Northeast => Wright Circle Northeast
# Strathmore Drive Northeast => Strathmore Drive Northeast
# Wessyngton Road Northeast => Wessyngton Road Northeast
# Elmwood Drive Northeast => Elmwood Drive Northeast
# Somerset Terrace Northeast => Somerset Terrace Northeast
# Winall Down Road Northeast => Winall Down Road Northeast
# Woodsdale Road Northeast => Woodsdale Road Northeast
# Sharondale Court Northeast => Sharondale Court Northeast
# Ivy Parkway Northeast => Ivy Parkway Northeast
# North Virginia Avenue Northeast => North Virginia Avenue Northeast
# Meadow Valley Drive Northeast => Meadow Valley Drive Northeast
# Hammond Drive Northeast => Hammond Drive Northeast
# Sidney Marcus Boulevard Northeast => Sidney Marcus Boulevard Northeast
# Calvert Lane Northeast => Calvert Lane Northeast
# Walker Terrace Northeast => Walker Terrace Northeast
# Indian Hills Parkway Northeast => Indian Hills Parkway Northeast
# Lakeview Drive Northeast => Lakeview Drive Northeast
# Glenforest Road Northeast => Glenforest Road Northeast
# Montgomery Ferry Drive Northeast => Montgomery Ferry Drive Northeast
# Taunton Way Northeast => Taunton Way Northeast
# Sheldon Drive Northeast => Sheldon Drive Northeast
# Merton Road Northeast => Merton Road Northeast
# Northgreen Drive Northeast => Northgreen Drive Northeast
# Old College Way Northeast => Old College Way Northeast
# Brixham Court Northeast => Brixham Court Northeast
# Jolyn Place Northeast => Jolyn Place Northeast
# Lindridge Drive Northeast => Lindridge Drive Northeast
# Ferncliff Road Northeast => Ferncliff Road Northeast
# Old Woodbine Road Northeast => Old Woodbine Road Northeast
# Highland View Northeast => Highland View Northeast
# White Oak Hollow Northeast => White Oak Hollow Northeast
# The South Chace Northeast => The South Chace Northeast
# Whittington Drive Northeast => Whittington Drive Northeast
# Selkirk Drive Northeast => Selkirk Drive Northeast
# Montevallo Drive Northeast => Montevallo Drive Northeast
# Hale Street Northeast => Hale Street Northeast
# Kitty Hawk Drive Northeast => Kitty Hawk Drive Northeast
# Chastain Park Court Northeast => Chastain Park Court Northeast
# Hunting Creek Road Northeast => Hunting Creek Road Northeast
# Highland Avenue Northeast => Highland Avenue Northeast
# Carter Drive Northeast => Carter Drive Northeast
# Old Campus Trail Northeast => Old Campus Trail Northeast
# Sterling Street Northeast => Sterling Street Northeast
# Delmont Drive Northeast => Delmont Drive Northeast
# Ashford Dunwoody Road Northeast => Ashford Dunwoody Road Northeast
# Stillwood Drive Northeast => Stillwood Drive Northeast
# Waterfront Circle Northeast => Waterfront Circle Northeast
# Windsor Park Place Northeast => Windsor Park Place Northeast
# Clemont Drive Northeast => Clemont Drive Northeast
# Windham Park Northeast => Windham Park Northeast
# North Ivy Road Northeast => North Ivy Road Northeast
# 6th Street Northeast => 6th Street Northeast
# Glen Iris Drive Northeast => Glen Iris Drive Northeast
# West Club Drive Northeast => West Club Drive Northeast
# Monroe Drive Northeast => Monroe Drive Northeast
# Hawthorne Street Northeast => Hawthorne Street Northeast
# Sherwood Road Northeast => Sherwood Road Northeast
# Arnold Street Northeast => Arnold Street Northeast
# Sudbury Road Northeast => Sudbury Road Northeast
# Amsterdam Avenue Northeast => Amsterdam Avenue Northeast
# Candler Park Drive Northeast => Candler Park Drive Northeast
# Telford Place Northeast => Telford Place Northeast
# Cresthill Avenue Northeast => Cresthill Avenue Northeast
# Rose Court Northeast => Rose Court Northeast
# Allison Drive Northeast => Allison Drive Northeast
# Carriage Drive Northeast => Carriage Drive Northeast
# Canter Road Northeast => Canter Road Northeast
# Manor House Drive Northeast => Manor House Drive Northeast
# Buckhead Avenue Northeast => Buckhead Avenue Northeast
# Marilyn Place Northeast => Marilyn Place Northeast
# West Ferry Drive Northeast => West Ferry Drive Northeast
# Wellbourne Drive Northeast => Wellbourne Drive Northeast
# Lenox Place Northeast => Lenox Place Northeast
# Land O Lakes Drive Northeast => Land O Lakes Drive Northeast
# Springdale Road Northeast => Springdale Road Northeast
# Alco Street Northeast => Alco Street Northeast
# Pelham Road Northeast => Pelham Road Northeast
# Pine Circle Northeast => Pine Circle Northeast
# Avery Drive Northeast => Avery Drive Northeast
# Doncaster Drive Northeast => Doncaster Drive Northeast
# Wyncourtney Drive Northeast => Wyncourtney Drive Northeast
# Winton Terrace Northeast => Winton Terrace Northeast
# Lenox Pointe Northeast => Lenox Pointe Northeast
# Starlight Court Northeast => Starlight Court Northeast
# East Powderhorn Road Northeast => East Powderhorn Road Northeast
# Brentwood Terrace Northeast => Brentwood Terrace Northeast
# Carlton Ridge Northeast => Carlton Ridge Northeast
# 10th Street Northeast => 10th Street Northeast
# Benning Place Northeast => Benning Place Northeast
# Old Ivy Lane Northeast => Old Ivy Lane Northeast
# Stovall Boulevard Northeast => Stovall Boulevard Northeast
# Zeblin Road Northeast => Zeblin Road Northeast
# Frederica Street Northeast => Frederica Street Northeast
# Orme Circle Northeast => Orme Circle Northeast
# Rickenbacker Way Northeast => Rickenbacker Way Northeast
# Whittington Court Northeast => Whittington Court Northeast
# 4th Street Northeast => 4th Street Northeast
# Abington Drive Northeast => Abington Drive Northeast
# Waddell Street Northeast => Waddell Street Northeast
# Monroe Circle Northeast => Monroe Circle Northeast
# Penn Avenue Northeast => Penn Avenue Northeast
# Glenwood Drive Northeast => Glenwood Drive Northeast
# Lake Avenue Northeast => Lake Avenue Northeast
# Parkway Drive Northeast => Parkway Drive Northeast
# Argonne Avenue Northeast => Argonne Avenue Northeast
# Cantrell Road Northeast => Cantrell Road Northeast
# Land O Lakes Court Northeast => Land O Lakes Court Northeast
# Green Hill Place Northeast => Green Hill Place Northeast
# Dresden Drive Northeast => Dresden Drive Northeast
# Westfield Drive Northeast => Westfield Drive Northeast
# Jefferson Circle Northeast => Jefferson Circle Northeast
# Edgewood Avenue Northeast => Edgewood Avenue Northeast
# Alta Avenue Northeast => Alta Avenue Northeast
# Martina Drive Northeast => Martina Drive Northeast
# Brinkley Lane Northeast => Brinkley Lane Northeast
# Conifer Circle Northeast => Conifer Circle Northeast
# 3rd Street Northeast => 3rd Street Northeast
# Avalon Place Northeast => Avalon Place Northeast
# Williamson Drive Northeast => Williamson Drive Northeast
# Wildwood Place Northeast => Wildwood Place Northeast
# Herrington Drive Northeast => Herrington Drive Northeast
# Peachtree Avenue Northeast => Peachtree Avenue Northeast
# Nell Court Northeast => Nell Court Northeast
# Cleburne Avenue Northeast => Cleburne Avenue Northeast
# Tall Oaks Drive Northeast => Tall Oaks Drive Northeast
# West Oak Parkway Northeast => West Oak Parkway Northeast
# Vermont Road Northeast => Vermont Road Northeast
# Balmoral Road Northeast => Balmoral Road Northeast
# East Club Lane Northeast => East Club Lane Northeast
# Angus Trail Northeast => Angus Trail Northeast
# East Pelham Road Northeast => East Pelham Road Northeast
# Whispering Lane Northeast => Whispering Lane Northeast
# Brookwood Drive Northeast => Brookwood Drive Northeast
# Vale Close Northeast => Vale Close Northeast
# Midvale Drive Northeast => Midvale Drive Northeast
# Colquitt Avenue Northeast => Colquitt Avenue Northeast
# The North Chace Northeast => The North Chace Northeast
# Rockhaven Circle Northeast => Rockhaven Circle Northeast
# Delta Place Northeast => Delta Place Northeast
# Lafayette Drive Northeast => Lafayette Drive Northeast
# 5th Street Northeast => 5th Street Northeast
# Greenwood Avenue Northeast => Greenwood Avenue Northeast
# Flora Avenue Northeast => Flora Avenue Northeast
# Fairhaven Circle Northeast => Fairhaven Circle Northeast
# Shiver Summit Northeast => Shiver Summit Northeast
# Mountain Creek Road Northeast => Mountain Creek Road Northeast
# Burke Road Northeast => Burke Road Northeast
# Armand Court Northeast => Armand Court Northeast
# Lansbury Drive Northeast => Lansbury Drive Northeast
# Bruton Way Northeast => Bruton Way Northeast
# Sandy Springs Place Northeast => Sandy Springs Place Northeast
# East Morningside Drive Northeast => East Morningside Drive Northeast
# Old Campus Court Northeast => Old Campus Court Northeast
# Sheridan Drive Northeast => Sheridan Drive Northeast
# Beech Valley Road Northeast => Beech Valley Road Northeast
# Lenox Road Northeast => Lenox Road Northeast
# Middlesex Avenue Northeast => Middlesex Avenue Northeast
# West Bolling Road Northeast => West Bolling Road Northeast
# Yorkshire Road Northeast => Yorkshire Road Northeast
# Mayfair Road Northeast => Mayfair Road Northeast
# Cole Street Northeast => Cole Street Northeast
# St Charles Avenue Northeast => St Charles Avenue Northeast
# Faulkner Road Northeast => Faulkner Road Northeast
# Northland Drive Northeast => Northland Drive Northeast
# Canterbury Road Northeast => Canterbury Road Northeast
# Chemin de Vie Northeast => Chemin de Vie Northeast
# Edison Avenue Northeast => Edison Avenue Northeast
# Westfield Way Northeast => Westfield Way Northeast
# Little John Trail Northeast => Little John Trail Northeast
# Randolph Street Northeast => Randolph Street Northeast
# East Rock Springs Road Northeast => East Rock Springs Road Northeast
# Seminole Drive Northeast => Seminole Drive Northeast
# Park Circle Northeast => Park Circle Northeast
# Bellevue Drive Northeast => Bellevue Drive Northeast
# Overton Drive Northeast => Overton Drive Northeast
# East Avenue Northeast => East Avenue Northeast
# Glenivy Northeast => Glenivy Northeast
# Alpine Way Northeast => Alpine Way Northeast
# West Club Lane Northeast => West Club Lane Northeast
# 12th Street Northeast => 12th Street Northeast
# Crescent Avenue Northeast => Crescent Avenue Northeast
# Park Lane Northeast => Park Lane Northeast
# 14th Place Northeast => 14th Place Northeast
# Beachland Drive Northeast => Beachland Drive Northeast
# Mount Paran Road Northeast => Mount Paran Road Northeast
# Lenox Circle Northeast => Lenox Circle Northeast
# Rankin Street Northeast => Rankin Street Northeast
# Wieuca Terrace Northeast => Wieuca Terrace Northeast
# North Pelham Road Northeast => North Pelham Road Northeast
# Virgil Street Northeast => Virgil Street Northeast
# Spalding Drive Northeast => Spalding Drive Northeast
# Angier Place Northeast => Angier Place Northeast
# Willoughby Way Northeast => Willoughby Way Northeast
# Marsh Trail Circle Northeast => Marsh Trail Circle Northeast
# Valley Brook Drive Northeast => Valley Brook Drive Northeast
# Brackenwood Circle Northeast => Brackenwood Circle Northeast
# Honey Bear Lane Northeast => Honey Bear Lane Northeast
# East Shadowlawn Avenue Northeast => East Shadowlawn Avenue Northeast
# Brookridge Drive Northeast => Brookridge Drive Northeast
# Ravenwood Drive Northeast => Ravenwood Drive Northeast
# Arlington Avenue Northeast => Arlington Avenue Northeast
# Abingdon Way Northeast => Abingdon Way Northeast
# Arlene Way Northeast => Arlene Way Northeast
# Charles Allen Drive Northeast => Charles Allen Drive Northeast
# Laurel Forest Circle Northeast => Laurel Forest Circle Northeast
# Summit Street Northeast => Summit Street Northeast
# Lindbergh Way Northeast => Lindbergh Way Northeast
# Old House Trail Northeast => Old House Trail Northeast
# Barnett Street Northeast => Barnett Street Northeast
# Carlisle Court Northeast => Carlisle Court Northeast
# Willow Glenn Drive Northeast => Willow Glenn Drive Northeast
# Ferguson Street Northeast => Ferguson Street Northeast
# Timber Valley Road Northeast => Timber Valley Road Northeast
# Saint Charles Place Northeast => Saint Charles Place Northeast
# Glen Arden Way Northeast => Glen Arden Way Northeast
# Lebanon Drive Northeast => Lebanon Drive Northeast
# Gaberonne Court Northeast => Gaberonne Court Northeast
# 16th Street Northeast => 16th Street Northeast
# Terrace Drive Northeast => Terrace Drive Northeast
# Briarcliff Place Northeast => Briarcliff Place Northeast
# Castleridge Drive Northeast => Castleridge Drive Northeast
# Eureka Drive Northeast => Eureka Drive Northeast
# Hardee Street Northeast => Hardee Street Northeast
# Sharondale Circle Northeast => Sharondale Circle Northeast
# Forestdale Drive Northeast => Forestdale Drive Northeast
# Wade Street Northeast => Wade Street Northeast
# Trickum Road Northeast => Trickum Road Northeast
# Lakeshore Circle Northeast => Lakeshore Circle Northeast
# Plantation Drive Northeast => Plantation Drive Northeast
# Holiday Avenue Northeast => Holiday Avenue Northeast
# University Drive Northeast => University Drive Northeast
# Dunwoody Springs Drive Northeast => Dunwoody Springs Drive Northeast
# Durant Place Northeast => Durant Place Northeast
# Corley Street Northeast => Corley Street Northeast
# Arizona Avenue Northeast => Arizona Avenue Northeast
# Colton Drive Northeast => Colton Drive Northeast
# Blakely Drive Northeast => Blakely Drive Northeast
# Felton Drive Northeast => Felton Drive Northeast
# Devonwood Drive Northeast => Devonwood Drive Northeast
# Peachtree Hollow Court Northeast => Peachtree Hollow Court Northeast
# Seminole Avenue Northeast => Seminole Avenue Northeast
# Nottingham Way Northeast => Nottingham Way Northeast
# Thomas Court Northeast => Thomas Court Northeast
# Meadowbrook Drive Northeast => Meadowbrook Drive Northeast
# East Belle Isle Road Northeast => East Belle Isle Road Northeast
# Pembrook Place Northeast => Pembrook Place Northeast
# Grandview Avenue Northeast => Grandview Avenue Northeast
# Pickens Industrial Drive Northeast => Pickens Industrial Drive Northeast
# Chateaugay Lane Northeast => Chateaugay Lane Northeast
# Northland Ridge Trail Northeast => Northland Ridge Trail Northeast
# Ridge Mill Lane Northeast => Ridge Mill Lane Northeast
# Camden Road Northeast => Camden Road Northeast
# Irwin Street Northeast => Irwin Street Northeast
# Hurt Street Northeast => Hurt Street Northeast
# Maple Drive Northeast => Maple Drive Northeast
# Cardigan Circle Northeast => Cardigan Circle Northeast
# Kings Court Northeast => Kings Court Northeast
# King Industrial Drive Northeast => King Industrial Drive Northeast
# Stephen Long Drive Northeast => Stephen Long Drive Northeast
# Holt Road Northeast => Holt Road Northeast
# Bell Street Northeast => Bell Street Northeast
# 9th Street Northeast => 9th Street Northeast
# Green Hill Road Northeast => Green Hill Road Northeast
# Roxboro Cove Northeast => Roxboro Cove Northeast
# Luckei Lane Northeast => Luckei Lane Northeast
# Euclid Avenue Northeast => Euclid Avenue Northeast
# Talbot Colony Northeast => Talbot Colony Northeast
# Spalding Gates Drive Northeast => Spalding Gates Drive Northeast
# Westminster Drive Northeast => Westminster Drive Northeast
# Northeast Expressway Northeast => Northeast Expressway Northeast
# Josephine Street Northeast => Josephine Street Northeast
# Trimble Lake Court Northeast => Trimble Lake Court Northeast
# Northway Drive Northeast => Northway Drive Northeast
# Marstevan Drive Northeast => Marstevan Drive Northeast
# Ferncliff Place Northeast => Ferncliff Place Northeast
# Brewer Way Northeast => Brewer Way Northeast
# Windy Ridge Drive Northeast => Windy Ridge Drive Northeast
# Auburn Avenue Northeast => Auburn Avenue Northeast
# Messina Way Northeast => Messina Way Northeast
# Friar Tuck Road Northeast => Friar Tuck Road Northeast
# Linden Avenue Northeast => Linden Avenue Northeast
# Ogilvie Drive Northeast => Ogilvie Drive Northeast
# Brookhaven Springs Court Northeast => Brookhaven Springs Court Northeast
# Morgan Street Northeast => Morgan Street Northeast
# Club Drive Northeast => Club Drive Northeast
# Trimble Crest Drive Northeast => Trimble Crest Drive Northeast
# Hudson Ridge => Hudson Ridge
# Hunters Ridge => Hunters Ridge
# Boston Ridge => Boston Ridge
# Fawn Ridge => Fawn Ridge
# Timber Ridge => Timber Ridge
# Redding Ridge => Redding Ridge
# Paces Lakes Ridge => Paces Lakes Ridge
# Morning Glory Ridge => Morning Glory Ridge
# Stuart Ridge => Stuart Ridge
# Chesapeake Ridge => Chesapeake Ridge
# Neal Ridge => Neal Ridge
# Confederate Ridge => Confederate Ridge
# Medley Ridge => Medley Ridge
# Hearthstone Ridge => Hearthstone Ridge
# Village Ridge => Village Ridge
# Saddle Ridge => Saddle Ridge
# Gold Ridge => Gold Ridge
# Walnut Ridge => Walnut Ridge
# Overlook Ridge => Overlook Ridge
# Hillcrest Ridge => Hillcrest Ridge
# Springharbor Ridge => Springharbor Ridge
# Trotters Ridge => Trotters Ridge
# Fox Ridge => Fox Ridge
# Picketts Ridge => Picketts Ridge
# Mt Vernon Ridge => Mt Vernon Ridge
# Rebel Ridge => Rebel Ridge
# Carolina Ridge => Carolina Ridge
# Partridge Ridge => Partridge Ridge
# Legendary Tarn => Legendary Tarn
# Willow Tarn => Willow Tarn
# Ridge Tarn => Ridge Tarn
# Misty Lake Tarn => Misty Lake Tarn
# Ferry Crossing Tarn => Ferry Crossing Tarn
# Riverside Causeway => Riverside Causeway
# Liberty Heights => Liberty Heights
# Nebo Rd => Nebo Road
# Holder Rd => Holder Road
# Lake Rd => Lake Road
# Windy Hill Rd => Windy Hill Road
# Allatoona Ridge Rd => Allatoona Ridge Road
# Roberts Rd => Roberts Road
# Harmony Grove Rd => Harmony Grove Road
# Ball Ground Rd => Ball Ground Road
# Curtis Miller Rd => Curtis Miller Road
# Bells Ferry Rd => Bells Ferry Road
# King Henry Rd => King Henry Road
# Billings Rd => Billings Road
# Red Barn Rd => Red Barn Road
# Barrett Rd => Barrett Road
# Burch Rd => Burch Road
# Compton Rd => Compton Road
# Adams Rd => Adams Road
# Weeks Rd => Weeks Road
# Reavis Mountain Rd => Reavis Mountain Road
# Stover Rd => Stover Road
# Woodstock Rd => Woodstock Road
# Cochran Ridge Rd => Cochran Ridge Road
# Sam Alexander Rd => Sam Alexander Road
# Old Marietta Rd => Old Marietta Road
# Fernwood Rd => Fernwood Road
# Doke Cohran Rd => Doke Cohran Road
# Golden Rd => Golden Road
# Breezy Valley Rd => Breezy Valley Road
# Old Yorkville Rd => Old Yorkville Road
# Owens Rd => Owens Road
# Arnold Mill Rd => Arnold Mill Road
# Mt Tabor Church Rd => Mt Tabor Church Road
# Mountain Rd => Mountain Road
# Roper Rd => Roper Road
# Hitchcock Rd => Hitchcock Road
# Williams Lake Rd => Williams Lake Road
# Mount Tabor Church Rd => Mount Tabor Church Road
# Jewel Cole Rd => Jewel Cole Road
# Florence Rd => Florence Road
# Old Farm Rd => Old Farm Road
# Little Ridge Rd => Little Ridge Road
# Lower Scott Mill Rd => Lower Scott Mill Road
# Snapfinger Rd => Snapfinger Road
# Hopewell Rd => Hopewell Road
# Rock Cliff Rd => Rock Cliff Road
# Clark Rd => Clark Road
# McCollum Rd => McCollum Road
# Fields Chapel Rd => Fields Chapel Road
# Dooley Rd => Dooley Road
# Jay Green Rd => Jay Green Road
# Quail Ridge Rd => Quail Ridge Road
# Watertank Rd => Watertank Road
# Dupree Rd => Dupree Road
# Colbert Rd => Colbert Road
# Harmony Rd => Harmony Road
# Brooks Rd => Brooks Road
# Lower Birmingham Rd => Lower Birmingham Road
# Dripping Rock Rd => Dripping Rock Road
# Rockbridge Rd => Rockbridge Road
# Upper Bethany Rd => Upper Bethany Road
# Mill Creek Rd => Mill Creek Road
# Steeplechase Rd => Steeplechase Road
# Charles Burgess Rd => Charles Burgess Road
# Rockstore Rd => Rockstore Road
# Tack Cole Rd => Tack Cole Road
# Neese Rd => Neese Road
# Mud Green Rd => Mud Green Road
# Charles Rd => Charles Road
# Sugar Pike Rd => Sugar Pike Road
# Hobart Smith Rd => Hobart Smith Road
# Creighton Rd => Creighton Road
# Gun Range Rd => Gun Range Road
# Edwards Mill Rd => Edwards Mill Road
# Old Howell Bridge Rd => Old Howell Bridge Road
# Lower Bethany Rd => Lower Bethany Road
# McKeown Rd => McKeown Road
# Roberson Rd => Roberson Road
# Tibbitts Rd => Tibbitts Road
# Old Canton Rd => Old Canton Road
# Lower Burris Rd => Lower Burris Road
# Cox Acres Rd => Cox Acres Road
# Thomas Rd => Thomas Road
# Holt Rd => Holt Road
# Billy Bullock Rd => Billy Bullock Road
# Teems Rd => Teems Road
# Rowe Rd => Rowe Road
# Crabapple Rd => Crabapple Road
# Braswell Mountain Rd => Braswell Mountain Road
# Hart Rd => Hart Road
# Morris Rd => Morris Road
# Fate Fuller Rd => Fate Fuller Road
# Macland Rd => Macland Road
# Laird Rd => Laird Road
# Mount Olivet Rd => Mount Olivet Road
# Robin Rd => Robin Road
# Jane Harris Rd => Jane Harris Road
# Jarrell Rd => Jarrell Road
# Lane Rd => Lane Road
# Ridge Rd => Ridge Road
# Cedarcrest Rd => Cedarcrest Road
# Melvin Rd => Melvin Road
# Goode Rd => Goode Road
# Hickory Ridge Rd => Hickory Ridge Road
# Pierce Rd => Pierce Road
# Goodell Rd => Goodell Road
# Handy Rd => Handy Road
# Townsend Rd => Townsend Road
# Trace Rd => Trace Road
# Raccoon Creek Rd => Raccoon Creek Road
# Friendship Church Rd => Friendship Church Road
# Big Springs Rd => Big Springs Road
# Beavers Rd => Beavers Road
# Haney Rd => Haney Road
# Carriage Crk Rd => Carriage Crk Road
# Holland Rd => Holland Road
# Hardin Rd => Hardin Road
# Johnson Brady Rd => Johnson Brady Road
# Little Victoria Rd => Little Victoria Road
# Barron Rd => Barron Road
# Hoisery Mill Rd => Hoisery Mill Road
# Mulberry Rock Rd => Mulberry Rock Road
# Stoker Rd => Stoker Road
# Lazy X Rd => Lazy X Road
# Northridge Rd => Northridge Road
# McGarity Rd => McGarity Road
# Courthouse Rd => Courthouse Road
# Hubbardsville Rd => Hubbardsville Road
# Lost Meadow Rd => Lost Meadow Road
# N Little Victoria Rd => N Little Victoria Road
# Ogle Rd => Ogle Road
# Orange Church Rd => Orange Church Road
# Pleasant Hill Rd => Pleasant Hill Road
# Scoggins Rd => Scoggins Road
# Old Orange Mill Rd => Old Orange Mill Road
# Hughes Rd => Hughes Road
# Northside Church Rd => Northside Church Road
# Melt Anderson Rd => Melt Anderson Road
# Mount Moriah Rd => Mount Moriah Road
# Conns Creek Rd => Conns Creek Road
# Lower Dowdy Mill Rd => Lower Dowdy Mill Road
# Legion Rd => Legion Road
# Floyd Creek Church Rd => Floyd Creek Church Road
# Shrine Lodge Rd => Shrine Lodge Road
# Batesville Rd => Batesville Road
# Barn Rd => Barn Road
# McMichen Rd => McMichen Road
# Watkins Rd => Watkins Road
# Taylor Rd => Taylor Road
# Trinity Church Rd => Trinity Church Road
# Old Sudie Rd => Old Sudie Road
# Shoal Creek Rd => Shoal Creek Road
# King Charles Rd => King Charles Road
# Hames Rd => Hames Road
# Old Billings Rd => Old Billings Road
# Happy Valley Church Rd => Happy Valley Church Road
# Winndale Rd => Winndale Road
# Galts Rd => Galts Road
# Burnie Rd => Burnie Road
# Old Dallas Acworth Rd => Old Dallas Acworth Road
# River Overlook Rd => River Overlook Road
# Graves Rd => Graves Road
# Hospital Rd => Hospital Road
# New Light Rd => New Light Road
# Old Carney Rd => Old Carney Road
# Zion Church Rd => Zion Church Road
# Cedar Crest Rd => Cedar Crest Road
# Rabbit Hill Rd => Rabbit Hill Road
# Dallas Rd => Dallas Road
# Old Bascomb Rd => Old Bascomb Road
# Plantation Rd => Plantation Road
# Garnet Ridge Rd => Garnet Ridge Road
# Old Millertown Rd => Old Millertown Road
# White Oak Church Rd => White Oak Church Road
# Borrow Pit Rd => Borrow Pit Road
# Wrights Mill Rd => Wrights Mill Road
# School Rd => School Road
# Williams Rd => Williams Road
# Lower Victoria Rd => Lower Victoria Road
# Huntgate Rd => Huntgate Road
# Antioch Rd => Antioch Road
# Franklin Goldmine Rd => Franklin Goldmine Road
# Medlock Bridge Rd => Medlock Bridge Road
# Dabbs Bridge Rd => Dabbs Bridge Road
# Banks Rd => Banks Road
# Flatbottom Rd => Flatbottom Road
# Butterworth Rd => Butterworth Road
# Wright Rd => Wright Road
# Liberty Hill Rd => Liberty Hill Road
# Richmond Rd => Richmond Road
# Tippens Rd => Tippens Road
# Old Donaldson Rd => Old Donaldson Road
# Webb Rd => Webb Road
# Land Rd => Land Road
# Old Nelson Rd => Old Nelson Road
# Marietta Rd => Marietta Road
# Able Rd => Able Road
# Paris Rd => Paris Road
# Gun Springs Rd => Gun Springs Road
# Love Rd => Love Road
# Hube Turner Rd => Hube Turner Road
# Cox Rd => Cox Road
# Cherry Grove Rd => Cherry Grove Road
# Garner Rd => Garner Road
# Harmony Grove Church Rd => Harmony Grove Church Road
# Old Dallas Rd => Old Dallas Road
# Coach Bobby Dodd Rd => Coach Bobby Dodd Road
# Taff Rd => Taff Road
# Poplar Springs Rd => Poplar Springs Road
# ...
# Winnview Dr => Winnview Drive
# Byrd Dr => Byrd Drive
# Ridge Crossing Dr => Ridge Crossing Drive
# Big Oak Dr => Big Oak Drive
# O'Farrell Dr => O'Farrell Drive
# Mills Lk Dr => Mills Lk Drive
# Trickum Dr => Trickum Drive
# Middlebrook Dr => Middlebrook Drive
# Hickory Cv Dr => Hickory Cv Drive
# Oak Landing Dr => Oak Landing Drive
# Tall Oaks Dr => Tall Oaks Drive
# Big K Dr => Big K Drive
# Eagle Watch Dr => Eagle Watch Drive
# Fairway Dr => Fairway Drive
# Vickie Dr => Vickie Drive
# Blankenship Dr => Blankenship Drive
# Talcmine Dr => Talcmine Drive
# Eagle Dr => Eagle Drive
# Taylors Farm Dr => Taylors Farm Drive
# Victoria Landing Dr => Victoria Landing Drive
# Birchwood Dr => Birchwood Drive
# Windridge Dr => Windridge Drive
# Cochise Dr => Cochise Drive
# Fitchburg Dr => Fitchburg Drive
# Indian Trail Dr => Indian Trail Drive
# Trenton Dr => Trenton Drive
# Londonderry Dr => Londonderry Drive
# Echo Ridge Dr => Echo Ridge Drive
# Ranch Dr => Ranch Drive
# Annandale Dr => Annandale Drive
# Casablanca Dr => Casablanca Drive
# Falcon Pointe Dr => Falcon Pointe Drive
# Colonial Dr => Colonial Drive
# Hickery Point Dr => Hickery Point Drive
# Blackhawk Dr => Blackhawk Drive
# Ivy Terrace Dr => Ivy Terrace Drive
# Richmond Dr => Richmond Drive
# Braxton Dr => Braxton Drive
# Willow Bend Dr => Willow Bend Drive
# Cape Ivy Dr => Cape Ivy Drive
# Thornbrook Dr => Thornbrook Drive
# Sims Dr => Sims Drive
# Sexton Dr => Sexton Drive
# Cooper Dr => Cooper Drive
# Fred Bishop Dr => Fred Bishop Drive
# Landsdowne Dr => Landsdowne Drive
# Sherwood Forest Dr => Sherwood Forest Drive
# Hope Dr => Hope Drive
# Tower Dr => Tower Drive
# Hickory Knoll Dr => Hickory Knoll Drive
# White Pines Dr => White Pines Drive
# Cedar Ridge Dr => Cedar Ridge Drive
# Quail Hollow Dr => Quail Hollow Drive
# Brock Dr => Brock Drive
# Bell Park Dr => Bell Park Drive
# Smithwyck Dr => Smithwyck Drive
# Vally Creek Dr => Vally Creek Drive
# Creek Hollow Dr => Creek Hollow Drive
# Gwenelyn Dr => Gwenelyn Drive
# Willow Tree Dr => Willow Tree Drive
# Laurel Lake Dr => Laurel Lake Drive
# Austin Dr => Austin Drive
# Lynnwood Dr => Lynnwood Drive
# Keith Dr => Keith Drive
# Gibbs Dr => Gibbs Drive
# Kelly Dr => Kelly Drive
# Sterling Dr => Sterling Drive
# Woodglen Dr => Woodglen Drive
# York Dr => York Drive
# Dons Dr => Dons Drive
# Hagin Dr => Hagin Drive
# Park Creek Dr => Park Creek Drive
# Whitby Dr => Whitby Drive
# Blue Bird Dr => Blue Bird Drive
# Lake Overlook Dr => Lake Overlook Drive
# Brookside Dr => Brookside Drive
# Circle Dr => Circle Drive
# Vaughn Dr => Vaughn Drive
# Rocky Creek Farm Dr => Rocky Creek Farm Drive
# Weatherstone Dr => Weatherstone Drive
# Arnold Mooney Dr => Arnold Mooney Drive
# Carl Barrett Dr => Carl Barrett Drive
# N River Dr => N River Drive
# Lake Arrowhead Dr => Lake Arrowhead Drive
# Glen Oaks Dr => Glen Oaks Drive
# Harbin Dr => Harbin Drive
# S Etowah Dr => S Etowah Drive
# Caracas Dr => Caracas Drive
# Toms Dr => Toms Drive
# Tanglewood Dr => Tanglewood Drive
# Manassas Dr => Manassas Drive
# Lambeth Dr => Lambeth Drive
# Smith Dr => Smith Drive
# Rivercrest Dr => Rivercrest Drive
# Creekbend Dr => Creekbend Drive
# Heard Dr => Heard Drive
# Patsy Dr => Patsy Drive
# Woodland Brook Dr => Woodland Brook Drive
# Laguna Springs Dr => Laguna Springs Drive
# Foxboro Dr => Foxboro Drive
# Peachtree Dr => Peachtree Drive
# Summer Point Dr => Summer Point Drive
# Hickory Dr => Hickory Drive
# Westover Dr => Westover Drive
# Memorial Dr => Memorial Drive
# Floating Cabin Dr => Floating Cabin Drive
# Evans Mill Dr => Evans Mill Drive
# Dewberry Creek Dr => Dewberry Creek Drive
# Pruitt Dr => Pruitt Drive
# Patty Dr => Patty Drive
# Gibson Dr => Gibson Drive
# Chastain Dr => Chastain Drive
# Dogwood Knoll Dr => Dogwood Knoll Drive
# S McCollum Dr => S McCollum Drive
# Towne Ridge Dr => Towne Ridge Drive
# Sky Lark Dr => Sky Lark Drive
# Hill Creek Dr => Hill Creek Drive
# Breckenridge Dr => Breckenridge Drive
# W Elmwood Dr => W Elmwood Drive
# Fountain Dr => Fountain Drive
# Ficklen Dr => Ficklen Drive
# Knotts Landing Dr => Knotts Landing Drive
# Arborhill Dr => Arborhill Drive
# Wood Valley Dr => Wood Valley Drive
# Skyline Dr => Skyline Drive
# Stonybrook Dr => Stonybrook Drive
# Charles Cox Dr => Charles Cox Drive
# Ivy Crest Dr => Ivy Crest Drive
# Arrowhead Dr => Arrowhead Drive
# Northcroft Dr => Northcroft Drive
# Greys Mill Dr => Greys Mill Drive
# Crabapple Springs Dr => Crabapple Springs Drive
# Ray Dr => Ray Drive
# Lee Dr => Lee Drive
# Cherokee Overlook Dr => Cherokee Overlook Drive
# River Station Dr => River Station Drive
# Twin Pines Dr => Twin Pines Drive
# Cowart Dr => Cowart Drive
# Civic Dr => Civic Drive
# Morris Hill Dr => Morris Hill Drive
# Mills Ridge Dr => Mills Ridge Drive
# Brook Forest Dr => Brook Forest Drive
# Tom Hulsey Dr => Tom Hulsey Drive
# Old Course Dr => Old Course Drive
# Lester Dr => Lester Drive
# Deerfield Dr => Deerfield Drive
# Hillmont Dr => Hillmont Drive
# Sundown Dr => Sundown Drive
# Green Dr => Green Drive
# Watkins Glen Dr => Watkins Glen Drive
# Stone Edge Dr => Stone Edge Drive
# Dixie Dr => Dixie Drive
# Woodside Park Dr => Woodside Park Drive
# Narrows Dr => Narrows Drive
# Valley Brook Dr => Valley Brook Drive
# Brandi Dr => Brandi Drive
# Due West Dr => Due West Drive
# Shady Brook Dr => Shady Brook Drive
# Fox Creek Dr => Fox Creek Drive
# Amberwood Dr => Amberwood Drive
# Claude Pettit Dr => Claude Pettit Drive
# Blake Dr => Blake Drive
# Gray Dr => Gray Drive
# Holly Dr => Holly Drive
# Cedar Brook Dr => Cedar Brook Drive
# Clarkview Dr => Clarkview Drive
# Williams Dr => Williams Drive
# Robinhood Dr => Robinhood Drive
# Bluff Creek Dr => Bluff Creek Drive
# W Memorial Dr => W Memorial Drive
# Putnam Ford Dr => Putnam Ford Drive
# Copper Creek Dr => Copper Creek Drive
# Cove Dr => Cove Drive
# Stockwood Dr => Stockwood Drive
# Messer Reece Dr => Messer Reece Drive
# S Lake Dr => S Lake Drive
# Allatoona Hill Dr => Allatoona Hill Drive
# Wiiliam Falls Dr => Wiiliam Falls Drive
# Mauldin Dr => Mauldin Drive
# Key Dr => Key Drive
# Jack Page Dr => Jack Page Drive
# Arch Dr => Arch Drive
# Merchants Dr => Merchants Drive
# Allatoona Dr => Allatoona Drive
# Quarles Dr => Quarles Drive
# Lady Savannah Dr => Lady Savannah Drive
# Springfield Dr => Springfield Drive
# White Eagle Dr => White Eagle Drive
# Indian Trace Dr => Indian Trace Drive
# Skyridge Dr => Skyridge Drive
# Sadler Dr => Sadler Drive
# Farmington Dr => Farmington Drive
# Watson Dr => Watson Drive
# Redfield Dr => Redfield Drive
# Mc Cready Dr => Mc Cready Drive
# Poinsetta Dr => Poinsetta Drive
# Winooki Dr => Winooki Drive
# Picketts Ferry Dr => Picketts Ferry Drive
# Pecan Dr => Pecan Drive
# Hampton Dr => Hampton Drive
# Brompton Dr => Brompton Drive
# Hidden Valley Dr => Hidden Valley Drive
# Jade Dr => Jade Drive
# Covered Wagon Dr => Covered Wagon Drive
# John Wesley Dr => John Wesley Drive
# Crossbrook Dr => Crossbrook Drive
# White City Dr => White City Drive
# Wolverine Dr => Wolverine Drive
# Southern Trace Dr => Southern Trace Drive
# Apple Valley Dr => Apple Valley Drive
# Woodland Dr => Woodland Drive
# Foothill Dr => Foothill Drive
# Wedgewood Dr => Wedgewood Drive
# Doris Dr => Doris Drive
# White Path Dr => White Path Drive
# Highlands Dr => Highlands Drive
# Emerald Pines Dr => Emerald Pines Drive
# Pine Grove Dr => Pine Grove Drive
# E Shore Dr => E Shore Drive
# Sweetwater Dr => Sweetwater Drive
# Magnolia Dr => Magnolia Drive
# Dials Dr => Dials Drive
# Apache Dr => Apache Drive
# Carmon Dr => Carmon Drive
# Walnut Dr => Walnut Drive
# Amanda Dr => Amanda Drive
# Little Brook Dr => Little Brook Drive
# Hopewell Chase Dr => Hopewell Chase Drive
# Poole Bridge Dr => Poole Bridge Drive
# Golden Hills Dr => Golden Hills Drive
# Ponderosa Dr => Ponderosa Drive
# Morningstar Dr => Morningstar Drive
# Nations Dr => Nations Drive
# Day Dr => Day Drive
# Orchard Dr => Orchard Drive
# Mountain View Dr => Mountain View Drive
# Summer Lake Dr => Summer Lake Drive
# Lawson Dr => Lawson Drive
# Crystal Springs Dr => Crystal Springs Drive
# Wood Ridge Dr => Wood Ridge Drive
# Horizon Dr => Horizon Drive
# Eagle Pointe Dr => Eagle Pointe Drive
# Roy Haynes Dr => Roy Haynes Drive
# Longwood Dr => Longwood Drive
# Windmill Dr => Windmill Drive
# Dene Dr => Dene Drive
# Arrow Wood Dr => Arrow Wood Drive
# Pinebrook Dr => Pinebrook Drive
# Westchester Club Dr => Westchester Club Drive
# Canvas Back Dr => Canvas Back Drive
# Apple Jack Dr => Apple Jack Drive
# Helms Dr => Helms Drive
# Hillside Dr => Hillside Drive
# Riverclift Dr => Riverclift Drive
# Princeton Dr => Princeton Drive
# Spring Dr => Spring Drive
# Norton Dr => Norton Drive
# Fielding Grove Dr => Fielding Grove Drive
# Creek Bank Dr => Creek Bank Drive
# Garretts Dr => Garretts Drive
# Hillcrest Dr => Hillcrest Drive
# Brook Rapids Dr => Brook Rapids Drive
# Thorn Thicket Dr => Thorn Thicket Drive
# Sycamore Dr => Sycamore Drive
# W Hanger Dr => W Hanger Drive
# Country Village Dr => Country Village Drive
# Queensbury Dr => Queensbury Drive
# Warehouse Dr => Warehouse Drive
# Quarry Dr => Quarry Drive
# Meadows Dr => Meadows Drive
# Regency Dr => Regency Drive
# Glendale Forest Dr => Glendale Forest Drive
# Lockhighland Dr => Lockhighland Drive
# Popcorn Dr => Popcorn Drive
# Dundee Dr => Dundee Drive
# Blackberry Dr => Blackberry Drive
# E Paulding Dr => E Paulding Drive
# Marsha Dr => Marsha Drive
# Mercer Dr => Mercer Drive
# Rose Ridge Dr => Rose Ridge Drive
# Cedar Mill Dr => Cedar Mill Drive
# Butler Industrial Dr => Butler Industrial Drive
# Jamie Dr => Jamie Drive
# William Bobo Dr => William Bobo Drive
# Lake Forest Dr => Lake Forest Drive
# Riverchase Dr => Riverchase Drive
# Big Woods Dr => Big Woods Drive
# Tyson Dr => Tyson Drive
# Mark Twain Dr => Mark Twain Drive
# Haithcock Dr => Haithcock Drive
# Pickett's Creek Dr => Pickett's Creek Drive
# King William Dr => King William Drive
# Hickory Fairway Dr => Hickory Fairway Drive
# Dillon Dr => Dillon Drive
# Willhaven Dr => Willhaven Drive
# Cliff Holcomb Dr => Cliff Holcomb Drive
# Cherokee Mills Dr => Cherokee Mills Drive
# Jaywood Dr => Jaywood Drive
# Allison Dr => Allison Drive
# Hedgewood Dr => Hedgewood Drive
# Kylemoor Dr => Kylemoor Drive
# Commerce Dr => Commerce Drive
# Timberchase Dr => Timberchase Drive
# Imperial Dr => Imperial Drive
# Coker Dr => Coker Drive
# Dogwood Dr => Dogwood Drive
# Woodbridge Dr => Woodbridge Drive
# Suzie Creek Dr => Suzie Creek Drive
# Purcell Free Dr => Purcell Free Drive
# Creekview Dr => Creekview Drive
# Paulding Meadows Dr => Paulding Meadows Drive
# Fort Wayne Dr => Fort Wayne Drive
# Heath Dr => Heath Drive
# White Oak Dr => White Oak Drive
# Cedar Creek Dr => Cedar Creek Drive
# Avery Creek Dr => Avery Creek Drive
# Magnolia Springs Dr => Magnolia Springs Drive
# Stewart Dr => Stewart Drive
# Bunt Hickory Dr => Bunt Hickory Drive
# River Plantation Dr => River Plantation Drive
# Lakewood Dr => Lakewood Drive
# Bridge Station Dr => Bridge Station Drive
# Rock Creek Dr => Rock Creek Drive
# Mondi Dr => Mondi Drive
# Beverly Dr => Beverly Drive
# Snookey Dr => Snookey Drive
# Diana Dr => Diana Drive
# Mohawk Dr => Mohawk Drive
# Robin Hood Dr => Robin Hood Drive
# Faye Dr => Faye Drive
# Hearthstone Dr => Hearthstone Drive
# Bluff Dr => Bluff Drive
# Bates Dr => Bates Drive
# Rustin Dr => Rustin Drive
# Wheeler Martin Dr => Wheeler Martin Drive
# Chattin Dr => Chattin Drive
# Monterey Dr => Monterey Drive
# Yorkshire Dr => Yorkshire Drive
# Zion Hill Dr => Zion Hill Drive
# Stoneybrook Dr => Stoneybrook Drive
# Rocky Creek Dr => Rocky Creek Drive
# Milton Dr => Milton Drive
# Viola Dr => Viola Drive
# Hicks Dr => Hicks Drive
# Brookridge Dr => Brookridge Drive
# Dunnwood Dr => Dunnwood Drive
# Swan Dr => Swan Drive
# E Memorial Dr => E Memorial Drive
# Fieldstone Dr => Fieldstone Drive
# Willis Dr => Willis Drive
# Northcreek Dr => Northcreek Drive
# Grey Eagle Dr => Grey Eagle Drive
# Sunset Dr => Sunset Drive
# Victory Dr => Victory Drive
# Cherecobb Dr => Cherecobb Drive
# Hummingbird Dr => Hummingbird Drive
# Cedar Dr => Cedar Drive
# Azalea Dr => Azalea Drive
# Yacht Club Dr => Yacht Club Drive
# Airport Dr => Airport Drive
# Hembree Hill Dr => Hembree Hill Drive
# Oak Hills Dr => Oak Hills Drive
# Whispering Woods Dr => Whispering Woods Drive
# Brolley Woods Dr => Brolley Woods Drive
# Gold Nugget Dr => Gold Nugget Drive
# Southfork Dr => Southfork Drive
# Little River Dr => Little River Drive
# Bascomb Park Dr => Bascomb Park Drive
# Old Cumming Dr => Old Cumming Drive
# Blueridge Dr => Blueridge Drive
# Neese Dr => Neese Drive
# Clearview Dr => Clearview Drive
# Fernbank Dr => Fernbank Drive
# Old Vandiver Dr => Old Vandiver Drive
# Barton Town Dr => Barton Town Drive
# Thornwood Dr => Thornwood Drive
# Cedar Valley Dr => Cedar Valley Drive
# Windsor Dr => Windsor Drive
# Lakeview Dr => Lakeview Drive
# Pope Dr => Pope Drive
# Providence Dr => Providence Drive
# Horsehoe Bend => Horsehoe Bend
# Overlook Bend => Overlook Bend
# Pool Bend => Pool Bend
# Sweetwater Bend => Sweetwater Bend
# Sapphire Bend => Sapphire Bend
# Marsh Rabbit Bend => Marsh Rabbit Bend
# Willow Bend => Willow Bend
# Parkland Bend => Parkland Bend
# Glade Bend => Glade Bend
# 5th Ave E => 5th Ave E
# 3rd Ave E => 3rd Ave E
# Towne Lake Hill E => Towne Lake Hill E
# S Forty Pass E => S Forty Pass E
# Village Green Cir E => Village Green Cir E
# Picketts Forge Dr E => Picketts Forge Dr E
# S R 140 => S R 140
# Sunset Strip => Sunset Strip
# US 41 (GA) => US 41 (GA)
# Cambridge Crossing => Cambridge Crossing
# Inverness Crossing => Inverness Crossing
# Hawkins Crossing => Hawkins Crossing
# West Hembree Crossing => West Hembree Crossing
# Wynhurst Crossing => Wynhurst Crossing
# Anmore Crossing => Anmore Crossing
# Galleon Crossing => Galleon Crossing
# Orso Crossing => Orso Crossing
# Idlewood Parc Crossing => Idlewood Parc Crossing
# Landing Entry => Landing Entry
# Davis Mill Rd N => Davis Mill Rd N
# Towne Lake Hill N => Towne Lake Hill N
# Brown Drive South => Brown Drive South
# Cobb Parkway South => Cobb Parkway South
# Interstate Highway 575 Byp Con => Interstate Highway 575 Byp Con
# State Rte 120 Con => State Rte 120 Con
# Lava lane => Lava Lane
# Creel lane => Creel Lane
# Benidorm COurt => Benidorm Court
# Shallowford Park Manor => Shallowford Park Manor
# Martin Falls Manor => Martin Falls Manor
# Hall Manor => Hall Manor
# Worthington Hills Manor => Worthington Hills Manor
# Manor Estate => Manor Estate
# Cedar Turn => Cedar Turn
# Gable Gate Turn => Gable Gate Turn
# Revere Turn => Revere Turn
# Riverwood Spring => Riverwood Spring
# Cherokee Ave S.E. => Cherokee Ave S.E.
# Clifton => Clifton
# Sanford drive => Sanford Drive
# Spring Hill Terrace => Spring Hill Terrace
# Waterbrook Terrace => Waterbrook Terrace
# Sylvan Terrace => Sylvan Terrace
# Scenic Terrace => Scenic Terrace
# Princeton Terrace => Princeton Terrace
# Fripp Terrace => Fripp Terrace
# Knoll Terrace => Knoll Terrace
# Clubside Terrace => Clubside Terrace
# Charleston Terrace => Charleston Terrace
# Fallview Terrace => Fallview Terrace
# Winburn Terrace => Winburn Terrace
# Dabney Terrace => Dabney Terrace
# Barcelona Terrace => Barcelona Terrace
# Wellington Terrace => Wellington Terrace
# Delmont Terrace => Delmont Terrace
# Parkside Terrace => Parkside Terrace
# Avalon Terrace => Avalon Terrace
# Courtyard Terrace => Courtyard Terrace
# Vesta Terrace => Vesta Terrace
# McAlpin Terrace => McAlpin Terrace
# Rugby Terrace => Rugby Terrace
# Villas Terrace => Villas Terrace
# Carlton Pointe Terrace => Carlton Pointe Terrace
# Carobet Terrace => Carobet Terrace
# Amhurst Terrace => Amhurst Terrace
# Weldstone Terrace => Weldstone Terrace
# Orchard Hill Terrace => Orchard Hill Terrace
# Wentworth Terrace => Wentworth Terrace
# Park Terrace => Park Terrace
# Valante Terrace => Valante Terrace
# Orly Terrace => Orly Terrace
# Springlake Terrace => Springlake Terrace
# Stoneview Terrace => Stoneview Terrace
# Raymond Terrace => Raymond Terrace
# Huntcliff Terrace => Huntcliff Terrace
# Jefferson Terrace => Jefferson Terrace
# Clear Creek Terrace => Clear Creek Terrace
# Oak Park Terrace => Oak Park Terrace
# Knoll Woods Terrace => Knoll Woods Terrace
# Headland Terrace => Headland Terrace
# Walnut Terrace => Walnut Terrace
# Pickett's Vw => Pickett's View
# Chadds Vw => Chadds View
# Cinema Vw => Cinema View
# Hunters Vw => Hunters View
# Peaceful Vw => Peaceful View
# N Industrial Blvd => N Industrial Blvd
# Millard Farmer Industrial Blvd => Millard Farmer Industrial Blvd
# Scott Blvd => Scott Blvd
# Paulding Blvd => Paulding Blvd
# Woodpark Blvd => Woodpark Blvd
# Liberty Blvd => Liberty Blvd
# White Columns Blvd => White Columns Blvd
# Satellite Blvd => Satellite Blvd
# Riverstone Blvd => Riverstone Blvd
# The Nalley Way, Atlanta, GA 30360 => The Nalley Way, Atlanta, GA 30360

# %%
# ================================================== #
#               Helper Functions                     #
# ================================================== #
def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag"""

    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


def validate_element(element, validator, schema=SCHEMA):
    """Raise ValidationError if element does not match schema"""
    if validator.validate(element, schema) is not True:
        field, errors = next(validator.errors.iteritems())
        message_string = "\nElement of type '{0}' has the following errors:\n{1}"
        error_string = pprint.pformat(errors)
        
        raise Exception(message_string.format(field, error_string))


class UnicodeDictWriter(csv.DictWriter, object):
    """Extend csv.DictWriter to handle Unicode input"""

    def writerow(self, row):
        super(UnicodeDictWriter, self).writerow({
            k: (v.encode('utf-8') if isinstance(v, unicode) else v) for k, v in row.iteritems()
        })

    def writerows(self, rows):
        for row in rows:
            self.writerow(row)

# %%
#shapes the interparse element object and return the dictionary
def shape_element_2(element, node_attr_fields=NODE_FIELDS, way_attr_fields=WAY_FIELDS,
                  problem_chars=PROBLEMCHARS, default_tag_type='regular'):
    """Clean and shape node or way XML element to Python dict"""
    node_attribs = {}
    way_attribs = {}
    way_nodes = []
    tags = []  #handle secondary tags the same way for both node and way elements

    if element.tag == 'node':
        for a in node_attr_fields:
            node_attribs[a] = element.attrib[a]

    if element.tag == 'way':
        for b in way_attr_fields:
            way_attribs[b] = element.attrib[b]

    for tag in element.iter('tag'):
        tag_dict = {}
        attributes = tag.attrib
        if problem_chars.search(tag.attrib['k']):
            continue

        if element.tag == 'node':
            tag_dict['id'] = node_attribs['id']
        else:
            tag_dict['id'] = way_attribs['id']
        tag_dict['value'] = attributes['v']

        if tag.attrib['k'] == 'addr:street':
            #update street names
            tag_dict['value'] = update_name(tag.attrib['v'], mapping) 
        else:
            pass
        lower_colon = LOWER_COLON.search(tag.attrib['k'])

        if lower_colon:

            before_colon = re.findall('^(.+?):', tag.attrib['k'])
            after_colon = re.findall('^[a-z|_]+:(.+)', tag.attrib['k'])

            tag_dict['type'] = before_colon
            tag_dict['key'] = after_colon

        else:
            tag_dict['key'] = attributes['k']
            tag_dict['type'] = 'regular'

        tags.append(tag_dict)

    if element.tag == 'way':
        count = 0 
        for nd in element.iter('nd'):
            way_node_dict = {}
            way_node_dict['id'] = element.attrib['id']
            way_node_dict['node_id'] = nd.attrib['ref']
            way_node_dict['position'] = count
            count += 1
            way_nodes.append(way_node_dict)



    if element.tag == 'node':
        return {'node': node_attribs, 'node_tags': tags}
    elif element.tag == 'way':
        return {'way': way_attribs, 'way_nodes': way_nodes, 'way_tags': tags}

# %%
# ================================================== #
#               Main Function                        #
# ================================================== #
def process_map_2(file_in, validate):
    """Iteratively process each XML element and write to csv(s)"""

    with codecs.open(NODES_PATH, 'w') as nodes_file, \
         codecs.open(NODE_TAGS_PATH, 'w') as nodes_tags_file, \
         codecs.open(WAYS_PATH, 'w') as ways_file, \
         codecs.open(WAY_NODES_PATH, 'w') as way_nodes_file, \
         codecs.open(WAY_TAGS_PATH, 'w') as way_tags_file:

        nodes_writer = UnicodeDictWriter(nodes_file, NODE_FIELDS)
        node_tags_writer = UnicodeDictWriter(nodes_tags_file, NODE_TAGS_FIELDS)
        ways_writer = UnicodeDictWriter(ways_file, WAY_FIELDS)
        way_nodes_writer = UnicodeDictWriter(way_nodes_file, WAY_NODES_FIELDS)
        way_tags_writer = UnicodeDictWriter(way_tags_file, WAY_TAGS_FIELDS)

        nodes_writer.writeheader()
        node_tags_writer.writeheader()
        ways_writer.writeheader()
        way_nodes_writer.writeheader()
        way_tags_writer.writeheader()

        validator = cerberus.Validator()

        for element in get_element(file_in, tags=('node', 'way')):
            el = shape_element_2(element)
            if el:
                if validate is True:
                    validate_element(el, validator)

                if element.tag == 'node':
                    nodes_writer.writerow(el['node'])
                    node_tags_writer.writerows(el['node_tags'])
                elif element.tag == 'way':
                    ways_writer.writerow(el['way'])
                    way_nodes_writer.writerows(el['way_nodes'])
                    way_tags_writer.writerows(el['way_tags'])

# %%
process_map_2(OSM_PATH, validate=False)

# %% [markdown]
# # Data Overview
#
# ### Statistics from the Atlanta OpenStreetMap dataset

# %% [markdown]
# `sample.osm:          248 MB
# project3.db:         146 MB
# nodes.csv:           97 MB
# nodes_tags.csv:      8 MB
# ways.csv:            5 MB
# ways_nodes.csv:      31 MB
# ways_tags.csv:       17 MB`

# %% [markdown]
# #### Number of unique users:

# %% [markdown]
# ``` sql
# SELECT COUNT(DISTINCT(e.uid))
# FROM (SELECT uid FROM nodes
#       UNION ALL
#       SELECT uid FROM ways) e;
# ```
#
# 1381

# %% [markdown]
# #### Number of nodes:

# %% [markdown]
# ```sql
# SELECT COUNT(*) FROM nodes;
# ```
#
# 1171609

# %% [markdown]
# #### Number of ways:

# %% [markdown]
# ``` sql
# SELECT COUNT(*) FROM ways;
# ```
#
# 84260

# %% [markdown]
# #### Top 5 contributing users:

# %% [markdown]
# ```sql
# SELECT u.user, COUNT(*) as num
# FROM (SELECT user FROM nodes
#       UNION ALL
#       SELECT user FROM ways) u
# GROUP BY u.user
# ORDER BY num DESC
# LIMIT 5;
# ```
#
#
# `Liber                         | 532818
# Saikrishna_FultonCountyImport | 241015
# woodpeck_fixbot               | 148812
# Jack the Ripper               | 35026
# afonit                        | 33632                       `

# %% [markdown]
# #### Top 5 types of 'natural' key:

# %% [markdown]
# ```sql
# SELECT tags.value, COUNT(*) as count
# FROM (SELECT * FROM nodes_tags
#       UNION ALL
#       SELECT * FROM ways_tags) tags
# WHERE tags.key = 'natural'
# GROUP BY tags.value
# ORDER BY count DESC
# LIMIT 5;
# ```
#
# `water   | 3180
# wood    | 810
# tree    | 561
# wetland | 137
# peak    | 25`

# %% [markdown]
# #### Most popular religions:

# %% [markdown]
# ```sql
# SELECT value, COUNT(*) as num
# FROM nodes_tags
# WHERE key='religion'
# GROUP BY value
# ORDER BY num DESC;
# ```
#
# `christian | 382
# muslim    | 1`

# %% [markdown]
# #### Top 5 cusines:

# %% [markdown]
# ```sql
# SELECT value, COUNT(*) as num
# FROM nodes_tags
# WHERE key='cuisine'
# GROUP BY value
# ORDER BY num DESC
# LIMIT 5;
# ```
#
#
# `
# burger   | 16
# pizza    | 11
# mexican  | 9
# chinese  | 7
# american | 6    `

# %% [markdown]
# ### Improvements
#
# #### 'place' key in the dataset:

# %% [markdown]
# ```sql
# SELECT value, COUNT(*) as num
# FROM nodes_tags
# WHERE key='place'
# GROUP BY value
# ORDER BY num DESC;
# ```
#
# `hamlet        | 193
# neighbourhood | 140
# village       | 13
# locality      | 6
# county        | 5
# suburb        | 5
# island        | 4    `

# %% [markdown]
# I thought it was odd to see the top place was a hamlet, the 3rd most common place was a village and neighbourhood is the British spelling. So I investigated where OpenStreetMaps was founded and it was as I guessed, in the UK. I would say that in the US we don't use the words hamlet or village to describe a place, at least not as widely as in the UK.
#
# I would recommend using more common words to the region to describe places. What does a hamlet mean vs. a village in the US? This would allow for better understanding of place types in the US, although I do understand using these place constructs for continuity throughout the entire map dataset. If this was implemented it would require common words to the region to be mapped back to the original meaning of hamlet/village.
#
# Benefits:
#
# * Better understanding of the place type keys in different areas of the world
# * Add meaning to the place keys in different areas of the world
#
# Anticipated Problems:
#
# * Going against the standard place keys can create continuity issues and create confusion
# * Common words to a region would have to be mapped back to the original place keys they are referring to
#
# I also noticed that there are apparently 4 islands in the dataset. I am not aware of any island in the Atlanta area so I investigated the 4 nodes.
#
# ``` sql
# SELECT nt.id, n.lat, n.lon
# FROM nodes_tags nt
# JOIN nodes n
# ON nt.id = n.id
# WHERE nt.key = 'place' AND nt.value = 'island';
# ```
#
# `358686776  | 32.9934577 | -85.1860533  -> Hairston Island (can't visibly see the island from Google Maps)
# 358697497  | 32.8515216 | -84.4668655  -> Owens Island
# 358705587  | 33.1481772 | -85.0546617  -> Swanson Island (can't visibly see the island from Google Maps)
# 3473397106 | 33.5887561 | -84.20201    -> An unnamed island, verified with Google Maps earth shot, maps shows as a body of water`
#
# It is strange that both OpenStreetMaps and Google Maps incorrectly identify 2 islands (and both show the unnamed island as a body of water), I would assume one is based on the other's incorrect assumption and neither have been audited.

# %% [markdown]
# ## References:

# %% [markdown]
# SQL sample project: https://gist.github.com/carlward/54ec1c91b62a5f911c42#file-sample_project-md
#
# SQL schema: https://gist.github.com/swwelch/f1144229848b407e0a5d13fcb7fbbd6f
#
# David Venturi's submission: https://gist.github.com/davidventuri/5c902f01ca2e483f5208111413adb13a
#
# Ly Vinh Hung's submission: https://github.com/lyvinhhung/Udacity-Data-Analyst-Nanodegree/blob/master/p3%20-%20Wrangle%20OpenStreetMap%20Data/P3%20-%20Data%20Wrangling%20with%20MongoDB.ipynb
#
# SQLite documentation: http://www.sqlite.org/cli.html
#
# Various posts in the Udacity forums: https://discussions.udacity.com/c/nd002-p3-data-wrangling
